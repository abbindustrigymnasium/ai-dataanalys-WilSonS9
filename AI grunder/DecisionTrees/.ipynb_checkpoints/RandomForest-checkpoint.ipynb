# %% [markdown]
# Modifierad kod modifierad kod från första exemplet, nu med 9000% fler träd!

# %%
# For Python 2 / 3 compatability
from __future__ import print_function
import random
import operator

# %%
# Toy dataset.
# Format: each row is an example.
# The last column is the label.
# The first two columns are features.
# Feel free to play with it by adding more features & examples.
# Interesting note: I've written this so the 2nd and 5th examples
# have the same features, but different labels - so we can see how the
# tree handles this case.
training_data = [    [54.4, 14.4, 'Kylrum'],    [45.4, 12.4, 'Kylrum'],    [89.4, 19.5, 'Klassrum'],
[57.4, 18.1, 'Lärarrum'],     [22.4, 8.6, 'Kylrum'],    [24.4, 11.24, 'Kylrum'],    [84.4, 24.4,
'Klassrum'],    [95.4, 22.4, 'Klassrum'],    [81.4, 20.1, 'Lärarrum'],    [70, 19.7, 'Lärarrum'],  [70, 19.8,'Klassrum']]

# %%
# Column labels.
# These are used only to print the tree.
header = ["luftfuktighet", "temperatur", "label"]

# %%
def unique_vals(rows, col):
    """Find the unique values for a column in a dataset."""
    return set([row[col] for row in rows])

# %%
#######
# Demo:
unique_vals(training_data, 2)
# unique_vals(training_data, 1)
#######
# Out:
# {'Klassrum', 'Kylrum', 'Lärarrum'}

# %%
def class_counts(rows):
    """Counts the number of each type of example in a dataset."""
    counts = {}  # a dictionary of label -> count.
    for row in rows:
        # in our dataset format, the label is always the last column
        label = row[-1]
        if label not in counts:
            counts[label] = 0
        counts[label] += 1
    return counts

# %%
## Här nedan har vi en datagenererare

# %%
# %%time
def dataGenerator(n):
    data = []
    n1 = random.randint(0, round(n/2)-1)
    n2 = random.randint(0, n-n1)
    n3 = n - n1 - n2
    for x in range(0,n1+1):
        l = round(random.uniform(15,60), 1)
        t = round(random.uniform(10,16), 1)
        label = "Kylrum"
        data.append([l,t,label])
    for x in range(0,n2+1):
        l = round(random.uniform(50,90), 1)
        t = round(random.uniform(16,22), 1)
        label = "Lärarrum"
        data.append([l,t,label])
    for x in range(0,n3+1):
        l = round(random.uniform(80,100), 1)
        t = round(random.uniform(18,24), 1)
        label = "Klassrum"
        data.append([l,t,label])
    return data
training_data = dataGenerator(2000)
random.shuffle(training_data)
training_data
# Out:
# Wall time: 47 ms
# [[72.5, 20.1, 'Lärarrum'],
#  [85.7, 23.4, 'Klassrum'],
#  [43.8, 11.3, 'Kylrum'],
#  [64.6, 19.5, 'Lärarrum'],
#  [71.6, 19.2, 'Lärarrum'],
#  [72.2, 16.2, 'Lärarrum'],
#  [38.7, 13.1, 'Kylrum'],
#  [63.6, 17.7, 'Lärarrum'],
#  [39.2, 15.1, 'Kylrum'],
#  [38.8, 15.8, 'Kylrum'],
#  [48.0, 11.0, 'Kylrum'],
#  [41.6, 13.7, 'Kylrum'],
#  [98.5, 19.3, 'Klassrum'],
#  [50.6, 17.1, 'Lärarrum'],
#  [24.4, 11.1, 'Kylrum'],
#  [58.0, 19.8, 'Lärarrum'],
#  [78.8, 16.7, 'Lärarrum'],
#  [81.3, 22.4, 'Klassrum'],
#  [65.0, 19.6, 'Lärarrum'],
#  [86.3, 23.0, 'Klassrum'],
#  [64.2, 17.7, 'Lärarrum'],
#  [85.0, 20.4, 'Klassrum'],
#  [76.9, 17.3, 'Lärarrum'],
#  [75.6, 16.7, 'Lärarrum'],
#  [88.2, 20.5, 'Lärarrum'],
#  [59.1, 20.2, 'Lärarrum'],
#  [66.4, 21.4, 'Lärarrum'],
#  [88.1, 18.8, 'Lärarrum'],
#  [52.4, 17.7, 'Lärarrum'],
#  [93.9, 18.2, 'Klassrum'],
#  [51.8, 14.9, 'Kylrum'],
#  [56.1, 21.9, 'Lärarrum'],
#  [50.9, 15.6, 'Kylrum'],
#  [80.0, 16.7, 'Lärarrum'],
#  [87.1, 22.5, 'Klassrum'],
#  [56.8, 19.3, 'Lärarrum'],
#  [52.7, 20.0, 'Lärarrum'],
#  [57.1, 19.3, 'Lärarrum'],
#  [88.3, 16.3, 'Lärarrum'],
#  [62.4, 20.5, 'Lärarrum'],
#  [48.7, 12.9, 'Kylrum'],
#  [45.2, 12.3, 'Kylrum'],
#  [81.0, 16.9, 'Lärarrum'],
#  [50.4, 15.4, 'Kylrum'],
#  [29.3, 14.4, 'Kylrum'],
#  [81.4, 18.8, 'Lärarrum'],
#  [38.9, 15.2, 'Kylrum'],
#  [59.9, 19.3, 'Lärarrum'],
#  [76.4, 17.1, 'Lärarrum'],
#  [73.6, 21.7, 'Lärarrum'],
#  [50.4, 19.3, 'Lärarrum'],
#  [89.7, 18.6, 'Klassrum'],
#  [29.8, 13.0, 'Kylrum'],
#  [59.2, 16.7, 'Lärarrum'],
#  [29.3, 14.6, 'Kylrum'],
#  [73.2, 18.2, 'Lärarrum'],
#  [98.3, 20.9, 'Klassrum'],
#  [88.7, 16.7, 'Lärarrum'],
#  [82.9, 23.3, 'Klassrum'],
#  [80.7, 16.2, 'Lärarrum'],
#  [66.7, 18.4, 'Lärarrum'],
#  [53.9, 20.0, 'Lärarrum'],
#  [47.9, 15.1, 'Kylrum'],
#  [42.4, 11.6, 'Kylrum'],
#  [80.5, 21.6, 'Lärarrum'],
#  [92.0, 23.0, 'Klassrum'],
#  [21.6, 12.0, 'Kylrum'],
#  [80.6, 19.8, 'Klassrum'],
#  [87.1, 17.1, 'Lärarrum'],
#  [82.7, 20.2, 'Klassrum'],
#  [62.2, 18.3, 'Lärarrum'],
#  [89.4, 21.8, 'Klassrum'],
#  [84.9, 16.9, 'Lärarrum'],
#  [95.3, 23.0, 'Klassrum'],
#  [55.2, 20.1, 'Lärarrum'],
#  [86.2, 18.7, 'Klassrum'],
#  [79.5, 17.6, 'Lärarrum'],
#  [73.1, 20.1, 'Lärarrum'],
#  [50.8, 21.4, 'Lärarrum'],
#  [25.0, 14.5, 'Kylrum'],
#  [75.5, 17.2, 'Lärarrum'],
#  [30.0, 15.6, 'Kylrum'],
#  [67.9, 17.8, 'Lärarrum'],
#  [81.6, 21.5, 'Lärarrum'],
#  [20.9, 10.2, 'Kylrum'],
#  [32.1, 14.9, 'Kylrum'],
#  [61.2, 16.1, 'Lärarrum'],
#  [30.9, 12.5, 'Kylrum'],
#  [51.2, 15.6, 'Kylrum'],
#  [26.5, 10.7, 'Kylrum'],
#  [50.4, 21.9, 'Lärarrum'],
#  [93.6, 20.9, 'Klassrum'],
#  [86.2, 19.7, 'Lärarrum'],
#  [50.3, 20.2, 'Lärarrum'],
#  [35.6, 10.3, 'Kylrum'],
#  [49.4, 10.9, 'Kylrum'],
#  [92.3, 20.4, 'Klassrum'],
#  [19.1, 11.6, 'Kylrum'],
#  [77.9, 20.2, 'Lärarrum'],
#  [94.9, 21.3, 'Klassrum'],
#  [62.2, 16.6, 'Lärarrum'],
#  [76.0, 16.0, 'Lärarrum'],
#  [59.3, 18.7, 'Lärarrum'],
#  [87.4, 20.3, 'Lärarrum'],
#  [78.5, 21.9, 'Lärarrum'],
#  [54.0, 16.9, 'Lärarrum'],
#  [21.6, 15.8, 'Kylrum'],
#  [29.0, 14.4, 'Kylrum'],
#  [79.3, 19.2, 'Lärarrum'],
#  [72.9, 17.9, 'Lärarrum'],
#  [27.9, 15.9, 'Kylrum'],
#  [53.0, 11.8, 'Kylrum'],
#  [66.1, 22.0, 'Lärarrum'],
#  [76.9, 21.9, 'Lärarrum'],
#  [77.5, 19.6, 'Lärarrum'],
#  [84.1, 23.1, 'Klassrum'],
#  [81.8, 18.7, 'Lärarrum'],
#  [55.5, 13.0, 'Kylrum'],
#  [35.2, 14.7, 'Kylrum'],
#  [26.2, 12.1, 'Kylrum'],
#  [68.1, 19.7, 'Lärarrum'],
#  [74.4, 21.9, 'Lärarrum'],
#  [51.2, 18.7, 'Lärarrum'],
#  [24.4, 14.7, 'Kylrum'],
#  [26.7, 11.4, 'Kylrum'],
#  [96.4, 19.2, 'Klassrum'],
#  [30.3, 15.9, 'Kylrum'],
#  [15.8, 15.9, 'Kylrum'],
#  [85.8, 18.3, 'Lärarrum'],
#  [27.9, 15.3, 'Kylrum'],
#  [70.2, 20.5, 'Lärarrum'],
#  [68.0, 20.4, 'Lärarrum'],
#  [56.2, 15.9, 'Kylrum'],
#  [40.6, 15.4, 'Kylrum'],
#  [54.1, 16.2, 'Lärarrum'],
#  [51.9, 18.6, 'Lärarrum'],
#  [90.8, 20.1, 'Klassrum'],
#  [73.5, 18.0, 'Lärarrum'],
#  [84.6, 22.9, 'Klassrum'],
#  [54.1, 12.8, 'Kylrum'],
#  [36.7, 15.6, 'Kylrum'],
#  [57.1, 18.6, 'Lärarrum'],
#  [89.8, 19.3, 'Lärarrum'],
#  [50.5, 11.6, 'Kylrum'],
#  [77.3, 16.8, 'Lärarrum'],
#  [68.2, 21.6, 'Lärarrum'],
#  [82.8, 16.9, 'Lärarrum'],
#  [83.6, 20.6, 'Klassrum'],
#  [82.6, 18.1, 'Klassrum'],
#  [78.3, 16.7, 'Lärarrum'],
#  [79.0, 20.0, 'Lärarrum'],
#  [97.5, 20.4, 'Klassrum'],
#  [69.7, 16.2, 'Lärarrum'],
#  [80.8, 23.9, 'Klassrum'],
#  [69.2, 21.8, 'Lärarrum'],
#  [74.3, 18.7, 'Lärarrum'],
#  [86.6, 19.0, 'Klassrum'],
#  [80.5, 18.0, 'Lärarrum'],
#  [63.9, 16.8, 'Lärarrum'],
#  [80.2, 23.6, 'Klassrum'],
#  [72.9, 17.0, 'Lärarrum'],
#  [85.7, 21.7, 'Lärarrum'],
#  [64.1, 16.8, 'Lärarrum'],
#  [74.7, 16.4, 'Lärarrum'],
#  [54.3, 19.2, 'Lärarrum'],
#  [70.0, 19.9, 'Lärarrum'],
#  [65.3, 17.9, 'Lärarrum'],
#  [49.6, 13.5, 'Kylrum'],
#  [50.9, 19.3, 'Lärarrum'],
#  [45.4, 12.3, 'Kylrum'],
#  [78.5, 16.1, 'Lärarrum'],
#  [82.9, 19.7, 'Klassrum'],
#  [75.1, 20.5, 'Lärarrum'],
#  [41.6, 15.0, 'Kylrum'],
#  [87.0, 18.2, 'Klassrum'],
#  [71.1, 16.4, 'Lärarrum'],
#  [89.1, 18.9, 'Lärarrum'],
#  [69.8, 16.2, 'Lärarrum'],
#  [84.7, 20.9, 'Klassrum'],
#  [87.5, 24.0, 'Klassrum'],
#  [18.6, 12.3, 'Kylrum'],
#  [51.0, 18.6, 'Lärarrum'],
#  [72.4, 21.9, 'Lärarrum'],
#  [88.6, 18.8, 'Lärarrum'],
#  [85.5, 23.9, 'Klassrum'],
#  [51.7, 16.8, 'Lärarrum'],
#  [75.4, 19.2, 'Lärarrum'],
#  [80.4, 20.1, 'Lärarrum'],
#  [54.1, 18.3, 'Lärarrum'],
#  [68.0, 17.7, 'Lärarrum'],
#  [93.5, 21.9, 'Klassrum'],
#  [81.0, 18.0, 'Klassrum'],
#  [17.2, 14.5, 'Kylrum'],
#  [37.5, 13.7, 'Kylrum'],
#  [79.7, 18.8, 'Lärarrum'],
#  [85.7, 23.4, 'Klassrum'],
#  [66.2, 20.7, 'Lärarrum'],
#  [23.6, 12.9, 'Kylrum'],
#  [74.4, 19.7, 'Lärarrum'],
#  [79.4, 17.4, 'Lärarrum'],
#  [68.8, 22.0, 'Lärarrum'],
#  [22.1, 15.7, 'Kylrum'],
#  [29.6, 13.0, 'Kylrum'],
#  [40.9, 10.7, 'Kylrum'],
#  [72.5, 20.0, 'Lärarrum'],
#  [47.1, 13.7, 'Kylrum'],
#  [77.2, 16.1, 'Lärarrum'],
#  [16.1, 10.3, 'Kylrum'],
#  [43.2, 10.7, 'Kylrum'],
#  [73.8, 18.4, 'Lärarrum'],
#  [22.9, 13.0, 'Kylrum'],
#  [31.7, 14.1, 'Kylrum'],
#  [52.1, 17.9, 'Lärarrum'],
#  [86.3, 18.0, 'Lärarrum'],
#  [82.3, 16.9, 'Lärarrum'],
#  [77.1, 21.2, 'Lärarrum'],
#  [19.4, 12.9, 'Kylrum'],
#  [86.7, 21.0, 'Klassrum'],
#  [83.1, 18.2, 'Klassrum'],
#  [55.9, 19.1, 'Lärarrum'],
#  [95.5, 20.8, 'Klassrum'],
#  [43.5, 13.1, 'Kylrum'],
#  [72.5, 18.3, 'Lärarrum'],
#  [83.1, 16.8, 'Lärarrum'],
#  [81.1, 19.3, 'Klassrum'],
#  [70.0, 17.7, 'Lärarrum'],
#  [82.9, 20.2, 'Lärarrum'],
#  [43.3, 13.2, 'Kylrum'],
#  [37.9, 12.1, 'Kylrum'],
#  [73.3, 20.0, 'Lärarrum'],
#  [82.6, 19.6, 'Lärarrum'],
#  [71.3, 18.4, 'Lärarrum'],
#  [76.9, 18.8, 'Lärarrum'],
#  [45.5, 13.9, 'Kylrum'],
#  [57.4, 20.4, 'Lärarrum'],
#  [65.5, 20.1, 'Lärarrum'],
#  [79.1, 16.7, 'Lärarrum'],
#  [50.4, 17.2, 'Lärarrum'],
#  [52.7, 16.0, 'Kylrum'],
#  [65.1, 20.3, 'Lärarrum'],
#  [44.2, 12.2, 'Kylrum'],
#  [71.9, 21.7, 'Lärarrum'],
#  [33.8, 13.0, 'Kylrum'],
#  [40.4, 11.9, 'Kylrum'],
#  [47.0, 14.6, 'Kylrum'],
#  [37.6, 14.4, 'Kylrum'],
#  [27.4, 13.7, 'Kylrum'],
#  [98.5, 22.6, 'Klassrum'],
#  [53.4, 21.0, 'Lärarrum'],
#  [89.4, 21.7, 'Lärarrum'],
#  [42.0, 11.8, 'Kylrum'],
#  [25.4, 15.8, 'Kylrum'],
#  [84.1, 17.1, 'Lärarrum'],
#  [81.5, 20.1, 'Klassrum'],
#  [61.0, 21.8, 'Lärarrum'],
#  [45.1, 10.5, 'Kylrum'],
#  [29.8, 15.7, 'Kylrum'],
#  [73.7, 18.4, 'Lärarrum'],
#  [87.7, 17.8, 'Lärarrum'],
#  [86.9, 20.9, 'Lärarrum'],
#  [38.5, 15.0, 'Kylrum'],
#  [48.7, 12.5, 'Kylrum'],
#  [74.3, 18.6, 'Lärarrum'],
#  [24.3, 15.5, 'Kylrum'],
#  [24.3, 11.7, 'Kylrum'],
#  [59.0, 21.4, 'Lärarrum'],
#  [74.6, 18.0, 'Lärarrum'],
#  [82.7, 18.1, 'Lärarrum'],
#  [89.6, 19.5, 'Lärarrum'],
#  [73.0, 21.3, 'Lärarrum'],
#  [56.7, 17.9, 'Lärarrum'],
#  [89.3, 23.5, 'Klassrum'],
#  [60.0, 10.3, 'Kylrum'],
#  [71.3, 20.2, 'Lärarrum'],
#  [57.7, 19.5, 'Lärarrum'],
#  [84.4, 20.3, 'Klassrum'],
#  [86.9, 16.1, 'Lärarrum'],
#  [31.2, 15.1, 'Kylrum'],
#  [94.4, 22.5, 'Klassrum'],
#  [59.8, 17.3, 'Lärarrum'],
#  [86.1, 21.0, 'Klassrum'],
#  [47.2, 11.6, 'Kylrum'],
#  [50.9, 17.4, 'Lärarrum'],
#  [33.7, 15.0, 'Kylrum'],
#  [57.6, 17.8, 'Lärarrum'],
#  [54.8, 10.3, 'Kylrum'],
#  [97.0, 20.8, 'Klassrum'],
#  [50.7, 21.8, 'Lärarrum'],
#  [52.5, 17.7, 'Lärarrum'],
#  [92.9, 19.5, 'Klassrum'],
#  [44.5, 15.4, 'Kylrum'],
#  [81.8, 19.6, 'Lärarrum'],
#  [54.1, 14.4, 'Kylrum'],
#  [76.8, 21.9, 'Lärarrum'],
#  [69.1, 20.6, 'Lärarrum'],
#  [74.0, 20.9, 'Lärarrum'],
#  [29.8, 11.7, 'Kylrum'],
#  [52.3, 11.9, 'Kylrum'],
#  [48.2, 11.4, 'Kylrum'],
#  [33.7, 11.0, 'Kylrum'],
#  [98.9, 22.4, 'Klassrum'],
#  [67.5, 21.8, 'Lärarrum'],
#  [66.2, 19.1, 'Lärarrum'],
#  [58.3, 20.2, 'Lärarrum'],
#  [83.6, 20.6, 'Lärarrum'],
#  [83.2, 21.1, 'Lärarrum'],
#  [74.1, 21.1, 'Lärarrum'],
#  [24.8, 10.4, 'Kylrum'],
#  [23.8, 13.7, 'Kylrum'],
#  [86.7, 16.9, 'Lärarrum'],
#  [48.8, 10.9, 'Kylrum'],
#  [74.3, 16.4, 'Lärarrum'],
#  [86.2, 20.1, 'Lärarrum'],
#  [44.7, 15.3, 'Kylrum'],
#  [55.1, 18.7, 'Lärarrum'],
#  [80.3, 19.0, 'Lärarrum'],
#  [45.7, 13.5, 'Kylrum'],
#  [53.1, 21.0, 'Lärarrum'],
#  [60.5, 17.0, 'Lärarrum'],
#  [91.1, 20.8, 'Klassrum'],
#  [55.6, 17.1, 'Lärarrum'],
#  [84.4, 21.3, 'Lärarrum'],
#  [84.0, 18.0, 'Lärarrum'],
#  [60.5, 17.2, 'Lärarrum'],
#  [85.1, 16.8, 'Lärarrum'],
#  [66.9, 20.3, 'Lärarrum'],
#  [83.8, 22.7, 'Klassrum'],
#  [84.6, 17.9, 'Lärarrum'],
#  [86.5, 21.9, 'Lärarrum'],
#  [64.9, 20.1, 'Lärarrum'],
#  [69.9, 19.8, 'Lärarrum'],
#  [56.3, 13.9, 'Kylrum'],
#  [65.3, 16.5, 'Lärarrum'],
#  [71.3, 21.8, 'Lärarrum'],
#  [53.1, 16.8, 'Lärarrum'],
#  [91.1, 20.0, 'Klassrum'],
#  [28.4, 13.9, 'Kylrum'],
#  [26.4, 15.6, 'Kylrum'],
#  [65.2, 20.7, 'Lärarrum'],
#  [52.4, 14.4, 'Kylrum'],
#  [99.3, 23.2, 'Klassrum'],
#  [59.4, 19.6, 'Lärarrum'],
#  [20.4, 13.2, 'Kylrum'],
#  [93.2, 18.7, 'Klassrum'],
#  [95.6, 19.6, 'Klassrum'],
#  [31.5, 10.6, 'Kylrum'],
#  [89.5, 19.7, 'Lärarrum'],
#  [55.9, 18.7, 'Lärarrum'],
#  [93.5, 21.1, 'Klassrum'],
#  [88.4, 20.2, 'Lärarrum'],
#  [72.6, 20.5, 'Lärarrum'],
#  [63.7, 19.1, 'Lärarrum'],
#  [23.6, 12.7, 'Kylrum'],
#  [62.6, 20.9, 'Lärarrum'],
#  [35.3, 14.8, 'Kylrum'],
#  [70.7, 18.9, 'Lärarrum'],
#  [72.9, 19.7, 'Lärarrum'],
#  [91.7, 18.9, 'Klassrum'],
#  [97.5, 18.7, 'Klassrum'],
#  [63.1, 21.3, 'Lärarrum'],
#  [89.8, 19.1, 'Lärarrum'],
#  [81.0, 22.9, 'Klassrum'],
#  [56.8, 10.5, 'Kylrum'],
#  [61.6, 16.5, 'Lärarrum'],
#  [94.9, 23.5, 'Klassrum'],
#  [93.5, 18.2, 'Klassrum'],
#  [99.5, 19.1, 'Klassrum'],
#  [27.6, 12.4, 'Kylrum'],
#  [53.8, 19.8, 'Lärarrum'],
#  [87.6, 23.1, 'Klassrum'],
#  [41.8, 12.0, 'Kylrum'],
#  [26.3, 15.4, 'Kylrum'],
#  [81.9, 18.0, 'Lärarrum'],
#  [32.4, 11.4, 'Kylrum'],
#  [36.4, 13.6, 'Kylrum'],
#  [25.9, 13.9, 'Kylrum'],
#  [98.8, 18.8, 'Klassrum'],
#  [80.3, 19.0, 'Klassrum'],
#  [25.5, 14.6, 'Kylrum'],
#  [51.2, 11.6, 'Kylrum'],
#  [84.2, 18.5, 'Klassrum'],
#  [76.9, 17.9, 'Lärarrum'],
#  [63.2, 21.0, 'Lärarrum'],
#  [54.0, 16.7, 'Lärarrum'],
#  [39.5, 13.2, 'Kylrum'],
#  [96.7, 21.9, 'Klassrum'],
#  [51.6, 19.8, 'Lärarrum'],
#  [26.8, 12.6, 'Kylrum'],
#  [16.9, 15.2, 'Kylrum'],
#  [97.3, 18.6, 'Klassrum'],
#  [55.8, 18.9, 'Lärarrum'],
#  [58.2, 17.0, 'Lärarrum'],
#  [44.6, 15.2, 'Kylrum'],
#  [67.8, 21.9, 'Lärarrum'],
#  [32.4, 12.1, 'Kylrum'],
#  [33.8, 11.1, 'Kylrum'],
#  [62.1, 20.4, 'Lärarrum'],
#  [89.3, 21.6, 'Klassrum'],
#  [89.3, 17.4, 'Lärarrum'],
#  [63.9, 19.1, 'Lärarrum'],
#  [27.4, 15.2, 'Kylrum'],
#  [27.6, 14.6, 'Kylrum'],
#  [67.3, 21.8, 'Lärarrum'],
#  [93.5, 22.2, 'Klassrum'],
#  [38.1, 10.3, 'Kylrum'],
#  [23.8, 13.8, 'Kylrum'],
#  [79.2, 19.9, 'Lärarrum'],
#  [86.3, 17.8, 'Lärarrum'],
#  [81.2, 19.9, 'Klassrum'],
#  [53.7, 18.9, 'Lärarrum'],
#  [67.3, 17.1, 'Lärarrum'],
#  [34.7, 10.0, 'Kylrum'],
#  [78.5, 18.3, 'Lärarrum'],
#  [86.2, 20.9, 'Klassrum'],
#  [55.2, 16.8, 'Lärarrum'],
#  [94.5, 24.0, 'Klassrum'],
#  [80.4, 18.5, 'Lärarrum'],
#  [79.5, 17.0, 'Lärarrum'],
#  [76.8, 21.3, 'Lärarrum'],
#  [57.9, 19.6, 'Lärarrum'],
#  [67.3, 17.2, 'Lärarrum'],
#  [74.3, 19.6, 'Lärarrum'],
#  [79.0, 20.2, 'Lärarrum'],
#  [50.8, 17.2, 'Lärarrum'],
#  [58.1, 17.8, 'Lärarrum'],
#  [26.3, 11.6, 'Kylrum'],
#  [23.3, 12.0, 'Kylrum'],
#  [57.6, 12.3, 'Kylrum'],
#  [81.2, 16.3, 'Lärarrum'],
#  [74.7, 20.1, 'Lärarrum'],
#  [43.4, 10.1, 'Kylrum'],
#  [52.7, 12.0, 'Kylrum'],
#  [74.5, 20.2, 'Lärarrum'],
#  [19.9, 11.4, 'Kylrum'],
#  [82.5, 21.7, 'Lärarrum'],
#  [83.4, 18.1, 'Lärarrum'],
#  [83.1, 20.0, 'Lärarrum'],
#  [86.1, 20.8, 'Lärarrum'],
#  [73.7, 16.9, 'Lärarrum'],
#  [94.1, 22.3, 'Klassrum'],
#  [64.3, 21.2, 'Lärarrum'],
#  [49.4, 12.4, 'Kylrum'],
#  [31.0, 11.0, 'Kylrum'],
#  [56.0, 20.9, 'Lärarrum'],
#  [20.9, 10.5, 'Kylrum'],
#  [58.9, 18.8, 'Lärarrum'],
#  [65.0, 18.7, 'Lärarrum'],
#  [71.0, 19.3, 'Lärarrum'],
#  [86.6, 17.9, 'Lärarrum'],
#  [74.7, 18.9, 'Lärarrum'],
#  [75.9, 20.2, 'Lärarrum'],
#  [55.4, 16.6, 'Lärarrum'],
#  [96.5, 18.4, 'Klassrum'],
#  [83.1, 19.6, 'Lärarrum'],
#  [59.7, 10.5, 'Kylrum'],
#  [89.5, 18.2, 'Klassrum'],
#  [66.7, 16.8, 'Lärarrum'],
#  [57.8, 16.4, 'Lärarrum'],
#  [54.4, 11.9, 'Kylrum'],
#  [78.5, 19.9, 'Lärarrum'],
#  [64.9, 17.7, 'Lärarrum'],
#  [56.6, 20.4, 'Lärarrum'],
#  [30.4, 15.7, 'Kylrum'],
#  [52.1, 15.0, 'Kylrum'],
#  [82.3, 20.9, 'Lärarrum'],
#  [87.4, 22.6, 'Klassrum'],
#  [69.7, 19.1, 'Lärarrum'],
#  [77.0, 19.8, 'Lärarrum'],
#  [74.3, 20.0, 'Lärarrum'],
#  [90.7, 19.5, 'Klassrum'],
#  [54.3, 20.8, 'Lärarrum'],
#  [62.6, 21.9, 'Lärarrum'],
#  [23.6, 14.5, 'Kylrum'],
#  [29.7, 11.6, 'Kylrum'],
#  [89.4, 21.6, 'Lärarrum'],
#  [58.8, 17.9, 'Lärarrum'],
#  [35.7, 16.0, 'Kylrum'],
#  [87.7, 22.2, 'Klassrum'],
#  [90.5, 18.5, 'Klassrum'],
#  [21.6, 14.8, 'Kylrum'],
#  [50.8, 18.2, 'Lärarrum'],
#  [89.7, 23.3, 'Klassrum'],
#  [55.2, 14.6, 'Kylrum'],
#  [84.7, 21.3, 'Klassrum'],
#  [71.0, 18.9, 'Lärarrum'],
#  [68.0, 18.6, 'Lärarrum'],
#  [53.0, 12.3, 'Kylrum'],
#  [86.4, 16.3, 'Lärarrum'],
#  [55.9, 16.9, 'Lärarrum'],
#  [87.4, 16.6, 'Lärarrum'],
#  [94.8, 21.8, 'Klassrum'],
#  [51.1, 15.6, 'Kylrum'],
#  [51.9, 18.3, 'Lärarrum'],
#  [62.8, 18.8, 'Lärarrum'],
#  [54.2, 17.4, 'Lärarrum'],
#  [86.1, 20.5, 'Lärarrum'],
#  [42.7, 11.2, 'Kylrum'],
#  [55.9, 16.3, 'Lärarrum'],
#  [87.5, 20.1, 'Klassrum'],
#  [70.1, 16.6, 'Lärarrum'],
#  [52.8, 19.9, 'Lärarrum'],
#  [98.4, 23.3, 'Klassrum'],
#  [53.9, 13.7, 'Kylrum'],
#  [27.1, 10.5, 'Kylrum'],
#  [91.9, 22.2, 'Klassrum'],
#  [52.0, 16.8, 'Lärarrum'],
#  [61.7, 20.1, 'Lärarrum'],
#  [31.4, 12.6, 'Kylrum'],
#  [83.1, 19.0, 'Lärarrum'],
#  [36.2, 14.3, 'Kylrum'],
#  [81.4, 19.9, 'Klassrum'],
#  [32.1, 13.1, 'Kylrum'],
#  [82.5, 19.0, 'Lärarrum'],
#  [47.2, 10.5, 'Kylrum'],
#  [82.2, 20.4, 'Lärarrum'],
#  [73.5, 17.8, 'Lärarrum'],
#  [63.1, 17.1, 'Lärarrum'],
#  [21.1, 12.5, 'Kylrum'],
#  [80.6, 16.5, 'Lärarrum'],
#  [65.9, 16.9, 'Lärarrum'],
#  [68.2, 20.4, 'Lärarrum'],
#  [73.9, 16.2, 'Lärarrum'],
#  [48.5, 11.7, 'Kylrum'],
#  [22.5, 10.7, 'Kylrum'],
#  [30.5, 15.9, 'Kylrum'],
#  [94.1, 19.7, 'Klassrum'],
#  [53.9, 15.5, 'Kylrum'],
#  [71.2, 19.9, 'Lärarrum'],
#  [59.8, 10.8, 'Kylrum'],
#  [81.2, 21.9, 'Lärarrum'],
#  [56.0, 19.0, 'Lärarrum'],
#  [66.3, 18.9, 'Lärarrum'],
#  [17.3, 10.7, 'Kylrum'],
#  [30.0, 13.2, 'Kylrum'],
#  [35.2, 14.9, 'Kylrum'],
#  [40.6, 12.5, 'Kylrum'],
#  [57.2, 15.7, 'Kylrum'],
#  [82.1, 21.1, 'Lärarrum'],
#  [30.3, 15.2, 'Kylrum'],
#  [87.4, 18.4, 'Klassrum'],
#  [81.4, 23.8, 'Klassrum'],
#  [24.9, 10.8, 'Kylrum'],
#  [62.8, 17.0, 'Lärarrum'],
#  [80.0, 17.0, 'Lärarrum'],
#  [15.6, 10.8, 'Kylrum'],
#  [55.9, 21.1, 'Lärarrum'],
#  [52.7, 20.5, 'Lärarrum'],
#  [68.4, 19.4, 'Lärarrum'],
#  [60.3, 20.7, 'Lärarrum'],
#  [55.4, 12.5, 'Kylrum'],
#  [78.5, 21.4, 'Lärarrum'],
#  [80.2, 19.2, 'Klassrum'],
#  [80.5, 21.6, 'Lärarrum'],
#  [73.8, 18.3, 'Lärarrum'],
#  [33.4, 10.6, 'Kylrum'],
#  [62.8, 20.5, 'Lärarrum'],
#  [80.3, 16.5, 'Lärarrum'],
#  [57.1, 18.8, 'Lärarrum'],
#  [62.9, 21.9, 'Lärarrum'],
#  [83.7, 20.5, 'Klassrum'],
#  [28.4, 14.2, 'Kylrum'],
#  [59.1, 14.8, 'Kylrum'],
#  [42.5, 11.8, 'Kylrum'],
#  [92.6, 23.8, 'Klassrum'],
#  [73.8, 20.9, 'Lärarrum'],
#  [43.3, 12.9, 'Kylrum'],
#  [65.1, 17.0, 'Lärarrum'],
#  [85.1, 21.3, 'Lärarrum'],
#  [67.9, 21.1, 'Lärarrum'],
#  [83.0, 19.0, 'Lärarrum'],
#  [63.2, 20.8, 'Lärarrum'],
#  [20.6, 10.4, 'Kylrum'],
#  [71.1, 19.5, 'Lärarrum'],
#  [59.8, 18.6, 'Lärarrum'],
#  [85.7, 16.9, 'Lärarrum'],
#  [66.6, 18.6, 'Lärarrum'],
#  [72.8, 17.0, 'Lärarrum'],
#  [37.8, 13.6, 'Kylrum'],
#  [80.5, 18.0, 'Lärarrum'],
#  [74.7, 17.4, 'Lärarrum'],
#  [88.3, 17.8, 'Lärarrum'],
#  [22.1, 15.6, 'Kylrum'],
#  [49.8, 14.5, 'Kylrum'],
#  [80.2, 21.8, 'Lärarrum'],
#  [88.9, 20.7, 'Lärarrum'],
#  [32.5, 16.0, 'Kylrum'],
#  [58.3, 15.4, 'Kylrum'],
#  [41.9, 12.0, 'Kylrum'],
#  [99.7, 21.7, 'Klassrum'],
#  [80.3, 18.7, 'Klassrum'],
#  [97.8, 22.1, 'Klassrum'],
#  [30.6, 15.4, 'Kylrum'],
#  [50.7, 11.7, 'Kylrum'],
#  [82.6, 16.3, 'Lärarrum'],
#  [48.5, 13.3, 'Kylrum'],
#  [30.2, 13.3, 'Kylrum'],
#  [56.2, 16.6, 'Lärarrum'],
#  [69.0, 16.4, 'Lärarrum'],
#  [79.1, 17.3, 'Lärarrum'],
#  [81.2, 16.8, 'Lärarrum'],
#  [67.9, 20.4, 'Lärarrum'],
#  [62.7, 21.3, 'Lärarrum'],
#  [60.9, 16.4, 'Lärarrum'],
#  [77.8, 16.4, 'Lärarrum'],
#  [35.6, 10.9, 'Kylrum'],
#  [24.6, 13.8, 'Kylrum'],
#  [72.3, 17.3, 'Lärarrum'],
#  [20.1, 16.0, 'Kylrum'],
#  [82.5, 17.9, 'Lärarrum'],
#  [26.6, 10.1, 'Kylrum'],
#  [86.7, 19.3, 'Lärarrum'],
#  [95.1, 18.1, 'Klassrum'],
#  [46.7, 13.7, 'Kylrum'],
#  [61.0, 17.7, 'Lärarrum'],
#  [86.0, 17.8, 'Lärarrum'],
#  [52.1, 21.5, 'Lärarrum'],
#  [52.6, 21.8, 'Lärarrum'],
#  [48.1, 14.7, 'Kylrum'],
#  [68.0, 16.1, 'Lärarrum'],
#  [39.1, 12.7, 'Kylrum'],
#  [88.3, 18.6, 'Lärarrum'],
#  [21.9, 11.0, 'Kylrum'],
#  [34.6, 11.4, 'Kylrum'],
#  [90.7, 23.6, 'Klassrum'],
#  [58.0, 17.7, 'Lärarrum'],
#  [57.5, 11.5, 'Kylrum'],
#  [63.1, 17.8, 'Lärarrum'],
#  [70.6, 18.5, 'Lärarrum'],
#  [35.4, 11.7, 'Kylrum'],
#  [77.2, 17.8, 'Lärarrum'],
#  [83.8, 19.0, 'Klassrum'],
#  [53.6, 18.4, 'Lärarrum'],
#  [51.4, 15.8, 'Kylrum'],
#  [59.3, 14.6, 'Kylrum'],
#  [86.4, 19.8, 'Klassrum'],
#  [89.5, 16.7, 'Lärarrum'],
#  [50.2, 17.2, 'Lärarrum'],
#  [78.9, 22.0, 'Lärarrum'],
#  [45.6, 15.8, 'Kylrum'],
#  [35.2, 15.1, 'Kylrum'],
#  [69.8, 21.8, 'Lärarrum'],
#  [75.6, 18.4, 'Lärarrum'],
#  [89.4, 21.7, 'Lärarrum'],
#  [62.6, 21.6, 'Lärarrum'],
#  [69.7, 18.8, 'Lärarrum'],
#  [37.9, 10.1, 'Kylrum'],
#  [52.0, 15.8, 'Kylrum'],
#  [74.9, 19.2, 'Lärarrum'],
#  [76.2, 21.4, 'Lärarrum'],
#  [50.3, 17.7, 'Lärarrum'],
#  [29.1, 12.1, 'Kylrum'],
#  [55.2, 18.4, 'Lärarrum'],
#  [50.8, 18.3, 'Lärarrum'],
#  [77.5, 19.7, 'Lärarrum'],
#  [53.1, 13.1, 'Kylrum'],
#  [68.1, 16.8, 'Lärarrum'],
#  [88.5, 21.5, 'Klassrum'],
#  [92.6, 22.8, 'Klassrum'],
#  [57.5, 14.2, 'Kylrum'],
#  [99.5, 21.9, 'Klassrum'],
#  [96.1, 19.3, 'Klassrum'],
#  [82.2, 18.4, 'Lärarrum'],
#  [41.6, 14.3, 'Kylrum'],
#  [22.7, 13.5, 'Kylrum'],
#  [33.5, 11.1, 'Kylrum'],
#  [67.4, 19.2, 'Lärarrum'],
#  [78.5, 20.2, 'Lärarrum'],
#  [53.1, 17.5, 'Lärarrum'],
#  [42.1, 12.8, 'Kylrum'],
#  [51.4, 18.3, 'Lärarrum'],
#  [79.2, 21.9, 'Lärarrum'],
#  [64.3, 21.1, 'Lärarrum'],
#  [69.3, 21.3, 'Lärarrum'],
#  [88.1, 16.9, 'Lärarrum'],
#  [60.0, 16.0, 'Lärarrum'],
#  [21.2, 13.8, 'Kylrum'],
#  [35.2, 11.0, 'Kylrum'],
#  [86.2, 21.9, 'Klassrum'],
#  [78.1, 19.7, 'Lärarrum'],
#  [58.6, 18.7, 'Lärarrum'],
#  [72.3, 21.8, 'Lärarrum'],
#  [59.1, 14.7, 'Kylrum'],
#  [94.0, 21.2, 'Klassrum'],
#  [63.1, 19.8, 'Lärarrum'],
#  [59.7, 20.8, 'Lärarrum'],
#  [60.8, 20.1, 'Lärarrum'],
#  [72.6, 18.4, 'Lärarrum'],
#  [72.8, 20.1, 'Lärarrum'],
#  [56.6, 17.1, 'Lärarrum'],
#  [52.5, 16.5, 'Lärarrum'],
#  [65.5, 19.2, 'Lärarrum'],
#  [90.8, 22.4, 'Klassrum'],
#  [98.0, 19.5, 'Klassrum'],
#  [35.8, 13.7, 'Kylrum'],
#  [59.4, 16.7, 'Lärarrum'],
#  [61.7, 18.4, 'Lärarrum'],
#  [74.8, 18.5, 'Lärarrum'],
#  [16.0, 15.5, 'Kylrum'],
#  [19.2, 15.0, 'Kylrum'],
#  [16.0, 13.2, 'Kylrum'],
#  [55.2, 20.9, 'Lärarrum'],
#  [29.7, 10.5, 'Kylrum'],
#  [22.5, 13.7, 'Kylrum'],
#  [70.9, 20.3, 'Lärarrum'],
#  [92.5, 21.9, 'Klassrum'],
#  [57.1, 11.3, 'Kylrum'],
#  [76.2, 17.5, 'Lärarrum'],
#  [16.8, 11.1, 'Kylrum'],
#  [62.6, 16.8, 'Lärarrum'],
#  [52.4, 16.4, 'Lärarrum'],
#  [67.8, 16.3, 'Lärarrum'],
#  [61.1, 17.3, 'Lärarrum'],
#  [56.9, 15.6, 'Kylrum'],
#  [55.5, 12.5, 'Kylrum'],
#  [64.6, 20.9, 'Lärarrum'],
#  [87.9, 21.6, 'Lärarrum'],
#  [29.8, 11.3, 'Kylrum'],
#  [25.7, 13.8, 'Kylrum'],
#  [89.9, 18.3, 'Lärarrum'],
#  [42.2, 14.1, 'Kylrum'],
#  [67.4, 21.8, 'Lärarrum'],
#  [59.5, 19.4, 'Lärarrum'],
#  [50.0, 11.3, 'Kylrum'],
#  [80.1, 17.1, 'Lärarrum'],
#  [75.9, 16.6, 'Lärarrum'],
#  [40.7, 11.9, 'Kylrum'],
#  [82.1, 16.5, 'Lärarrum'],
#  [69.9, 20.7, 'Lärarrum'],
#  [61.0, 17.4, 'Lärarrum'],
#  [17.9, 14.3, 'Kylrum'],
#  [89.1, 23.8, 'Klassrum'],
#  [52.9, 13.4, 'Kylrum'],
#  [71.8, 21.8, 'Lärarrum'],
#  [40.1, 10.2, 'Kylrum'],
#  [51.5, 19.9, 'Lärarrum'],
#  [44.9, 12.5, 'Kylrum'],
#  [99.0, 19.5, 'Klassrum'],
#  [35.3, 15.1, 'Kylrum'],
#  [55.1, 18.3, 'Lärarrum'],
#  [41.3, 16.0, 'Kylrum'],
#  [86.1, 20.3, 'Klassrum'],
#  [22.8, 14.5, 'Kylrum'],
#  [28.0, 11.1, 'Kylrum'],
#  [81.6, 20.4, 'Klassrum'],
#  [57.7, 17.2, 'Lärarrum'],
#  [55.3, 16.5, 'Lärarrum'],
#  [66.0, 18.8, 'Lärarrum'],
#  [31.5, 10.5, 'Kylrum'],
#  [30.7, 15.1, 'Kylrum'],
#  [70.8, 18.1, 'Lärarrum'],
#  [62.7, 21.4, 'Lärarrum'],
#  [88.9, 20.9, 'Lärarrum'],
#  [74.8, 16.5, 'Lärarrum'],
#  [86.9, 19.6, 'Lärarrum'],
#  [22.0, 10.3, 'Kylrum'],
#  [28.3, 13.8, 'Kylrum'],
#  [89.8, 16.9, 'Lärarrum'],
#  [39.0, 11.2, 'Kylrum'],
#  [79.8, 19.7, 'Lärarrum'],
#  [26.1, 12.6, 'Kylrum'],
#  [62.4, 18.5, 'Lärarrum'],
#  [27.7, 14.1, 'Kylrum'],
#  [69.6, 19.7, 'Lärarrum'],
#  [88.7, 17.2, 'Lärarrum'],
#  [26.4, 13.0, 'Kylrum'],
#  [96.8, 22.9, 'Klassrum'],
#  [85.8, 16.3, 'Lärarrum'],
#  [50.3, 10.7, 'Kylrum'],
#  [57.7, 13.5, 'Kylrum'],
#  [16.4, 10.7, 'Kylrum'],
#  [54.2, 19.3, 'Lärarrum'],
#  [56.8, 16.4, 'Lärarrum'],
#  [54.4, 18.1, 'Lärarrum'],
#  [75.2, 17.9, 'Lärarrum'],
#  [86.2, 21.5, 'Lärarrum'],
#  [41.3, 15.8, 'Kylrum'],
#  [85.7, 21.5, 'Klassrum'],
#  [74.0, 16.4, 'Lärarrum'],
#  [99.3, 18.6, 'Klassrum'],
#  [79.5, 19.9, 'Lärarrum'],
#  [74.3, 19.4, 'Lärarrum'],
#  [62.0, 20.1, 'Lärarrum'],
#  [80.5, 21.0, 'Klassrum'],
#  [62.5, 16.0, 'Lärarrum'],
#  [19.4, 10.7, 'Kylrum'],
#  [95.8, 20.8, 'Klassrum'],
#  [58.8, 12.9, 'Kylrum'],
#  [95.1, 22.1, 'Klassrum'],
#  [39.3, 14.6, 'Kylrum'],
#  [86.7, 18.2, 'Lärarrum'],
#  [72.0, 20.4, 'Lärarrum'],
#  [74.9, 18.9, 'Lärarrum'],
#  [88.7, 20.2, 'Lärarrum'],
#  [34.2, 15.0, 'Kylrum'],
#  [41.2, 11.9, 'Kylrum'],
#  [56.6, 18.5, 'Lärarrum'],
#  [81.1, 23.6, 'Klassrum'],
#  [54.1, 13.6, 'Kylrum'],
#  [85.0, 21.4, 'Klassrum'],
#  [89.5, 16.5, 'Lärarrum'],
#  [30.4, 11.7, 'Kylrum'],
#  [33.1, 15.6, 'Kylrum'],
#  [33.9, 13.7, 'Kylrum'],
#  [36.9, 13.0, 'Kylrum'],
#  [98.5, 18.4, 'Klassrum'],
#  [54.1, 16.2, 'Lärarrum'],
#  [63.3, 16.6, 'Lärarrum'],
#  [36.4, 14.4, 'Kylrum'],
#  [70.6, 21.7, 'Lärarrum'],
#  [54.3, 16.3, 'Lärarrum'],
#  [77.1, 18.5, 'Lärarrum'],
#  [57.8, 11.1, 'Kylrum'],
#  [76.9, 17.7, 'Lärarrum'],
#  [53.9, 13.8, 'Kylrum'],
#  [55.9, 16.5, 'Lärarrum'],
#  [56.3, 19.3, 'Lärarrum'],
#  [56.8, 18.5, 'Lärarrum'],
#  [74.6, 20.5, 'Lärarrum'],
#  [36.9, 11.8, 'Kylrum'],
#  [87.1, 19.2, 'Lärarrum'],
#  [69.9, 17.4, 'Lärarrum'],
#  [40.2, 14.3, 'Kylrum'],
#  [40.0, 11.3, 'Kylrum'],
#  [84.7, 20.2, 'Lärarrum'],
#  [50.6, 18.9, 'Lärarrum'],
#  [63.8, 17.5, 'Lärarrum'],
#  [59.2, 20.8, 'Lärarrum'],
#  [52.4, 19.3, 'Lärarrum'],
#  [56.3, 21.9, 'Lärarrum'],
#  [63.3, 17.9, 'Lärarrum'],
#  [23.2, 12.5, 'Kylrum'],
#  [54.3, 16.1, 'Lärarrum'],
#  [78.7, 18.9, 'Lärarrum'],
#  [59.6, 15.6, 'Kylrum'],
#  [75.8, 18.1, 'Lärarrum'],
#  [59.6, 21.3, 'Lärarrum'],
#  [25.7, 12.2, 'Kylrum'],
#  [89.6, 16.3, 'Lärarrum'],
#  [54.7, 10.1, 'Kylrum'],
#  [52.9, 20.5, 'Lärarrum'],
#  [82.8, 20.1, 'Lärarrum'],
#  [44.9, 15.8, 'Kylrum'],
#  [83.5, 22.9, 'Klassrum'],
#  [84.6, 21.1, 'Klassrum'],
#  [54.5, 14.0, 'Kylrum'],
#  [52.5, 21.0, 'Lärarrum'],
#  [54.8, 19.4, 'Lärarrum'],
#  [81.0, 22.0, 'Lärarrum'],
#  [69.0, 17.0, 'Lärarrum'],
#  [96.2, 24.0, 'Klassrum'],
#  [91.4, 22.1, 'Klassrum'],
#  [57.1, 16.6, 'Lärarrum'],
#  [71.4, 19.5, 'Lärarrum'],
#  [29.0, 14.4, 'Kylrum'],
#  [93.4, 23.2, 'Klassrum'],
#  [47.3, 11.1, 'Kylrum'],
#  [69.1, 22.0, 'Lärarrum'],
#  [83.3, 19.0, 'Lärarrum'],
#  [44.3, 14.7, 'Kylrum'],
#  [22.4, 15.1, 'Kylrum'],
#  [72.0, 21.5, 'Lärarrum'],
#  [87.1, 20.9, 'Klassrum'],
#  [25.1, 10.3, 'Kylrum'],
#  [58.8, 20.7, 'Lärarrum'],
#  [99.6, 22.2, 'Klassrum'],
#  [68.7, 20.8, 'Lärarrum'],
#  [74.8, 20.8, 'Lärarrum'],
#  [83.0, 18.8, 'Lärarrum'],
#  [65.3, 17.4, 'Lärarrum'],
#  [22.6, 12.1, 'Kylrum'],
#  [78.2, 16.9, 'Lärarrum'],
#  [62.6, 20.4, 'Lärarrum'],
#  [37.0, 11.5, 'Kylrum'],
#  [84.0, 23.0, 'Klassrum'],
#  [60.1, 21.9, 'Lärarrum'],
#  [39.0, 10.4, 'Kylrum'],
#  [58.2, 16.1, 'Lärarrum'],
#  [70.8, 16.7, 'Lärarrum'],
#  [62.8, 20.1, 'Lärarrum'],
#  [52.7, 19.2, 'Lärarrum'],
#  [80.7, 21.1, 'Lärarrum'],
#  [31.7, 12.5, 'Kylrum'],
#  [58.2, 12.3, 'Kylrum'],
#  [80.7, 18.6, 'Lärarrum'],
#  [52.0, 10.6, 'Kylrum'],
#  [87.9, 17.8, 'Lärarrum'],
#  [63.0, 18.5, 'Lärarrum'],
#  [17.3, 15.3, 'Kylrum'],
#  [63.1, 20.8, 'Lärarrum'],
#  [98.3, 19.4, 'Klassrum'],
#  [55.0, 17.1, 'Lärarrum'],
#  [54.1, 11.1, 'Kylrum'],
#  [56.3, 20.3, 'Lärarrum'],
#  [71.5, 17.5, 'Lärarrum'],
#  [85.2, 18.9, 'Lärarrum'],
#  [95.1, 19.8, 'Klassrum'],
#  [76.4, 16.6, 'Lärarrum'],
#  [38.9, 15.1, 'Kylrum'],
#  [73.0, 19.9, 'Lärarrum'],
#  [83.5, 19.0, 'Lärarrum'],
#  [92.9, 21.9, 'Klassrum'],
#  [58.4, 18.7, 'Lärarrum'],
#  [81.7, 21.7, 'Lärarrum'],
#  [33.4, 10.8, 'Kylrum'],
#  [55.0, 20.2, 'Lärarrum'],
#  [79.4, 16.5, 'Lärarrum'],
#  [25.0, 14.5, 'Kylrum'],
#  [55.7, 19.2, 'Lärarrum'],
#  [68.5, 21.1, 'Lärarrum'],
#  [59.1, 11.3, 'Kylrum'],
#  [90.9, 23.8, 'Klassrum'],
#  [86.3, 17.1, 'Lärarrum'],
#  [72.2, 21.7, 'Lärarrum'],
#  [56.3, 16.0, 'Lärarrum'],
#  [33.0, 12.7, 'Kylrum'],
#  [36.2, 13.8, 'Kylrum'],
#  [94.8, 21.6, 'Klassrum'],
#  [66.1, 20.1, 'Lärarrum'],
#  [83.9, 21.8, 'Lärarrum'],
#  [80.5, 21.3, 'Lärarrum'],
#  [65.7, 20.3, 'Lärarrum'],
#  [94.0, 23.2, 'Klassrum'],
#  [80.7, 22.8, 'Klassrum'],
#  [65.2, 19.2, 'Lärarrum'],
#  [96.1, 21.9, 'Klassrum'],
#  [71.7, 18.4, 'Lärarrum'],
#  [55.9, 15.3, 'Kylrum'],
#  [69.1, 21.2, 'Lärarrum'],
#  [52.3, 19.8, 'Lärarrum'],
#  [75.5, 18.3, 'Lärarrum'],
#  [42.5, 13.6, 'Kylrum'],
#  [55.9, 12.7, 'Kylrum'],
#  [76.8, 21.3, 'Lärarrum'],
#  [86.7, 22.7, 'Klassrum'],
#  [69.4, 20.4, 'Lärarrum'],
#  [51.8, 19.4, 'Lärarrum'],
#  [99.9, 21.0, 'Klassrum'],
#  [54.1, 18.4, 'Lärarrum'],
#  [53.7, 21.3, 'Lärarrum'],
#  [50.1, 11.5, 'Kylrum'],
#  [79.4, 19.7, 'Lärarrum'],
#  [83.1, 21.9, 'Klassrum'],
#  [46.8, 10.8, 'Kylrum'],
#  [85.3, 17.3, 'Lärarrum'],
#  [59.9, 18.9, 'Lärarrum'],
#  [53.0, 18.1, 'Lärarrum'],
#  [87.3, 19.3, 'Lärarrum'],
#  [30.0, 10.3, 'Kylrum'],
#  [53.2, 12.4, 'Kylrum'],
#  [56.1, 17.0, 'Lärarrum'],
#  [61.0, 17.9, 'Lärarrum'],
#  [43.1, 14.5, 'Kylrum'],
#  [53.9, 18.0, 'Lärarrum'],
#  [81.1, 18.2, 'Lärarrum'],
#  [89.7, 17.6, 'Lärarrum'],
#  [55.0, 14.4, 'Kylrum'],
#  [51.7, 18.0, 'Lärarrum'],
#  [85.5, 17.5, 'Lärarrum'],
#  [79.7, 21.9, 'Lärarrum'],
#  [53.5, 17.5, 'Lärarrum'],
#  [93.5, 20.1, 'Klassrum'],
#  [88.3, 16.2, 'Lärarrum'],
#  [67.6, 17.4, 'Lärarrum'],
#  [79.8, 20.6, 'Lärarrum'],
#  [51.7, 19.2, 'Lärarrum'],
#  [33.0, 12.4, 'Kylrum'],
#  [98.3, 20.4, 'Klassrum'],
#  [23.1, 15.4, 'Kylrum'],
#  [86.4, 21.5, 'Lärarrum'],
#  [59.9, 18.8, 'Lärarrum'],
#  [17.3, 13.6, 'Kylrum'],
#  [85.5, 22.8, 'Klassrum'],
#  [55.6, 15.6, 'Kylrum'],
#  [73.4, 18.9, 'Lärarrum'],
#  [65.5, 21.2, 'Lärarrum'],
#  [82.2, 16.5, 'Lärarrum'],
#  [53.4, 17.6, 'Lärarrum'],
#  [96.2, 18.4, 'Klassrum'],
#  [49.0, 14.4, 'Kylrum'],
#  [93.6, 23.1, 'Klassrum'],
#  [82.3, 23.1, 'Klassrum'],
#  [85.6, 21.5, 'Lärarrum'],
#  [40.4, 14.9, 'Kylrum'],
#  [99.1, 20.3, 'Klassrum'],
#  [84.5, 17.1, 'Lärarrum'],
#  [56.4, 10.7, 'Kylrum'],
#  [83.4, 19.4, 'Klassrum'],
#  [80.5, 20.5, 'Lärarrum'],
#  [17.5, 15.3, 'Kylrum'],
#  [82.9, 19.0, 'Lärarrum'],
#  [63.5, 19.1, 'Lärarrum'],
#  [33.5, 15.5, 'Kylrum'],
#  [34.2, 13.0, 'Kylrum'],
#  [42.1, 10.3, 'Kylrum'],
#  [89.2, 18.6, 'Klassrum'],
#  [88.5, 21.9, 'Lärarrum'],
#  [57.0, 12.8, 'Kylrum'],
#  [77.9, 18.5, 'Lärarrum'],
#  [89.9, 18.9, 'Klassrum'],
#  [53.1, 21.5, 'Lärarrum'],
#  ...]

# %%
#######
# Demo:
class_counts(training_data)
#######
# Out:
# {'Lärarrum': 1109, 'Klassrum': 301, 'Kylrum': 593}

# %%
def is_numeric(value):
    """Test if a value is numeric."""
    return isinstance(value, int) or isinstance(value, float)

# %%
#######
# Demo:
is_numeric(7)
# is_numeric("Red")
#######
# Out:
# True

# %%
class Question:
    """A Question is used to partition a dataset.

    This class just records a 'column number' (e.g., 0 for Color) and a
    'column value' (e.g., Green). The 'match' method is used to compare
    the feature value in an example to the feature value stored in the
    question. See the demo below.
    """

    def __init__(self, column, value, less, eq):
        self.column = column
        self.value  = value
        self.less   = less
        self.eq     = eq

    def match(self, example):
        # Compare the feature value in an example to the
        # feature value in this question.
        val = example[self.column]
        if is_numeric(val):
            return val >= self.value
        else:
            return val == self.value
    def moreless(self, example):
        # Compare the feature value in an example to the
        # feature value in this question.
        val = example[self.column]
        if self.less:
            if self.eq:
                return val <= self.value
            else:
                return val < self.value
        elif is_numeric(self.value):
            if self.eq:
                return val >= self.value
            else:
                return val > self.value
        else:
            return val == self.value

    def __repr__(self):
        # This is just a helper method to print
        # the question in a readable format.
        condition = "=="
        if self.less:
            if self.eq:
                condition = "<="
            else:
                condition = "<"
        elif is_numeric(self.value):
            if self.eq:
                condition = ">="
            else:
                condition = ">"
        return "Är %s %s %s?" % (
            header[self.column], condition, str(self.value))

# %%
#######
# Demo:
# Let's write a question for a numeric attribute
Question(1, 19.5, 1, 0)
# Out:
# Är temperatur < 19.5?

# %%
# How about one for a categorical attribute
q = Question(0, 50, 1, 0)
q
# Out:
# Är luftfuktighet < 50?

# %%
# Let's pick an example from the training set...
example = training_data[0]
# ... and see if it matches the question
q.moreless(example) # this will be true, since the first example is Green.
#######
# Out:
# False

# %%
def partition(rows, question):
    """Partitions a dataset.

    For each row in the dataset, check if it matches the question. If
    so, add it to 'true rows', otherwise, add it to 'false rows'.
    """
    true_rows, false_rows = [], []
    for row in rows:
        if question.moreless(row):
            true_rows.append(row)
        else:
            false_rows.append(row)
    return true_rows, false_rows

# %%
#######
# Demo:
# Let's partition the training data based on whether rows are Red.
true_rows, false_rows = partition(training_data, Question(1, 19.5, 1, 0))
# This will contain all the 'Red' rows.
true_rows
# Out:
# [[43.8, 11.3, 'Kylrum'],
#  [71.6, 19.2, 'Lärarrum'],
#  [72.2, 16.2, 'Lärarrum'],
#  [38.7, 13.1, 'Kylrum'],
#  [63.6, 17.7, 'Lärarrum'],
#  [39.2, 15.1, 'Kylrum'],
#  [38.8, 15.8, 'Kylrum'],
#  [48.0, 11.0, 'Kylrum'],
#  [41.6, 13.7, 'Kylrum'],
#  [98.5, 19.3, 'Klassrum'],
#  [50.6, 17.1, 'Lärarrum'],
#  [24.4, 11.1, 'Kylrum'],
#  [78.8, 16.7, 'Lärarrum'],
#  [64.2, 17.7, 'Lärarrum'],
#  [76.9, 17.3, 'Lärarrum'],
#  [75.6, 16.7, 'Lärarrum'],
#  [88.1, 18.8, 'Lärarrum'],
#  [52.4, 17.7, 'Lärarrum'],
#  [93.9, 18.2, 'Klassrum'],
#  [51.8, 14.9, 'Kylrum'],
#  [50.9, 15.6, 'Kylrum'],
#  [80.0, 16.7, 'Lärarrum'],
#  [56.8, 19.3, 'Lärarrum'],
#  [57.1, 19.3, 'Lärarrum'],
#  [88.3, 16.3, 'Lärarrum'],
#  [48.7, 12.9, 'Kylrum'],
#  [45.2, 12.3, 'Kylrum'],
#  [81.0, 16.9, 'Lärarrum'],
#  [50.4, 15.4, 'Kylrum'],
#  [29.3, 14.4, 'Kylrum'],
#  [81.4, 18.8, 'Lärarrum'],
#  [38.9, 15.2, 'Kylrum'],
#  [59.9, 19.3, 'Lärarrum'],
#  [76.4, 17.1, 'Lärarrum'],
#  [50.4, 19.3, 'Lärarrum'],
#  [89.7, 18.6, 'Klassrum'],
#  [29.8, 13.0, 'Kylrum'],
#  [59.2, 16.7, 'Lärarrum'],
#  [29.3, 14.6, 'Kylrum'],
#  [73.2, 18.2, 'Lärarrum'],
#  [88.7, 16.7, 'Lärarrum'],
#  [80.7, 16.2, 'Lärarrum'],
#  [66.7, 18.4, 'Lärarrum'],
#  [47.9, 15.1, 'Kylrum'],
#  [42.4, 11.6, 'Kylrum'],
#  [21.6, 12.0, 'Kylrum'],
#  [87.1, 17.1, 'Lärarrum'],
#  [62.2, 18.3, 'Lärarrum'],
#  [84.9, 16.9, 'Lärarrum'],
#  [86.2, 18.7, 'Klassrum'],
#  [79.5, 17.6, 'Lärarrum'],
#  [25.0, 14.5, 'Kylrum'],
#  [75.5, 17.2, 'Lärarrum'],
#  [30.0, 15.6, 'Kylrum'],
#  [67.9, 17.8, 'Lärarrum'],
#  [20.9, 10.2, 'Kylrum'],
#  [32.1, 14.9, 'Kylrum'],
#  [61.2, 16.1, 'Lärarrum'],
#  [30.9, 12.5, 'Kylrum'],
#  [51.2, 15.6, 'Kylrum'],
#  [26.5, 10.7, 'Kylrum'],
#  [35.6, 10.3, 'Kylrum'],
#  [49.4, 10.9, 'Kylrum'],
#  [19.1, 11.6, 'Kylrum'],
#  [62.2, 16.6, 'Lärarrum'],
#  [76.0, 16.0, 'Lärarrum'],
#  [59.3, 18.7, 'Lärarrum'],
#  [54.0, 16.9, 'Lärarrum'],
#  [21.6, 15.8, 'Kylrum'],
#  [29.0, 14.4, 'Kylrum'],
#  [79.3, 19.2, 'Lärarrum'],
#  [72.9, 17.9, 'Lärarrum'],
#  [27.9, 15.9, 'Kylrum'],
#  [53.0, 11.8, 'Kylrum'],
#  [81.8, 18.7, 'Lärarrum'],
#  [55.5, 13.0, 'Kylrum'],
#  [35.2, 14.7, 'Kylrum'],
#  [26.2, 12.1, 'Kylrum'],
#  [51.2, 18.7, 'Lärarrum'],
#  [24.4, 14.7, 'Kylrum'],
#  [26.7, 11.4, 'Kylrum'],
#  [96.4, 19.2, 'Klassrum'],
#  [30.3, 15.9, 'Kylrum'],
#  [15.8, 15.9, 'Kylrum'],
#  [85.8, 18.3, 'Lärarrum'],
#  [27.9, 15.3, 'Kylrum'],
#  [56.2, 15.9, 'Kylrum'],
#  [40.6, 15.4, 'Kylrum'],
#  [54.1, 16.2, 'Lärarrum'],
#  [51.9, 18.6, 'Lärarrum'],
#  [73.5, 18.0, 'Lärarrum'],
#  [54.1, 12.8, 'Kylrum'],
#  [36.7, 15.6, 'Kylrum'],
#  [57.1, 18.6, 'Lärarrum'],
#  [89.8, 19.3, 'Lärarrum'],
#  [50.5, 11.6, 'Kylrum'],
#  [77.3, 16.8, 'Lärarrum'],
#  [82.8, 16.9, 'Lärarrum'],
#  [82.6, 18.1, 'Klassrum'],
#  [78.3, 16.7, 'Lärarrum'],
#  [69.7, 16.2, 'Lärarrum'],
#  [74.3, 18.7, 'Lärarrum'],
#  [86.6, 19.0, 'Klassrum'],
#  [80.5, 18.0, 'Lärarrum'],
#  [63.9, 16.8, 'Lärarrum'],
#  [72.9, 17.0, 'Lärarrum'],
#  [64.1, 16.8, 'Lärarrum'],
#  [74.7, 16.4, 'Lärarrum'],
#  [54.3, 19.2, 'Lärarrum'],
#  [65.3, 17.9, 'Lärarrum'],
#  [49.6, 13.5, 'Kylrum'],
#  [50.9, 19.3, 'Lärarrum'],
#  [45.4, 12.3, 'Kylrum'],
#  [78.5, 16.1, 'Lärarrum'],
#  [41.6, 15.0, 'Kylrum'],
#  [87.0, 18.2, 'Klassrum'],
#  [71.1, 16.4, 'Lärarrum'],
#  [89.1, 18.9, 'Lärarrum'],
#  [69.8, 16.2, 'Lärarrum'],
#  [18.6, 12.3, 'Kylrum'],
#  [51.0, 18.6, 'Lärarrum'],
#  [88.6, 18.8, 'Lärarrum'],
#  [51.7, 16.8, 'Lärarrum'],
#  [75.4, 19.2, 'Lärarrum'],
#  [54.1, 18.3, 'Lärarrum'],
#  [68.0, 17.7, 'Lärarrum'],
#  [81.0, 18.0, 'Klassrum'],
#  [17.2, 14.5, 'Kylrum'],
#  [37.5, 13.7, 'Kylrum'],
#  [79.7, 18.8, 'Lärarrum'],
#  [23.6, 12.9, 'Kylrum'],
#  [79.4, 17.4, 'Lärarrum'],
#  [22.1, 15.7, 'Kylrum'],
#  [29.6, 13.0, 'Kylrum'],
#  [40.9, 10.7, 'Kylrum'],
#  [47.1, 13.7, 'Kylrum'],
#  [77.2, 16.1, 'Lärarrum'],
#  [16.1, 10.3, 'Kylrum'],
#  [43.2, 10.7, 'Kylrum'],
#  [73.8, 18.4, 'Lärarrum'],
#  [22.9, 13.0, 'Kylrum'],
#  [31.7, 14.1, 'Kylrum'],
#  [52.1, 17.9, 'Lärarrum'],
#  [86.3, 18.0, 'Lärarrum'],
#  [82.3, 16.9, 'Lärarrum'],
#  [19.4, 12.9, 'Kylrum'],
#  [83.1, 18.2, 'Klassrum'],
#  [55.9, 19.1, 'Lärarrum'],
#  [43.5, 13.1, 'Kylrum'],
#  [72.5, 18.3, 'Lärarrum'],
#  [83.1, 16.8, 'Lärarrum'],
#  [81.1, 19.3, 'Klassrum'],
#  [70.0, 17.7, 'Lärarrum'],
#  [43.3, 13.2, 'Kylrum'],
#  [37.9, 12.1, 'Kylrum'],
#  [71.3, 18.4, 'Lärarrum'],
#  [76.9, 18.8, 'Lärarrum'],
#  [45.5, 13.9, 'Kylrum'],
#  [79.1, 16.7, 'Lärarrum'],
#  [50.4, 17.2, 'Lärarrum'],
#  [52.7, 16.0, 'Kylrum'],
#  [44.2, 12.2, 'Kylrum'],
#  [33.8, 13.0, 'Kylrum'],
#  [40.4, 11.9, 'Kylrum'],
#  [47.0, 14.6, 'Kylrum'],
#  [37.6, 14.4, 'Kylrum'],
#  [27.4, 13.7, 'Kylrum'],
#  [42.0, 11.8, 'Kylrum'],
#  [25.4, 15.8, 'Kylrum'],
#  [84.1, 17.1, 'Lärarrum'],
#  [45.1, 10.5, 'Kylrum'],
#  [29.8, 15.7, 'Kylrum'],
#  [73.7, 18.4, 'Lärarrum'],
#  [87.7, 17.8, 'Lärarrum'],
#  [38.5, 15.0, 'Kylrum'],
#  [48.7, 12.5, 'Kylrum'],
#  [74.3, 18.6, 'Lärarrum'],
#  [24.3, 15.5, 'Kylrum'],
#  [24.3, 11.7, 'Kylrum'],
#  [74.6, 18.0, 'Lärarrum'],
#  [82.7, 18.1, 'Lärarrum'],
#  [56.7, 17.9, 'Lärarrum'],
#  [60.0, 10.3, 'Kylrum'],
#  [86.9, 16.1, 'Lärarrum'],
#  [31.2, 15.1, 'Kylrum'],
#  [59.8, 17.3, 'Lärarrum'],
#  [47.2, 11.6, 'Kylrum'],
#  [50.9, 17.4, 'Lärarrum'],
#  [33.7, 15.0, 'Kylrum'],
#  [57.6, 17.8, 'Lärarrum'],
#  [54.8, 10.3, 'Kylrum'],
#  [52.5, 17.7, 'Lärarrum'],
#  [44.5, 15.4, 'Kylrum'],
#  [54.1, 14.4, 'Kylrum'],
#  [29.8, 11.7, 'Kylrum'],
#  [52.3, 11.9, 'Kylrum'],
#  [48.2, 11.4, 'Kylrum'],
#  [33.7, 11.0, 'Kylrum'],
#  [66.2, 19.1, 'Lärarrum'],
#  [24.8, 10.4, 'Kylrum'],
#  [23.8, 13.7, 'Kylrum'],
#  [86.7, 16.9, 'Lärarrum'],
#  [48.8, 10.9, 'Kylrum'],
#  [74.3, 16.4, 'Lärarrum'],
#  [44.7, 15.3, 'Kylrum'],
#  [55.1, 18.7, 'Lärarrum'],
#  [80.3, 19.0, 'Lärarrum'],
#  [45.7, 13.5, 'Kylrum'],
#  [60.5, 17.0, 'Lärarrum'],
#  [55.6, 17.1, 'Lärarrum'],
#  [84.0, 18.0, 'Lärarrum'],
#  [60.5, 17.2, 'Lärarrum'],
#  [85.1, 16.8, 'Lärarrum'],
#  [84.6, 17.9, 'Lärarrum'],
#  [56.3, 13.9, 'Kylrum'],
#  [65.3, 16.5, 'Lärarrum'],
#  [53.1, 16.8, 'Lärarrum'],
#  [28.4, 13.9, 'Kylrum'],
#  [26.4, 15.6, 'Kylrum'],
#  [52.4, 14.4, 'Kylrum'],
#  [20.4, 13.2, 'Kylrum'],
#  [93.2, 18.7, 'Klassrum'],
#  [31.5, 10.6, 'Kylrum'],
#  [55.9, 18.7, 'Lärarrum'],
#  [63.7, 19.1, 'Lärarrum'],
#  [23.6, 12.7, 'Kylrum'],
#  [35.3, 14.8, 'Kylrum'],
#  [70.7, 18.9, 'Lärarrum'],
#  [91.7, 18.9, 'Klassrum'],
#  [97.5, 18.7, 'Klassrum'],
#  [89.8, 19.1, 'Lärarrum'],
#  [56.8, 10.5, 'Kylrum'],
#  [61.6, 16.5, 'Lärarrum'],
#  [93.5, 18.2, 'Klassrum'],
#  [99.5, 19.1, 'Klassrum'],
#  [27.6, 12.4, 'Kylrum'],
#  [41.8, 12.0, 'Kylrum'],
#  [26.3, 15.4, 'Kylrum'],
#  [81.9, 18.0, 'Lärarrum'],
#  [32.4, 11.4, 'Kylrum'],
#  [36.4, 13.6, 'Kylrum'],
#  [25.9, 13.9, 'Kylrum'],
#  [98.8, 18.8, 'Klassrum'],
#  [80.3, 19.0, 'Klassrum'],
#  [25.5, 14.6, 'Kylrum'],
#  [51.2, 11.6, 'Kylrum'],
#  [84.2, 18.5, 'Klassrum'],
#  [76.9, 17.9, 'Lärarrum'],
#  [54.0, 16.7, 'Lärarrum'],
#  [39.5, 13.2, 'Kylrum'],
#  [26.8, 12.6, 'Kylrum'],
#  [16.9, 15.2, 'Kylrum'],
#  [97.3, 18.6, 'Klassrum'],
#  [55.8, 18.9, 'Lärarrum'],
#  [58.2, 17.0, 'Lärarrum'],
#  [44.6, 15.2, 'Kylrum'],
#  [32.4, 12.1, 'Kylrum'],
#  [33.8, 11.1, 'Kylrum'],
#  [89.3, 17.4, 'Lärarrum'],
#  [63.9, 19.1, 'Lärarrum'],
#  [27.4, 15.2, 'Kylrum'],
#  [27.6, 14.6, 'Kylrum'],
#  [38.1, 10.3, 'Kylrum'],
#  [23.8, 13.8, 'Kylrum'],
#  [86.3, 17.8, 'Lärarrum'],
#  [53.7, 18.9, 'Lärarrum'],
#  [67.3, 17.1, 'Lärarrum'],
#  [34.7, 10.0, 'Kylrum'],
#  [78.5, 18.3, 'Lärarrum'],
#  [55.2, 16.8, 'Lärarrum'],
#  [80.4, 18.5, 'Lärarrum'],
#  [79.5, 17.0, 'Lärarrum'],
#  [67.3, 17.2, 'Lärarrum'],
#  [50.8, 17.2, 'Lärarrum'],
#  [58.1, 17.8, 'Lärarrum'],
#  [26.3, 11.6, 'Kylrum'],
#  [23.3, 12.0, 'Kylrum'],
#  [57.6, 12.3, 'Kylrum'],
#  [81.2, 16.3, 'Lärarrum'],
#  [43.4, 10.1, 'Kylrum'],
#  [52.7, 12.0, 'Kylrum'],
#  [19.9, 11.4, 'Kylrum'],
#  [83.4, 18.1, 'Lärarrum'],
#  [73.7, 16.9, 'Lärarrum'],
#  [49.4, 12.4, 'Kylrum'],
#  [31.0, 11.0, 'Kylrum'],
#  [20.9, 10.5, 'Kylrum'],
#  [58.9, 18.8, 'Lärarrum'],
#  [65.0, 18.7, 'Lärarrum'],
#  [71.0, 19.3, 'Lärarrum'],
#  [86.6, 17.9, 'Lärarrum'],
#  [74.7, 18.9, 'Lärarrum'],
#  [55.4, 16.6, 'Lärarrum'],
#  [96.5, 18.4, 'Klassrum'],
#  [59.7, 10.5, 'Kylrum'],
#  [89.5, 18.2, 'Klassrum'],
#  [66.7, 16.8, 'Lärarrum'],
#  [57.8, 16.4, 'Lärarrum'],
#  [54.4, 11.9, 'Kylrum'],
#  [64.9, 17.7, 'Lärarrum'],
#  [30.4, 15.7, 'Kylrum'],
#  [52.1, 15.0, 'Kylrum'],
#  [69.7, 19.1, 'Lärarrum'],
#  [23.6, 14.5, 'Kylrum'],
#  [29.7, 11.6, 'Kylrum'],
#  [58.8, 17.9, 'Lärarrum'],
#  [35.7, 16.0, 'Kylrum'],
#  [90.5, 18.5, 'Klassrum'],
#  [21.6, 14.8, 'Kylrum'],
#  [50.8, 18.2, 'Lärarrum'],
#  [55.2, 14.6, 'Kylrum'],
#  [71.0, 18.9, 'Lärarrum'],
#  [68.0, 18.6, 'Lärarrum'],
#  [53.0, 12.3, 'Kylrum'],
#  [86.4, 16.3, 'Lärarrum'],
#  [55.9, 16.9, 'Lärarrum'],
#  [87.4, 16.6, 'Lärarrum'],
#  [51.1, 15.6, 'Kylrum'],
#  [51.9, 18.3, 'Lärarrum'],
#  [62.8, 18.8, 'Lärarrum'],
#  [54.2, 17.4, 'Lärarrum'],
#  [42.7, 11.2, 'Kylrum'],
#  [55.9, 16.3, 'Lärarrum'],
#  [70.1, 16.6, 'Lärarrum'],
#  [53.9, 13.7, 'Kylrum'],
#  [27.1, 10.5, 'Kylrum'],
#  [52.0, 16.8, 'Lärarrum'],
#  [31.4, 12.6, 'Kylrum'],
#  [83.1, 19.0, 'Lärarrum'],
#  [36.2, 14.3, 'Kylrum'],
#  [32.1, 13.1, 'Kylrum'],
#  [82.5, 19.0, 'Lärarrum'],
#  [47.2, 10.5, 'Kylrum'],
#  [73.5, 17.8, 'Lärarrum'],
#  [63.1, 17.1, 'Lärarrum'],
#  [21.1, 12.5, 'Kylrum'],
#  [80.6, 16.5, 'Lärarrum'],
#  [65.9, 16.9, 'Lärarrum'],
#  [73.9, 16.2, 'Lärarrum'],
#  [48.5, 11.7, 'Kylrum'],
#  [22.5, 10.7, 'Kylrum'],
#  [30.5, 15.9, 'Kylrum'],
#  [53.9, 15.5, 'Kylrum'],
#  [59.8, 10.8, 'Kylrum'],
#  [56.0, 19.0, 'Lärarrum'],
#  [66.3, 18.9, 'Lärarrum'],
#  [17.3, 10.7, 'Kylrum'],
#  [30.0, 13.2, 'Kylrum'],
#  [35.2, 14.9, 'Kylrum'],
#  [40.6, 12.5, 'Kylrum'],
#  [57.2, 15.7, 'Kylrum'],
#  [30.3, 15.2, 'Kylrum'],
#  [87.4, 18.4, 'Klassrum'],
#  [24.9, 10.8, 'Kylrum'],
#  [62.8, 17.0, 'Lärarrum'],
#  [80.0, 17.0, 'Lärarrum'],
#  [15.6, 10.8, 'Kylrum'],
#  [68.4, 19.4, 'Lärarrum'],
#  [55.4, 12.5, 'Kylrum'],
#  [80.2, 19.2, 'Klassrum'],
#  [73.8, 18.3, 'Lärarrum'],
#  [33.4, 10.6, 'Kylrum'],
#  [80.3, 16.5, 'Lärarrum'],
#  [57.1, 18.8, 'Lärarrum'],
#  [28.4, 14.2, 'Kylrum'],
#  [59.1, 14.8, 'Kylrum'],
#  [42.5, 11.8, 'Kylrum'],
#  [43.3, 12.9, 'Kylrum'],
#  [65.1, 17.0, 'Lärarrum'],
#  [83.0, 19.0, 'Lärarrum'],
#  [20.6, 10.4, 'Kylrum'],
#  [59.8, 18.6, 'Lärarrum'],
#  [85.7, 16.9, 'Lärarrum'],
#  [66.6, 18.6, 'Lärarrum'],
#  [72.8, 17.0, 'Lärarrum'],
#  [37.8, 13.6, 'Kylrum'],
#  [80.5, 18.0, 'Lärarrum'],
#  [74.7, 17.4, 'Lärarrum'],
#  [88.3, 17.8, 'Lärarrum'],
#  [22.1, 15.6, 'Kylrum'],
#  [49.8, 14.5, 'Kylrum'],
#  [32.5, 16.0, 'Kylrum'],
#  [58.3, 15.4, 'Kylrum'],
#  [41.9, 12.0, 'Kylrum'],
#  [80.3, 18.7, 'Klassrum'],
#  [30.6, 15.4, 'Kylrum'],
#  [50.7, 11.7, 'Kylrum'],
#  [82.6, 16.3, 'Lärarrum'],
#  [48.5, 13.3, 'Kylrum'],
#  [30.2, 13.3, 'Kylrum'],
#  [56.2, 16.6, 'Lärarrum'],
#  [69.0, 16.4, 'Lärarrum'],
#  [79.1, 17.3, 'Lärarrum'],
#  [81.2, 16.8, 'Lärarrum'],
#  [60.9, 16.4, 'Lärarrum'],
#  [77.8, 16.4, 'Lärarrum'],
#  [35.6, 10.9, 'Kylrum'],
#  [24.6, 13.8, 'Kylrum'],
#  [72.3, 17.3, 'Lärarrum'],
#  [20.1, 16.0, 'Kylrum'],
#  [82.5, 17.9, 'Lärarrum'],
#  [26.6, 10.1, 'Kylrum'],
#  [86.7, 19.3, 'Lärarrum'],
#  [95.1, 18.1, 'Klassrum'],
#  [46.7, 13.7, 'Kylrum'],
#  [61.0, 17.7, 'Lärarrum'],
#  [86.0, 17.8, 'Lärarrum'],
#  [48.1, 14.7, 'Kylrum'],
#  [68.0, 16.1, 'Lärarrum'],
#  [39.1, 12.7, 'Kylrum'],
#  [88.3, 18.6, 'Lärarrum'],
#  [21.9, 11.0, 'Kylrum'],
#  [34.6, 11.4, 'Kylrum'],
#  [58.0, 17.7, 'Lärarrum'],
#  [57.5, 11.5, 'Kylrum'],
#  [63.1, 17.8, 'Lärarrum'],
#  [70.6, 18.5, 'Lärarrum'],
#  [35.4, 11.7, 'Kylrum'],
#  [77.2, 17.8, 'Lärarrum'],
#  [83.8, 19.0, 'Klassrum'],
#  [53.6, 18.4, 'Lärarrum'],
#  [51.4, 15.8, 'Kylrum'],
#  [59.3, 14.6, 'Kylrum'],
#  [89.5, 16.7, 'Lärarrum'],
#  [50.2, 17.2, 'Lärarrum'],
#  [45.6, 15.8, 'Kylrum'],
#  [35.2, 15.1, 'Kylrum'],
#  [75.6, 18.4, 'Lärarrum'],
#  [69.7, 18.8, 'Lärarrum'],
#  [37.9, 10.1, 'Kylrum'],
#  [52.0, 15.8, 'Kylrum'],
#  [74.9, 19.2, 'Lärarrum'],
#  [50.3, 17.7, 'Lärarrum'],
#  [29.1, 12.1, 'Kylrum'],
#  [55.2, 18.4, 'Lärarrum'],
#  [50.8, 18.3, 'Lärarrum'],
#  [53.1, 13.1, 'Kylrum'],
#  [68.1, 16.8, 'Lärarrum'],
#  [57.5, 14.2, 'Kylrum'],
#  [96.1, 19.3, 'Klassrum'],
#  [82.2, 18.4, 'Lärarrum'],
#  [41.6, 14.3, 'Kylrum'],
#  [22.7, 13.5, 'Kylrum'],
#  [33.5, 11.1, 'Kylrum'],
#  [67.4, 19.2, 'Lärarrum'],
#  [53.1, 17.5, 'Lärarrum'],
#  [42.1, 12.8, 'Kylrum'],
#  [51.4, 18.3, 'Lärarrum'],
#  [88.1, 16.9, 'Lärarrum'],
#  [60.0, 16.0, 'Lärarrum'],
#  [21.2, 13.8, 'Kylrum'],
#  [35.2, 11.0, 'Kylrum'],
#  [58.6, 18.7, 'Lärarrum'],
#  [59.1, 14.7, 'Kylrum'],
#  [72.6, 18.4, 'Lärarrum'],
#  [56.6, 17.1, 'Lärarrum'],
#  [52.5, 16.5, 'Lärarrum'],
#  [65.5, 19.2, 'Lärarrum'],
#  [35.8, 13.7, 'Kylrum'],
#  [59.4, 16.7, 'Lärarrum'],
#  [61.7, 18.4, 'Lärarrum'],
#  [74.8, 18.5, 'Lärarrum'],
#  [16.0, 15.5, 'Kylrum'],
#  [19.2, 15.0, 'Kylrum'],
#  [16.0, 13.2, 'Kylrum'],
#  [29.7, 10.5, 'Kylrum'],
#  [22.5, 13.7, 'Kylrum'],
#  [57.1, 11.3, 'Kylrum'],
#  [76.2, 17.5, 'Lärarrum'],
#  [16.8, 11.1, 'Kylrum'],
#  [62.6, 16.8, 'Lärarrum'],
#  [52.4, 16.4, 'Lärarrum'],
#  [67.8, 16.3, 'Lärarrum'],
#  [61.1, 17.3, 'Lärarrum'],
#  [56.9, 15.6, 'Kylrum'],
#  [55.5, 12.5, 'Kylrum'],
#  [29.8, 11.3, 'Kylrum'],
#  [25.7, 13.8, 'Kylrum'],
#  [89.9, 18.3, 'Lärarrum'],
#  [42.2, 14.1, 'Kylrum'],
#  [59.5, 19.4, 'Lärarrum'],
#  [50.0, 11.3, 'Kylrum'],
#  [80.1, 17.1, 'Lärarrum'],
#  [75.9, 16.6, 'Lärarrum'],
#  [40.7, 11.9, 'Kylrum'],
#  [82.1, 16.5, 'Lärarrum'],
#  [61.0, 17.4, 'Lärarrum'],
#  [17.9, 14.3, 'Kylrum'],
#  [52.9, 13.4, 'Kylrum'],
#  [40.1, 10.2, 'Kylrum'],
#  [44.9, 12.5, 'Kylrum'],
#  [35.3, 15.1, 'Kylrum'],
#  [55.1, 18.3, 'Lärarrum'],
#  [41.3, 16.0, 'Kylrum'],
#  [22.8, 14.5, 'Kylrum'],
#  [28.0, 11.1, 'Kylrum'],
#  [57.7, 17.2, 'Lärarrum'],
#  [55.3, 16.5, 'Lärarrum'],
#  [66.0, 18.8, 'Lärarrum'],
#  [31.5, 10.5, 'Kylrum'],
#  [30.7, 15.1, 'Kylrum'],
#  [70.8, 18.1, 'Lärarrum'],
#  [74.8, 16.5, 'Lärarrum'],
#  [22.0, 10.3, 'Kylrum'],
#  [28.3, 13.8, 'Kylrum'],
#  [89.8, 16.9, 'Lärarrum'],
#  [39.0, 11.2, 'Kylrum'],
#  [26.1, 12.6, 'Kylrum'],
#  [62.4, 18.5, 'Lärarrum'],
#  [27.7, 14.1, 'Kylrum'],
#  [88.7, 17.2, 'Lärarrum'],
#  [26.4, 13.0, 'Kylrum'],
#  [85.8, 16.3, 'Lärarrum'],
#  [50.3, 10.7, 'Kylrum'],
#  [57.7, 13.5, 'Kylrum'],
#  [16.4, 10.7, 'Kylrum'],
#  [54.2, 19.3, 'Lärarrum'],
#  [56.8, 16.4, 'Lärarrum'],
#  [54.4, 18.1, 'Lärarrum'],
#  [75.2, 17.9, 'Lärarrum'],
#  [41.3, 15.8, 'Kylrum'],
#  [74.0, 16.4, 'Lärarrum'],
#  [99.3, 18.6, 'Klassrum'],
#  [74.3, 19.4, 'Lärarrum'],
#  [62.5, 16.0, 'Lärarrum'],
#  [19.4, 10.7, 'Kylrum'],
#  [58.8, 12.9, 'Kylrum'],
#  [39.3, 14.6, 'Kylrum'],
#  [86.7, 18.2, 'Lärarrum'],
#  [74.9, 18.9, 'Lärarrum'],
#  [34.2, 15.0, 'Kylrum'],
#  [41.2, 11.9, 'Kylrum'],
#  [56.6, 18.5, 'Lärarrum'],
#  [54.1, 13.6, 'Kylrum'],
#  [89.5, 16.5, 'Lärarrum'],
#  [30.4, 11.7, 'Kylrum'],
#  [33.1, 15.6, 'Kylrum'],
#  [33.9, 13.7, 'Kylrum'],
#  [36.9, 13.0, 'Kylrum'],
#  [98.5, 18.4, 'Klassrum'],
#  [54.1, 16.2, 'Lärarrum'],
#  [63.3, 16.6, 'Lärarrum'],
#  [36.4, 14.4, 'Kylrum'],
#  [54.3, 16.3, 'Lärarrum'],
#  [77.1, 18.5, 'Lärarrum'],
#  [57.8, 11.1, 'Kylrum'],
#  [76.9, 17.7, 'Lärarrum'],
#  [53.9, 13.8, 'Kylrum'],
#  [55.9, 16.5, 'Lärarrum'],
#  [56.3, 19.3, 'Lärarrum'],
#  [56.8, 18.5, 'Lärarrum'],
#  [36.9, 11.8, 'Kylrum'],
#  [87.1, 19.2, 'Lärarrum'],
#  [69.9, 17.4, 'Lärarrum'],
#  [40.2, 14.3, 'Kylrum'],
#  [40.0, 11.3, 'Kylrum'],
#  [50.6, 18.9, 'Lärarrum'],
#  [63.8, 17.5, 'Lärarrum'],
#  [52.4, 19.3, 'Lärarrum'],
#  [63.3, 17.9, 'Lärarrum'],
#  [23.2, 12.5, 'Kylrum'],
#  [54.3, 16.1, 'Lärarrum'],
#  [78.7, 18.9, 'Lärarrum'],
#  [59.6, 15.6, 'Kylrum'],
#  [75.8, 18.1, 'Lärarrum'],
#  [25.7, 12.2, 'Kylrum'],
#  [89.6, 16.3, 'Lärarrum'],
#  [54.7, 10.1, 'Kylrum'],
#  [44.9, 15.8, 'Kylrum'],
#  [54.5, 14.0, 'Kylrum'],
#  [54.8, 19.4, 'Lärarrum'],
#  [69.0, 17.0, 'Lärarrum'],
#  [57.1, 16.6, 'Lärarrum'],
#  [29.0, 14.4, 'Kylrum'],
#  [47.3, 11.1, 'Kylrum'],
#  [83.3, 19.0, 'Lärarrum'],
#  [44.3, 14.7, 'Kylrum'],
#  [22.4, 15.1, 'Kylrum'],
#  [25.1, 10.3, 'Kylrum'],
#  [83.0, 18.8, 'Lärarrum'],
#  [65.3, 17.4, 'Lärarrum'],
#  [22.6, 12.1, 'Kylrum'],
#  [78.2, 16.9, 'Lärarrum'],
#  [37.0, 11.5, 'Kylrum'],
#  [39.0, 10.4, 'Kylrum'],
#  [58.2, 16.1, 'Lärarrum'],
#  [70.8, 16.7, 'Lärarrum'],
#  [52.7, 19.2, 'Lärarrum'],
#  [31.7, 12.5, 'Kylrum'],
#  [58.2, 12.3, 'Kylrum'],
#  [80.7, 18.6, 'Lärarrum'],
#  [52.0, 10.6, 'Kylrum'],
#  [87.9, 17.8, 'Lärarrum'],
#  [63.0, 18.5, 'Lärarrum'],
#  [17.3, 15.3, 'Kylrum'],
#  [98.3, 19.4, 'Klassrum'],
#  [55.0, 17.1, 'Lärarrum'],
#  [54.1, 11.1, 'Kylrum'],
#  [71.5, 17.5, 'Lärarrum'],
#  [85.2, 18.9, 'Lärarrum'],
#  [76.4, 16.6, 'Lärarrum'],
#  [38.9, 15.1, 'Kylrum'],
#  [83.5, 19.0, 'Lärarrum'],
#  [58.4, 18.7, 'Lärarrum'],
#  [33.4, 10.8, 'Kylrum'],
#  [79.4, 16.5, 'Lärarrum'],
#  [25.0, 14.5, 'Kylrum'],
#  [55.7, 19.2, 'Lärarrum'],
#  [59.1, 11.3, 'Kylrum'],
#  [86.3, 17.1, 'Lärarrum'],
#  [56.3, 16.0, 'Lärarrum'],
#  [33.0, 12.7, 'Kylrum'],
#  [36.2, 13.8, 'Kylrum'],
#  [65.2, 19.2, 'Lärarrum'],
#  [71.7, 18.4, 'Lärarrum'],
#  [55.9, 15.3, 'Kylrum'],
#  [75.5, 18.3, 'Lärarrum'],
#  [42.5, 13.6, 'Kylrum'],
#  [55.9, 12.7, 'Kylrum'],
#  [51.8, 19.4, 'Lärarrum'],
#  [54.1, 18.4, 'Lärarrum'],
#  [50.1, 11.5, 'Kylrum'],
#  [46.8, 10.8, 'Kylrum'],
#  [85.3, 17.3, 'Lärarrum'],
#  [59.9, 18.9, 'Lärarrum'],
#  [53.0, 18.1, 'Lärarrum'],
#  [87.3, 19.3, 'Lärarrum'],
#  [30.0, 10.3, 'Kylrum'],
#  [53.2, 12.4, 'Kylrum'],
#  [56.1, 17.0, 'Lärarrum'],
#  [61.0, 17.9, 'Lärarrum'],
#  [43.1, 14.5, 'Kylrum'],
#  [53.9, 18.0, 'Lärarrum'],
#  [81.1, 18.2, 'Lärarrum'],
#  [89.7, 17.6, 'Lärarrum'],
#  [55.0, 14.4, 'Kylrum'],
#  [51.7, 18.0, 'Lärarrum'],
#  [85.5, 17.5, 'Lärarrum'],
#  [53.5, 17.5, 'Lärarrum'],
#  [88.3, 16.2, 'Lärarrum'],
#  [67.6, 17.4, 'Lärarrum'],
#  [51.7, 19.2, 'Lärarrum'],
#  [33.0, 12.4, 'Kylrum'],
#  [23.1, 15.4, 'Kylrum'],
#  [59.9, 18.8, 'Lärarrum'],
#  [17.3, 13.6, 'Kylrum'],
#  [55.6, 15.6, 'Kylrum'],
#  [73.4, 18.9, 'Lärarrum'],
#  [82.2, 16.5, 'Lärarrum'],
#  [53.4, 17.6, 'Lärarrum'],
#  [96.2, 18.4, 'Klassrum'],
#  [49.0, 14.4, 'Kylrum'],
#  [40.4, 14.9, 'Kylrum'],
#  [84.5, 17.1, 'Lärarrum'],
#  [56.4, 10.7, 'Kylrum'],
#  [83.4, 19.4, 'Klassrum'],
#  [17.5, 15.3, 'Kylrum'],
#  [82.9, 19.0, 'Lärarrum'],
#  [63.5, 19.1, 'Lärarrum'],
#  [33.5, 15.5, 'Kylrum'],
#  [34.2, 13.0, 'Kylrum'],
#  [42.1, 10.3, 'Kylrum'],
#  [89.2, 18.6, 'Klassrum'],
#  [57.0, 12.8, 'Kylrum'],
#  [77.9, 18.5, 'Lärarrum'],
#  [89.9, 18.9, 'Klassrum'],
#  [53.1, 17.1, 'Lärarrum'],
#  [31.0, 12.1, 'Kylrum'],
#  [50.1, 16.4, 'Lärarrum'],
#  [78.8, 17.3, 'Lärarrum'],
#  [74.4, 16.7, 'Lärarrum'],
#  [62.2, 16.2, 'Lärarrum'],
#  [66.9, 19.2, 'Lärarrum'],
#  [52.4, 19.1, 'Lärarrum'],
#  [82.2, 18.9, 'Lärarrum'],
#  [40.0, 11.4, 'Kylrum'],
#  [84.3, 16.2, 'Lärarrum'],
#  [56.2, 11.4, 'Kylrum'],
#  [59.4, 14.0, 'Kylrum'],
#  [51.7, 17.7, 'Lärarrum'],
#  [77.5, 17.9, 'Lärarrum'],
#  [17.0, 13.1, 'Kylrum'],
#  [30.4, 14.1, 'Kylrum'],
#  [45.3, 10.1, 'Kylrum'],
#  [51.0, 15.5, 'Kylrum'],
#  [54.6, 11.5, 'Kylrum'],
#  [52.7, 11.0, 'Kylrum'],
#  [96.1, 18.7, 'Klassrum'],
#  [82.9, 18.1, 'Klassrum'],
#  [64.2, 16.1, 'Lärarrum'],
#  [86.8, 17.4, 'Lärarrum'],
#  [87.0, 19.0, 'Lärarrum'],
#  [72.0, 17.1, 'Lärarrum'],
#  [32.6, 10.9, 'Kylrum'],
#  [82.9, 18.8, 'Klassrum'],
#  [58.9, 14.7, 'Kylrum'],
#  [43.7, 13.2, 'Kylrum'],
#  [69.2, 18.2, 'Lärarrum'],
#  [71.7, 19.1, 'Lärarrum'],
#  [58.6, 12.8, 'Kylrum'],
#  [36.1, 11.7, 'Kylrum'],
#  [74.6, 16.9, 'Lärarrum'],
#  [45.4, 14.8, 'Kylrum'],
#  [59.5, 16.9, 'Lärarrum'],
#  [53.3, 11.7, 'Kylrum'],
#  [64.4, 17.7, 'Lärarrum'],
#  [67.7, 16.8, 'Lärarrum'],
#  [90.6, 18.4, 'Klassrum'],
#  [82.7, 18.8, 'Klassrum'],
#  [81.7, 17.8, 'Lärarrum'],
#  [41.8, 10.7, 'Kylrum'],
#  [44.6, 12.0, 'Kylrum'],
#  [88.7, 19.1, 'Klassrum'],
#  [73.1, 16.9, 'Lärarrum'],
#  [19.0, 15.0, 'Kylrum'],
#  [74.5, 16.2, 'Lärarrum'],
#  [54.2, 14.5, 'Kylrum'],
#  [26.1, 10.5, 'Kylrum'],
#  [44.0, 13.4, 'Kylrum'],
#  [52.3, 16.2, 'Lärarrum'],
#  [38.2, 16.0, 'Kylrum'],
#  [62.7, 18.1, 'Lärarrum'],
#  [77.2, 17.2, 'Lärarrum'],
#  [54.8, 18.3, 'Lärarrum'],
#  [83.5, 18.2, 'Lärarrum'],
#  [59.1, 18.6, 'Lärarrum'],
#  [89.0, 16.5, 'Lärarrum'],
#  [68.5, 18.7, 'Lärarrum'],
#  [82.7, 16.4, 'Lärarrum'],
#  [95.6, 18.4, 'Klassrum'],
#  [39.7, 10.2, 'Kylrum'],
#  [80.9, 17.4, 'Lärarrum'],
#  [15.9, 15.6, 'Kylrum'],
#  [82.9, 19.0, 'Klassrum'],
#  [32.8, 10.8, 'Kylrum'],
#  [54.2, 16.2, 'Lärarrum'],
#  [72.9, 16.7, 'Lärarrum'],
#  [25.7, 13.1, 'Kylrum'],
#  [24.8, 15.7, 'Kylrum'],
#  [70.5, 18.7, 'Lärarrum'],
#  [15.2, 12.5, 'Kylrum'],
#  [21.7, 14.8, 'Kylrum'],
#  [57.3, 13.8, 'Kylrum'],
#  [22.0, 11.3, 'Kylrum'],
#  [53.7, 19.3, 'Lärarrum'],
#  [62.8, 17.7, 'Lärarrum'],
#  [79.6, 17.2, 'Lärarrum'],
#  [46.5, 15.9, 'Kylrum'],
#  [58.9, 18.9, 'Lärarrum'],
#  [96.7, 18.0, 'Klassrum'],
#  [86.7, 18.5, 'Klassrum'],
#  [55.2, 13.1, 'Kylrum'],
#  [82.2, 18.8, 'Lärarrum'],
#  [40.3, 15.6, 'Kylrum'],
#  [84.4, 18.7, 'Klassrum'],
#  [42.6, 12.8, 'Kylrum'],
#  [24.5, 10.1, 'Kylrum'],
#  [87.8, 17.0, 'Lärarrum'],
#  [83.2, 18.5, 'Klassrum'],
#  [57.9, 16.3, 'Lärarrum'],
#  [25.0, 15.0, 'Kylrum'],
#  [38.5, 13.5, 'Kylrum'],
#  [59.2, 12.1, 'Kylrum'],
#  [52.0, 17.4, 'Lärarrum'],
#  [18.6, 11.6, 'Kylrum'],
#  [98.9, 19.4, 'Klassrum'],
#  [51.7, 13.2, 'Kylrum'],
#  [74.1, 16.9, 'Lärarrum'],
#  [33.0, 10.9, 'Kylrum'],
#  [41.3, 15.6, 'Kylrum'],
#  [86.6, 17.7, 'Lärarrum'],
#  [64.2, 16.4, 'Lärarrum'],
#  [84.6, 16.4, 'Lärarrum'],
#  [59.4, 18.3, 'Lärarrum'],
#  [58.7, 10.6, 'Kylrum'],
#  [48.6, 15.4, 'Kylrum'],
#  [47.3, 11.0, 'Kylrum'],
#  [86.5, 19.1, 'Klassrum'],
#  [20.2, 11.6, 'Kylrum'],
#  [17.0, 14.9, 'Kylrum'],
#  [15.8, 15.7, 'Kylrum'],
#  [52.3, 16.4, 'Lärarrum'],
#  [21.7, 14.5, 'Kylrum'],
#  [79.3, 16.4, 'Lärarrum'],
#  [78.0, 18.6, 'Lärarrum'],
#  [70.1, 16.5, 'Lärarrum'],
#  [85.6, 16.8, 'Lärarrum'],
#  [48.3, 10.8, 'Kylrum'],
#  [68.3, 17.9, 'Lärarrum'],
#  [55.8, 17.5, 'Lärarrum'],
#  [50.0, 14.0, 'Kylrum'],
#  [51.4, 14.6, 'Kylrum'],
#  [46.2, 12.2, 'Kylrum'],
#  [84.6, 16.7, 'Lärarrum'],
#  [55.7, 16.6, 'Lärarrum'],
#  [58.3, 19.2, 'Lärarrum'],
#  [36.2, 14.4, 'Kylrum'],
#  [44.6, 15.2, 'Kylrum'],
#  [50.3, 17.9, 'Lärarrum'],
#  [82.3, 18.7, 'Lärarrum'],
#  [41.9, 13.9, 'Kylrum'],
#  [54.4, 16.3, 'Lärarrum'],
#  [15.1, 10.8, 'Kylrum'],
#  [65.9, 18.2, 'Lärarrum'],
#  [63.0, 17.8, 'Lärarrum'],
#  [78.7, 17.1, 'Lärarrum'],
#  [52.9, 16.9, 'Lärarrum'],
#  [52.7, 10.7, 'Kylrum'],
#  [83.8, 16.9, 'Lärarrum'],
#  [76.6, 17.9, 'Lärarrum'],
#  [56.2, 16.8, 'Lärarrum'],
#  [57.2, 16.7, 'Lärarrum'],
#  [53.2, 10.8, 'Kylrum'],
#  [42.7, 11.9, 'Kylrum'],
#  [39.4, 15.8, 'Kylrum'],
#  [19.9, 12.4, 'Kylrum'],
#  [63.7, 19.4, 'Lärarrum'],
#  [63.0, 17.5, 'Lärarrum'],
#  [58.8, 18.5, 'Lärarrum'],
#  [57.1, 11.8, 'Kylrum'],
#  [76.1, 16.3, 'Lärarrum'],
#  [21.6, 13.9, 'Kylrum'],
#  [44.1, 13.1, 'Kylrum'],
#  [52.6, 15.3, 'Kylrum'],
#  [74.0, 16.5, 'Lärarrum'],
#  [82.4, 19.4, 'Lärarrum'],
#  [56.5, 17.4, 'Lärarrum'],
#  [52.0, 18.1, 'Lärarrum'],
#  [50.1, 16.7, 'Lärarrum'],
#  [29.5, 11.1, 'Kylrum'],
#  [15.3, 15.2, 'Kylrum'],
#  [90.0, 16.5, 'Lärarrum'],
#  [77.9, 16.4, 'Lärarrum'],
#  [56.4, 17.9, 'Lärarrum'],
#  [53.8, 13.3, 'Kylrum'],
#  [85.9, 16.3, 'Lärarrum'],
#  [55.9, 16.9, 'Lärarrum'],
#  [58.8, 18.2, 'Lärarrum'],
#  [43.3, 10.3, 'Kylrum'],
#  [44.3, 15.4, 'Kylrum'],
#  [98.5, 18.1, 'Klassrum'],
#  [70.5, 18.8, 'Lärarrum'],
#  [70.1, 18.9, 'Lärarrum'],
#  [27.6, 10.6, 'Kylrum'],
#  [53.3, 14.5, 'Kylrum'],
#  [22.6, 15.7, 'Kylrum'],
#  [26.9, 11.0, 'Kylrum'],
#  [83.1, 17.5, 'Lärarrum'],
#  [27.1, 12.9, 'Kylrum'],
#  [37.5, 12.6, 'Kylrum'],
#  [82.9, 19.2, 'Lärarrum'],
#  [36.7, 15.6, 'Kylrum'],
#  [33.4, 15.3, 'Kylrum'],
#  [63.7, 18.3, 'Lärarrum'],
#  [46.9, 15.0, 'Kylrum'],
#  [21.6, 14.4, 'Kylrum'],
#  [89.1, 18.0, 'Lärarrum'],
#  [28.3, 11.9, 'Kylrum'],
#  [20.8, 13.3, 'Kylrum'],
#  [17.4, 12.9, 'Kylrum'],
#  [25.3, 10.0, 'Kylrum'],
#  [27.0, 11.2, 'Kylrum'],
#  [82.8, 19.3, 'Klassrum'],
#  [33.3, 13.7, 'Kylrum'],
#  [66.9, 18.9, 'Lärarrum'],
#  [54.1, 18.8, 'Lärarrum'],
#  [68.8, 17.8, 'Lärarrum'],
#  [63.7, 16.6, 'Lärarrum'],
#  [54.5, 10.5, 'Kylrum'],
#  [54.8, 15.8, 'Kylrum'],
#  [58.9, 11.8, 'Kylrum'],
#  [38.5, 12.2, 'Kylrum'],
#  [87.0, 18.7, 'Lärarrum'],
#  [49.2, 10.4, 'Kylrum'],
#  [88.3, 16.6, 'Lärarrum'],
#  [80.3, 19.3, 'Lärarrum'],
#  [74.6, 18.0, 'Lärarrum'],
#  [30.0, 11.1, 'Kylrum'],
#  [68.4, 17.0, 'Lärarrum'],
#  [61.4, 16.1, 'Lärarrum'],
#  [37.1, 15.7, 'Kylrum'],
#  [45.0, 13.1, 'Kylrum'],
#  [83.3, 19.3, 'Lärarrum'],
#  [78.9, 18.0, 'Lärarrum'],
#  [75.9, 16.2, 'Lärarrum'],
#  [29.7, 11.3, 'Kylrum'],
#  [73.6, 17.0, 'Lärarrum'],
#  [29.8, 11.1, 'Kylrum'],
#  [87.6, 17.1, 'Lärarrum'],
#  [64.4, 17.2, 'Lärarrum'],
#  [50.3, 11.1, 'Kylrum'],
#  [73.3, 18.9, 'Lärarrum'],
#  [66.8, 17.2, 'Lärarrum'],
#  [36.0, 13.7, 'Kylrum'],
#  [34.6, 11.7, 'Kylrum'],
#  [34.5, 13.5, 'Kylrum'],
#  [58.1, 19.4, 'Lärarrum'],
#  [58.8, 18.2, 'Lärarrum'],
#  [92.2, 18.8, 'Klassrum'],
#  [61.7, 18.8, 'Lärarrum'],
#  [72.7, 18.9, 'Lärarrum'],
#  [16.7, 11.2, 'Kylrum'],
#  [73.5, 18.9, 'Lärarrum'],
#  [55.0, 15.4, 'Kylrum'],
#  [76.9, 16.6, 'Lärarrum'],
#  [90.4, 18.0, 'Klassrum'],
#  [37.5, 14.7, 'Kylrum'],
#  [28.8, 13.1, 'Kylrum'],
#  [25.5, 10.9, 'Kylrum'],
#  [51.7, 14.4, 'Kylrum'],
#  [51.8, 14.5, 'Kylrum'],
#  [53.8, 17.3, 'Lärarrum'],
#  [73.2, 18.2, 'Lärarrum'],
#  [18.0, 12.7, 'Kylrum'],
#  [59.0, 12.7, 'Kylrum'],
#  [63.5, 17.0, 'Lärarrum'],
#  [86.5, 18.3, 'Lärarrum'],
#  [71.1, 17.2, 'Lärarrum'],
#  [16.2, 15.9, 'Kylrum'],
#  [52.5, 13.8, 'Kylrum'],
#  [52.3, 16.0, 'Kylrum'],
#  [58.1, 13.9, 'Kylrum'],
#  [15.0, 14.9, 'Kylrum'],
#  [67.1, 17.3, 'Lärarrum'],
#  [50.7, 15.4, 'Kylrum'],
#  [23.5, 10.7, 'Kylrum'],
#  [44.4, 11.7, 'Kylrum'],
#  [58.1, 11.7, 'Kylrum'],
#  [21.5, 12.4, 'Kylrum'],
#  [30.0, 14.7, 'Kylrum'],
#  [75.6, 17.3, 'Lärarrum'],
#  [74.3, 16.9, 'Lärarrum'],
#  [71.6, 17.2, 'Lärarrum'],
#  [58.9, 17.2, 'Lärarrum'],
#  [82.4, 19.0, 'Lärarrum'],
#  [32.1, 11.4, 'Kylrum'],
#  [77.7, 17.8, 'Lärarrum'],
#  [61.1, 17.9, 'Lärarrum'],
#  [76.9, 19.1, 'Lärarrum'],
#  [91.8, 18.3, 'Klassrum'],
#  [21.9, 11.6, 'Kylrum'],
#  [39.3, 11.1, 'Kylrum'],
#  [39.3, 14.8, 'Kylrum'],
#  [57.5, 18.4, 'Lärarrum'],
#  [77.9, 18.2, 'Lärarrum'],
#  [55.2, 16.4, 'Lärarrum'],
#  [62.4, 17.6, 'Lärarrum'],
#  [68.8, 16.7, 'Lärarrum'],
#  [83.9, 19.1, 'Klassrum'],
#  [28.3, 11.6, 'Kylrum'],
#  [60.2, 19.4, 'Lärarrum'],
#  [74.1, 17.8, 'Lärarrum'],
#  [52.3, 13.5, 'Kylrum'],
#  [28.6, 10.3, 'Kylrum'],
#  [74.5, 19.1, 'Lärarrum'],
#  [15.7, 13.7, 'Kylrum'],
#  [85.6, 17.8, 'Lärarrum'],
#  [56.6, 19.3, 'Lärarrum'],
#  [45.5, 15.8, 'Kylrum'],
#  [84.1, 18.5, 'Lärarrum'],
#  [85.1, 17.0, 'Lärarrum'],
#  [62.9, 16.1, 'Lärarrum'],
#  [42.0, 11.8, 'Kylrum'],
#  [23.7, 10.4, 'Kylrum'],
#  [54.4, 18.7, 'Lärarrum'],
#  [63.0, 17.0, 'Lärarrum'],
#  [81.3, 18.3, 'Klassrum'],
#  [42.6, 12.5, 'Kylrum'],
#  [61.1, 18.8, 'Lärarrum'],
#  [22.6, 14.6, 'Kylrum'],
#  [64.3, 18.3, 'Lärarrum'],
#  [58.9, 10.1, 'Kylrum'],
#  [69.1, 16.7, 'Lärarrum'],
#  [30.3, 12.7, 'Kylrum'],
#  [62.4, 16.6, 'Lärarrum'],
#  [37.8, 13.2, 'Kylrum'],
#  [50.1, 18.6, 'Lärarrum'],
#  [26.5, 11.2, 'Kylrum'],
#  [62.8, 16.8, 'Lärarrum'],
#  [50.9, 13.7, 'Kylrum'],
#  [31.4, 15.9, 'Kylrum'],
#  [61.1, 18.9, 'Lärarrum'],
#  [52.0, 17.4, 'Lärarrum'],
#  [59.3, 16.7, 'Lärarrum'],
#  [52.0, 18.3, 'Lärarrum'],
#  [87.5, 18.5, 'Lärarrum'],
#  [55.2, 18.5, 'Lärarrum'],
#  [51.2, 13.3, 'Kylrum'],
#  [52.4, 16.5, 'Lärarrum'],
#  [64.5, 18.0, 'Lärarrum'],
#  [89.0, 16.7, 'Lärarrum'],
#  [63.3, 18.0, 'Lärarrum'],
#  [85.2, 17.4, 'Lärarrum'],
#  [68.8, 19.4, 'Lärarrum'],
#  [26.2, 10.9, 'Kylrum'],
#  [24.9, 12.4, 'Kylrum'],
#  [77.2, 16.8, 'Lärarrum'],
#  [26.8, 10.0, 'Kylrum'],
#  [35.6, 10.9, 'Kylrum'],
#  [52.0, 16.6, 'Lärarrum'],
#  ...]

# %%
# This will contain everything else.
false_rows
#######
# Out:
# [[72.5, 20.1, 'Lärarrum'],
#  [85.7, 23.4, 'Klassrum'],
#  [64.6, 19.5, 'Lärarrum'],
#  [58.0, 19.8, 'Lärarrum'],
#  [81.3, 22.4, 'Klassrum'],
#  [65.0, 19.6, 'Lärarrum'],
#  [86.3, 23.0, 'Klassrum'],
#  [85.0, 20.4, 'Klassrum'],
#  [88.2, 20.5, 'Lärarrum'],
#  [59.1, 20.2, 'Lärarrum'],
#  [66.4, 21.4, 'Lärarrum'],
#  [56.1, 21.9, 'Lärarrum'],
#  [87.1, 22.5, 'Klassrum'],
#  [52.7, 20.0, 'Lärarrum'],
#  [62.4, 20.5, 'Lärarrum'],
#  [73.6, 21.7, 'Lärarrum'],
#  [98.3, 20.9, 'Klassrum'],
#  [82.9, 23.3, 'Klassrum'],
#  [53.9, 20.0, 'Lärarrum'],
#  [80.5, 21.6, 'Lärarrum'],
#  [92.0, 23.0, 'Klassrum'],
#  [80.6, 19.8, 'Klassrum'],
#  [82.7, 20.2, 'Klassrum'],
#  [89.4, 21.8, 'Klassrum'],
#  [95.3, 23.0, 'Klassrum'],
#  [55.2, 20.1, 'Lärarrum'],
#  [73.1, 20.1, 'Lärarrum'],
#  [50.8, 21.4, 'Lärarrum'],
#  [81.6, 21.5, 'Lärarrum'],
#  [50.4, 21.9, 'Lärarrum'],
#  [93.6, 20.9, 'Klassrum'],
#  [86.2, 19.7, 'Lärarrum'],
#  [50.3, 20.2, 'Lärarrum'],
#  [92.3, 20.4, 'Klassrum'],
#  [77.9, 20.2, 'Lärarrum'],
#  [94.9, 21.3, 'Klassrum'],
#  [87.4, 20.3, 'Lärarrum'],
#  [78.5, 21.9, 'Lärarrum'],
#  [66.1, 22.0, 'Lärarrum'],
#  [76.9, 21.9, 'Lärarrum'],
#  [77.5, 19.6, 'Lärarrum'],
#  [84.1, 23.1, 'Klassrum'],
#  [68.1, 19.7, 'Lärarrum'],
#  [74.4, 21.9, 'Lärarrum'],
#  [70.2, 20.5, 'Lärarrum'],
#  [68.0, 20.4, 'Lärarrum'],
#  [90.8, 20.1, 'Klassrum'],
#  [84.6, 22.9, 'Klassrum'],
#  [68.2, 21.6, 'Lärarrum'],
#  [83.6, 20.6, 'Klassrum'],
#  [79.0, 20.0, 'Lärarrum'],
#  [97.5, 20.4, 'Klassrum'],
#  [80.8, 23.9, 'Klassrum'],
#  [69.2, 21.8, 'Lärarrum'],
#  [80.2, 23.6, 'Klassrum'],
#  [85.7, 21.7, 'Lärarrum'],
#  [70.0, 19.9, 'Lärarrum'],
#  [82.9, 19.7, 'Klassrum'],
#  [75.1, 20.5, 'Lärarrum'],
#  [84.7, 20.9, 'Klassrum'],
#  [87.5, 24.0, 'Klassrum'],
#  [72.4, 21.9, 'Lärarrum'],
#  [85.5, 23.9, 'Klassrum'],
#  [80.4, 20.1, 'Lärarrum'],
#  [93.5, 21.9, 'Klassrum'],
#  [85.7, 23.4, 'Klassrum'],
#  [66.2, 20.7, 'Lärarrum'],
#  [74.4, 19.7, 'Lärarrum'],
#  [68.8, 22.0, 'Lärarrum'],
#  [72.5, 20.0, 'Lärarrum'],
#  [77.1, 21.2, 'Lärarrum'],
#  [86.7, 21.0, 'Klassrum'],
#  [95.5, 20.8, 'Klassrum'],
#  [82.9, 20.2, 'Lärarrum'],
#  [73.3, 20.0, 'Lärarrum'],
#  [82.6, 19.6, 'Lärarrum'],
#  [57.4, 20.4, 'Lärarrum'],
#  [65.5, 20.1, 'Lärarrum'],
#  [65.1, 20.3, 'Lärarrum'],
#  [71.9, 21.7, 'Lärarrum'],
#  [98.5, 22.6, 'Klassrum'],
#  [53.4, 21.0, 'Lärarrum'],
#  [89.4, 21.7, 'Lärarrum'],
#  [81.5, 20.1, 'Klassrum'],
#  [61.0, 21.8, 'Lärarrum'],
#  [86.9, 20.9, 'Lärarrum'],
#  [59.0, 21.4, 'Lärarrum'],
#  [89.6, 19.5, 'Lärarrum'],
#  [73.0, 21.3, 'Lärarrum'],
#  [89.3, 23.5, 'Klassrum'],
#  [71.3, 20.2, 'Lärarrum'],
#  [57.7, 19.5, 'Lärarrum'],
#  [84.4, 20.3, 'Klassrum'],
#  [94.4, 22.5, 'Klassrum'],
#  [86.1, 21.0, 'Klassrum'],
#  [97.0, 20.8, 'Klassrum'],
#  [50.7, 21.8, 'Lärarrum'],
#  [92.9, 19.5, 'Klassrum'],
#  [81.8, 19.6, 'Lärarrum'],
#  [76.8, 21.9, 'Lärarrum'],
#  [69.1, 20.6, 'Lärarrum'],
#  [74.0, 20.9, 'Lärarrum'],
#  [98.9, 22.4, 'Klassrum'],
#  [67.5, 21.8, 'Lärarrum'],
#  [58.3, 20.2, 'Lärarrum'],
#  [83.6, 20.6, 'Lärarrum'],
#  [83.2, 21.1, 'Lärarrum'],
#  [74.1, 21.1, 'Lärarrum'],
#  [86.2, 20.1, 'Lärarrum'],
#  [53.1, 21.0, 'Lärarrum'],
#  [91.1, 20.8, 'Klassrum'],
#  [84.4, 21.3, 'Lärarrum'],
#  [66.9, 20.3, 'Lärarrum'],
#  [83.8, 22.7, 'Klassrum'],
#  [86.5, 21.9, 'Lärarrum'],
#  [64.9, 20.1, 'Lärarrum'],
#  [69.9, 19.8, 'Lärarrum'],
#  [71.3, 21.8, 'Lärarrum'],
#  [91.1, 20.0, 'Klassrum'],
#  [65.2, 20.7, 'Lärarrum'],
#  [99.3, 23.2, 'Klassrum'],
#  [59.4, 19.6, 'Lärarrum'],
#  [95.6, 19.6, 'Klassrum'],
#  [89.5, 19.7, 'Lärarrum'],
#  [93.5, 21.1, 'Klassrum'],
#  [88.4, 20.2, 'Lärarrum'],
#  [72.6, 20.5, 'Lärarrum'],
#  [62.6, 20.9, 'Lärarrum'],
#  [72.9, 19.7, 'Lärarrum'],
#  [63.1, 21.3, 'Lärarrum'],
#  [81.0, 22.9, 'Klassrum'],
#  [94.9, 23.5, 'Klassrum'],
#  [53.8, 19.8, 'Lärarrum'],
#  [87.6, 23.1, 'Klassrum'],
#  [63.2, 21.0, 'Lärarrum'],
#  [96.7, 21.9, 'Klassrum'],
#  [51.6, 19.8, 'Lärarrum'],
#  [67.8, 21.9, 'Lärarrum'],
#  [62.1, 20.4, 'Lärarrum'],
#  [89.3, 21.6, 'Klassrum'],
#  [67.3, 21.8, 'Lärarrum'],
#  [93.5, 22.2, 'Klassrum'],
#  [79.2, 19.9, 'Lärarrum'],
#  [81.2, 19.9, 'Klassrum'],
#  [86.2, 20.9, 'Klassrum'],
#  [94.5, 24.0, 'Klassrum'],
#  [76.8, 21.3, 'Lärarrum'],
#  [57.9, 19.6, 'Lärarrum'],
#  [74.3, 19.6, 'Lärarrum'],
#  [79.0, 20.2, 'Lärarrum'],
#  [74.7, 20.1, 'Lärarrum'],
#  [74.5, 20.2, 'Lärarrum'],
#  [82.5, 21.7, 'Lärarrum'],
#  [83.1, 20.0, 'Lärarrum'],
#  [86.1, 20.8, 'Lärarrum'],
#  [94.1, 22.3, 'Klassrum'],
#  [64.3, 21.2, 'Lärarrum'],
#  [56.0, 20.9, 'Lärarrum'],
#  [75.9, 20.2, 'Lärarrum'],
#  [83.1, 19.6, 'Lärarrum'],
#  [78.5, 19.9, 'Lärarrum'],
#  [56.6, 20.4, 'Lärarrum'],
#  [82.3, 20.9, 'Lärarrum'],
#  [87.4, 22.6, 'Klassrum'],
#  [77.0, 19.8, 'Lärarrum'],
#  [74.3, 20.0, 'Lärarrum'],
#  [90.7, 19.5, 'Klassrum'],
#  [54.3, 20.8, 'Lärarrum'],
#  [62.6, 21.9, 'Lärarrum'],
#  [89.4, 21.6, 'Lärarrum'],
#  [87.7, 22.2, 'Klassrum'],
#  [89.7, 23.3, 'Klassrum'],
#  [84.7, 21.3, 'Klassrum'],
#  [94.8, 21.8, 'Klassrum'],
#  [86.1, 20.5, 'Lärarrum'],
#  [87.5, 20.1, 'Klassrum'],
#  [52.8, 19.9, 'Lärarrum'],
#  [98.4, 23.3, 'Klassrum'],
#  [91.9, 22.2, 'Klassrum'],
#  [61.7, 20.1, 'Lärarrum'],
#  [81.4, 19.9, 'Klassrum'],
#  [82.2, 20.4, 'Lärarrum'],
#  [68.2, 20.4, 'Lärarrum'],
#  [94.1, 19.7, 'Klassrum'],
#  [71.2, 19.9, 'Lärarrum'],
#  [81.2, 21.9, 'Lärarrum'],
#  [82.1, 21.1, 'Lärarrum'],
#  [81.4, 23.8, 'Klassrum'],
#  [55.9, 21.1, 'Lärarrum'],
#  [52.7, 20.5, 'Lärarrum'],
#  [60.3, 20.7, 'Lärarrum'],
#  [78.5, 21.4, 'Lärarrum'],
#  [80.5, 21.6, 'Lärarrum'],
#  [62.8, 20.5, 'Lärarrum'],
#  [62.9, 21.9, 'Lärarrum'],
#  [83.7, 20.5, 'Klassrum'],
#  [92.6, 23.8, 'Klassrum'],
#  [73.8, 20.9, 'Lärarrum'],
#  [85.1, 21.3, 'Lärarrum'],
#  [67.9, 21.1, 'Lärarrum'],
#  [63.2, 20.8, 'Lärarrum'],
#  [71.1, 19.5, 'Lärarrum'],
#  [80.2, 21.8, 'Lärarrum'],
#  [88.9, 20.7, 'Lärarrum'],
#  [99.7, 21.7, 'Klassrum'],
#  [97.8, 22.1, 'Klassrum'],
#  [67.9, 20.4, 'Lärarrum'],
#  [62.7, 21.3, 'Lärarrum'],
#  [52.1, 21.5, 'Lärarrum'],
#  [52.6, 21.8, 'Lärarrum'],
#  [90.7, 23.6, 'Klassrum'],
#  [86.4, 19.8, 'Klassrum'],
#  [78.9, 22.0, 'Lärarrum'],
#  [69.8, 21.8, 'Lärarrum'],
#  [89.4, 21.7, 'Lärarrum'],
#  [62.6, 21.6, 'Lärarrum'],
#  [76.2, 21.4, 'Lärarrum'],
#  [77.5, 19.7, 'Lärarrum'],
#  [88.5, 21.5, 'Klassrum'],
#  [92.6, 22.8, 'Klassrum'],
#  [99.5, 21.9, 'Klassrum'],
#  [78.5, 20.2, 'Lärarrum'],
#  [79.2, 21.9, 'Lärarrum'],
#  [64.3, 21.1, 'Lärarrum'],
#  [69.3, 21.3, 'Lärarrum'],
#  [86.2, 21.9, 'Klassrum'],
#  [78.1, 19.7, 'Lärarrum'],
#  [72.3, 21.8, 'Lärarrum'],
#  [94.0, 21.2, 'Klassrum'],
#  [63.1, 19.8, 'Lärarrum'],
#  [59.7, 20.8, 'Lärarrum'],
#  [60.8, 20.1, 'Lärarrum'],
#  [72.8, 20.1, 'Lärarrum'],
#  [90.8, 22.4, 'Klassrum'],
#  [98.0, 19.5, 'Klassrum'],
#  [55.2, 20.9, 'Lärarrum'],
#  [70.9, 20.3, 'Lärarrum'],
#  [92.5, 21.9, 'Klassrum'],
#  [64.6, 20.9, 'Lärarrum'],
#  [87.9, 21.6, 'Lärarrum'],
#  [67.4, 21.8, 'Lärarrum'],
#  [69.9, 20.7, 'Lärarrum'],
#  [89.1, 23.8, 'Klassrum'],
#  [71.8, 21.8, 'Lärarrum'],
#  [51.5, 19.9, 'Lärarrum'],
#  [99.0, 19.5, 'Klassrum'],
#  [86.1, 20.3, 'Klassrum'],
#  [81.6, 20.4, 'Klassrum'],
#  [62.7, 21.4, 'Lärarrum'],
#  [88.9, 20.9, 'Lärarrum'],
#  [86.9, 19.6, 'Lärarrum'],
#  [79.8, 19.7, 'Lärarrum'],
#  [69.6, 19.7, 'Lärarrum'],
#  [96.8, 22.9, 'Klassrum'],
#  [86.2, 21.5, 'Lärarrum'],
#  [85.7, 21.5, 'Klassrum'],
#  [79.5, 19.9, 'Lärarrum'],
#  [62.0, 20.1, 'Lärarrum'],
#  [80.5, 21.0, 'Klassrum'],
#  [95.8, 20.8, 'Klassrum'],
#  [95.1, 22.1, 'Klassrum'],
#  [72.0, 20.4, 'Lärarrum'],
#  [88.7, 20.2, 'Lärarrum'],
#  [81.1, 23.6, 'Klassrum'],
#  [85.0, 21.4, 'Klassrum'],
#  [70.6, 21.7, 'Lärarrum'],
#  [74.6, 20.5, 'Lärarrum'],
#  [84.7, 20.2, 'Lärarrum'],
#  [59.2, 20.8, 'Lärarrum'],
#  [56.3, 21.9, 'Lärarrum'],
#  [59.6, 21.3, 'Lärarrum'],
#  [52.9, 20.5, 'Lärarrum'],
#  [82.8, 20.1, 'Lärarrum'],
#  [83.5, 22.9, 'Klassrum'],
#  [84.6, 21.1, 'Klassrum'],
#  [52.5, 21.0, 'Lärarrum'],
#  [81.0, 22.0, 'Lärarrum'],
#  [96.2, 24.0, 'Klassrum'],
#  [91.4, 22.1, 'Klassrum'],
#  [71.4, 19.5, 'Lärarrum'],
#  [93.4, 23.2, 'Klassrum'],
#  [69.1, 22.0, 'Lärarrum'],
#  [72.0, 21.5, 'Lärarrum'],
#  [87.1, 20.9, 'Klassrum'],
#  [58.8, 20.7, 'Lärarrum'],
#  [99.6, 22.2, 'Klassrum'],
#  [68.7, 20.8, 'Lärarrum'],
#  [74.8, 20.8, 'Lärarrum'],
#  [62.6, 20.4, 'Lärarrum'],
#  [84.0, 23.0, 'Klassrum'],
#  [60.1, 21.9, 'Lärarrum'],
#  [62.8, 20.1, 'Lärarrum'],
#  [80.7, 21.1, 'Lärarrum'],
#  [63.1, 20.8, 'Lärarrum'],
#  [56.3, 20.3, 'Lärarrum'],
#  [95.1, 19.8, 'Klassrum'],
#  [73.0, 19.9, 'Lärarrum'],
#  [92.9, 21.9, 'Klassrum'],
#  [81.7, 21.7, 'Lärarrum'],
#  [55.0, 20.2, 'Lärarrum'],
#  [68.5, 21.1, 'Lärarrum'],
#  [90.9, 23.8, 'Klassrum'],
#  [72.2, 21.7, 'Lärarrum'],
#  [94.8, 21.6, 'Klassrum'],
#  [66.1, 20.1, 'Lärarrum'],
#  [83.9, 21.8, 'Lärarrum'],
#  [80.5, 21.3, 'Lärarrum'],
#  [65.7, 20.3, 'Lärarrum'],
#  [94.0, 23.2, 'Klassrum'],
#  [80.7, 22.8, 'Klassrum'],
#  [96.1, 21.9, 'Klassrum'],
#  [69.1, 21.2, 'Lärarrum'],
#  [52.3, 19.8, 'Lärarrum'],
#  [76.8, 21.3, 'Lärarrum'],
#  [86.7, 22.7, 'Klassrum'],
#  [69.4, 20.4, 'Lärarrum'],
#  [99.9, 21.0, 'Klassrum'],
#  [53.7, 21.3, 'Lärarrum'],
#  [79.4, 19.7, 'Lärarrum'],
#  [83.1, 21.9, 'Klassrum'],
#  [79.7, 21.9, 'Lärarrum'],
#  [93.5, 20.1, 'Klassrum'],
#  [79.8, 20.6, 'Lärarrum'],
#  [98.3, 20.4, 'Klassrum'],
#  [86.4, 21.5, 'Lärarrum'],
#  [85.5, 22.8, 'Klassrum'],
#  [65.5, 21.2, 'Lärarrum'],
#  [93.6, 23.1, 'Klassrum'],
#  [82.3, 23.1, 'Klassrum'],
#  [85.6, 21.5, 'Lärarrum'],
#  [99.1, 20.3, 'Klassrum'],
#  [80.5, 20.5, 'Lärarrum'],
#  [88.5, 21.9, 'Lärarrum'],
#  [53.1, 21.5, 'Lärarrum'],
#  [71.5, 20.0, 'Lärarrum'],
#  [83.0, 21.9, 'Lärarrum'],
#  [83.7, 23.6, 'Klassrum'],
#  [57.0, 21.6, 'Lärarrum'],
#  [84.0, 21.5, 'Klassrum'],
#  [56.3, 19.8, 'Lärarrum'],
#  [90.6, 23.1, 'Klassrum'],
#  [75.9, 20.3, 'Lärarrum'],
#  [86.7, 20.2, 'Klassrum'],
#  [62.5, 20.6, 'Lärarrum'],
#  [87.0, 19.8, 'Lärarrum'],
#  [92.3, 21.8, 'Klassrum'],
#  [82.8, 19.8, 'Lärarrum'],
#  [73.4, 21.2, 'Lärarrum'],
#  [88.9, 20.3, 'Klassrum'],
#  [69.1, 19.6, 'Lärarrum'],
#  [73.8, 20.3, 'Lärarrum'],
#  [56.1, 19.5, 'Lärarrum'],
#  [95.6, 20.8, 'Klassrum'],
#  [76.5, 20.8, 'Lärarrum'],
#  [62.1, 20.0, 'Lärarrum'],
#  [62.4, 21.3, 'Lärarrum'],
#  [54.9, 21.1, 'Lärarrum'],
#  [98.3, 22.7, 'Klassrum'],
#  [59.9, 20.7, 'Lärarrum'],
#  [78.2, 20.7, 'Lärarrum'],
#  [97.5, 23.2, 'Klassrum'],
#  [53.1, 19.9, 'Lärarrum'],
#  [54.8, 21.2, 'Lärarrum'],
#  [59.1, 19.7, 'Lärarrum'],
#  [81.1, 21.9, 'Lärarrum'],
#  [88.2, 20.0, 'Klassrum'],
#  [79.8, 21.1, 'Lärarrum'],
#  [60.3, 20.0, 'Lärarrum'],
#  [57.1, 19.8, 'Lärarrum'],
#  [83.7, 20.0, 'Lärarrum'],
#  [78.2, 21.8, 'Lärarrum'],
#  [95.1, 23.9, 'Klassrum'],
#  [81.8, 21.2, 'Lärarrum'],
#  [71.2, 22.0, 'Lärarrum'],
#  [72.8, 21.3, 'Lärarrum'],
#  [80.7, 21.2, 'Lärarrum'],
#  [89.8, 21.4, 'Lärarrum'],
#  [67.5, 21.3, 'Lärarrum'],
#  [86.7, 19.5, 'Klassrum'],
#  [83.2, 21.5, 'Klassrum'],
#  [84.6, 21.5, 'Lärarrum'],
#  [76.3, 20.8, 'Lärarrum'],
#  [58.1, 20.2, 'Lärarrum'],
#  [86.4, 23.4, 'Klassrum'],
#  [82.9, 19.6, 'Lärarrum'],
#  [61.6, 20.8, 'Lärarrum'],
#  [88.1, 19.9, 'Lärarrum'],
#  [88.3, 21.1, 'Lärarrum'],
#  [85.6, 20.9, 'Klassrum'],
#  [50.2, 21.9, 'Lärarrum'],
#  [70.8, 20.0, 'Lärarrum'],
#  [70.8, 21.5, 'Lärarrum'],
#  [71.4, 21.8, 'Lärarrum'],
#  [56.5, 20.1, 'Lärarrum'],
#  [55.6, 19.8, 'Lärarrum'],
#  [88.1, 22.0, 'Lärarrum'],
#  [60.5, 20.9, 'Lärarrum'],
#  [85.9, 21.5, 'Lärarrum'],
#  [71.9, 19.6, 'Lärarrum'],
#  [83.7, 21.5, 'Lärarrum'],
#  [52.6, 20.9, 'Lärarrum'],
#  [60.3, 20.2, 'Lärarrum'],
#  [88.4, 23.9, 'Klassrum'],
#  [84.3, 22.6, 'Klassrum'],
#  [51.1, 20.3, 'Lärarrum'],
#  [90.3, 20.6, 'Klassrum'],
#  [71.4, 20.1, 'Lärarrum'],
#  [79.4, 19.7, 'Lärarrum'],
#  [78.7, 21.0, 'Lärarrum'],
#  [71.3, 20.6, 'Lärarrum'],
#  [82.3, 20.1, 'Lärarrum'],
#  [99.1, 22.9, 'Klassrum'],
#  [66.0, 19.9, 'Lärarrum'],
#  [92.3, 22.9, 'Klassrum'],
#  [82.9, 20.4, 'Klassrum'],
#  [83.0, 23.9, 'Klassrum'],
#  [91.3, 20.5, 'Klassrum'],
#  [62.0, 21.5, 'Lärarrum'],
#  [83.6, 20.6, 'Klassrum'],
#  [85.1, 20.3, 'Klassrum'],
#  [83.3, 22.7, 'Klassrum'],
#  [52.1, 21.4, 'Lärarrum'],
#  [83.2, 21.5, 'Lärarrum'],
#  [94.5, 20.0, 'Klassrum'],
#  [84.5, 22.9, 'Klassrum'],
#  [89.2, 21.4, 'Lärarrum'],
#  [60.8, 21.4, 'Lärarrum'],
#  [91.9, 22.0, 'Klassrum'],
#  [66.7, 20.5, 'Lärarrum'],
#  [72.0, 20.3, 'Lärarrum'],
#  [89.5, 19.5, 'Klassrum'],
#  [69.2, 21.2, 'Lärarrum'],
#  [76.3, 21.6, 'Lärarrum'],
#  [84.7, 20.3, 'Lärarrum'],
#  [85.2, 21.5, 'Lärarrum'],
#  [54.6, 21.9, 'Lärarrum'],
#  [93.1, 20.5, 'Klassrum'],
#  [84.5, 21.2, 'Klassrum'],
#  [59.2, 21.1, 'Lärarrum'],
#  [87.0, 23.2, 'Klassrum'],
#  [61.7, 21.2, 'Lärarrum'],
#  [67.3, 20.4, 'Lärarrum'],
#  [83.1, 21.2, 'Klassrum'],
#  [51.1, 20.9, 'Lärarrum'],
#  [62.9, 20.8, 'Lärarrum'],
#  [89.0, 20.0, 'Lärarrum'],
#  [65.4, 21.7, 'Lärarrum'],
#  [55.0, 19.9, 'Lärarrum'],
#  [92.8, 20.2, 'Klassrum'],
#  [81.4, 22.0, 'Lärarrum'],
#  [63.3, 19.7, 'Lärarrum'],
#  [57.3, 21.1, 'Lärarrum'],
#  [64.6, 19.8, 'Lärarrum'],
#  [86.4, 21.8, 'Lärarrum'],
#  [84.2, 20.3, 'Klassrum'],
#  [89.9, 21.4, 'Klassrum'],
#  [88.5, 20.0, 'Lärarrum'],
#  [78.9, 20.8, 'Lärarrum'],
#  [78.0, 20.6, 'Lärarrum'],
#  [85.9, 22.9, 'Klassrum'],
#  [74.9, 19.7, 'Lärarrum'],
#  [53.6, 20.8, 'Lärarrum'],
#  [89.2, 23.6, 'Klassrum'],
#  [83.6, 22.9, 'Klassrum'],
#  [89.9, 20.7, 'Lärarrum'],
#  [85.6, 21.0, 'Lärarrum'],
#  [85.9, 20.8, 'Klassrum'],
#  [52.9, 21.2, 'Lärarrum'],
#  [83.8, 23.8, 'Klassrum'],
#  [55.2, 20.2, 'Lärarrum'],
#  [59.9, 21.4, 'Lärarrum'],
#  [79.1, 21.0, 'Lärarrum'],
#  [84.7, 23.9, 'Klassrum'],
#  [93.1, 21.8, 'Klassrum'],
#  [64.2, 20.9, 'Lärarrum'],
#  [70.1, 21.5, 'Lärarrum'],
#  [84.0, 21.2, 'Lärarrum'],
#  [87.6, 21.9, 'Klassrum'],
#  [77.9, 21.0, 'Lärarrum'],
#  [64.7, 20.3, 'Lärarrum'],
#  [90.3, 21.8, 'Klassrum'],
#  [94.9, 20.6, 'Klassrum'],
#  [80.5, 19.9, 'Lärarrum'],
#  [77.0, 19.6, 'Lärarrum'],
#  [86.8, 20.6, 'Lärarrum'],
#  [81.7, 23.6, 'Klassrum'],
#  [66.6, 20.2, 'Lärarrum'],
#  [58.4, 21.6, 'Lärarrum'],
#  [52.6, 21.8, 'Lärarrum'],
#  [63.4, 20.6, 'Lärarrum'],
#  [98.3, 23.5, 'Klassrum'],
#  [52.7, 21.8, 'Lärarrum'],
#  [65.1, 21.5, 'Lärarrum'],
#  [79.2, 19.6, 'Lärarrum'],
#  [79.7, 21.3, 'Lärarrum'],
#  [59.8, 20.6, 'Lärarrum'],
#  [61.1, 21.0, 'Lärarrum'],
#  [60.7, 20.8, 'Lärarrum'],
#  [99.0, 20.0, 'Klassrum'],
#  [96.7, 22.0, 'Klassrum'],
#  [57.9, 20.3, 'Lärarrum'],
#  [71.5, 19.5, 'Lärarrum'],
#  [54.1, 21.1, 'Lärarrum'],
#  [53.7, 20.7, 'Lärarrum'],
#  [60.0, 20.5, 'Lärarrum'],
#  [86.4, 21.1, 'Lärarrum'],
#  [71.6, 21.9, 'Lärarrum'],
#  [78.2, 19.8, 'Lärarrum'],
#  [98.3, 21.3, 'Klassrum'],
#  [82.3, 20.4, 'Klassrum'],
#  [56.4, 20.8, 'Lärarrum'],
#  [92.2, 21.0, 'Klassrum'],
#  [89.4, 20.6, 'Lärarrum'],
#  [66.7, 19.8, 'Lärarrum'],
#  [74.4, 21.4, 'Lärarrum'],
#  [88.3, 23.5, 'Klassrum'],
#  [59.7, 19.8, 'Lärarrum'],
#  [81.9, 20.7, 'Klassrum'],
#  [94.6, 22.6, 'Klassrum'],
#  [66.9, 19.9, 'Lärarrum'],
#  [81.3, 21.8, 'Lärarrum'],
#  [71.6, 19.7, 'Lärarrum'],
#  [58.1, 21.9, 'Lärarrum'],
#  [66.0, 20.4, 'Lärarrum'],
#  [54.6, 21.3, 'Lärarrum'],
#  [50.6, 21.2, 'Lärarrum'],
#  [56.1, 21.5, 'Lärarrum'],
#  [69.3, 20.0, 'Lärarrum'],
#  [75.5, 19.6, 'Lärarrum'],
#  [95.4, 20.5, 'Klassrum'],
#  [63.5, 19.9, 'Lärarrum'],
#  [69.3, 21.8, 'Lärarrum'],
#  [57.9, 19.6, 'Lärarrum'],
#  [55.8, 19.5, 'Lärarrum'],
#  [95.5, 21.5, 'Klassrum'],
#  [84.9, 20.0, 'Klassrum'],
#  [84.7, 22.1, 'Klassrum'],
#  [84.7, 19.8, 'Lärarrum'],
#  [72.5, 21.8, 'Lärarrum'],
#  [64.7, 21.4, 'Lärarrum'],
#  [55.0, 19.5, 'Lärarrum'],
#  [63.7, 20.7, 'Lärarrum'],
#  [57.1, 19.6, 'Lärarrum'],
#  [82.4, 23.8, 'Klassrum'],
#  [67.1, 19.9, 'Lärarrum'],
#  [85.6, 20.9, 'Klassrum'],
#  [55.4, 22.0, 'Lärarrum'],
#  [84.8, 20.1, 'Lärarrum'],
#  [88.2, 22.8, 'Klassrum'],
#  [74.1, 21.2, 'Lärarrum'],
#  [86.8, 20.7, 'Klassrum'],
#  [76.8, 21.9, 'Lärarrum'],
#  [99.9, 21.1, 'Klassrum'],
#  [87.4, 19.8, 'Klassrum'],
#  [80.2, 21.4, 'Klassrum'],
#  [86.7, 20.6, 'Lärarrum'],
#  [95.0, 22.8, 'Klassrum'],
#  [80.8, 21.5, 'Klassrum'],
#  [92.1, 21.0, 'Klassrum'],
#  [77.7, 22.0, 'Lärarrum'],
#  [81.2, 19.6, 'Lärarrum'],
#  [77.6, 19.6, 'Lärarrum'],
#  [65.6, 21.4, 'Lärarrum'],
#  [81.5, 19.8, 'Lärarrum'],
#  [86.5, 21.3, 'Lärarrum'],
#  [94.1, 20.3, 'Klassrum'],
#  [56.1, 20.0, 'Lärarrum'],
#  [64.4, 21.9, 'Lärarrum'],
#  [84.9, 20.5, 'Klassrum'],
#  [52.9, 21.5, 'Lärarrum'],
#  [79.4, 19.9, 'Lärarrum'],
#  [65.4, 21.7, 'Lärarrum'],
#  [93.6, 23.8, 'Klassrum'],
#  [63.2, 20.9, 'Lärarrum'],
#  [86.4, 22.0, 'Klassrum'],
#  [72.7, 19.6, 'Lärarrum'],
#  [71.8, 20.2, 'Lärarrum'],
#  [84.5, 21.1, 'Lärarrum'],
#  [87.1, 23.5, 'Klassrum'],
#  [89.8, 19.7, 'Lärarrum'],
#  [54.5, 20.7, 'Lärarrum'],
#  [88.1, 23.6, 'Klassrum'],
#  [80.3, 20.1, 'Klassrum'],
#  [65.4, 20.1, 'Lärarrum'],
#  [81.2, 21.4, 'Klassrum'],
#  [96.8, 20.2, 'Klassrum'],
#  [81.1, 21.6, 'Klassrum'],
#  [92.3, 21.1, 'Klassrum'],
#  [89.1, 23.9, 'Klassrum'],
#  [71.0, 21.9, 'Lärarrum'],
#  [82.7, 21.5, 'Lärarrum'],
#  [54.2, 21.8, 'Lärarrum'],
#  [85.2, 20.3, 'Lärarrum'],
#  [51.8, 21.4, 'Lärarrum'],
#  [81.5, 21.3, 'Klassrum'],
#  [76.2, 19.9, 'Lärarrum'],
#  [86.5, 21.5, 'Lärarrum'],
#  [73.8, 19.9, 'Lärarrum'],
#  [84.1, 21.8, 'Klassrum'],
#  [85.3, 20.3, 'Klassrum'],
#  [59.3, 20.7, 'Lärarrum'],
#  [56.0, 21.2, 'Lärarrum'],
#  [68.5, 20.3, 'Lärarrum'],
#  [89.0, 21.5, 'Klassrum'],
#  [83.2, 21.5, 'Lärarrum'],
#  [53.6, 20.5, 'Lärarrum'],
#  [63.2, 20.7, 'Lärarrum'],
#  [90.7, 19.6, 'Klassrum'],
#  [76.7, 21.9, 'Lärarrum'],
#  [65.8, 21.1, 'Lärarrum'],
#  [55.4, 21.9, 'Lärarrum'],
#  [52.6, 21.4, 'Lärarrum'],
#  [97.0, 22.5, 'Klassrum'],
#  [98.7, 22.0, 'Klassrum'],
#  [69.8, 21.3, 'Lärarrum'],
#  [62.8, 19.6, 'Lärarrum'],
#  [83.4, 21.2, 'Lärarrum'],
#  [73.6, 21.0, 'Lärarrum'],
#  [51.9, 21.1, 'Lärarrum'],
#  [66.9, 20.7, 'Lärarrum'],
#  [81.6, 22.8, 'Klassrum'],
#  [79.2, 19.8, 'Lärarrum'],
#  [75.6, 19.9, 'Lärarrum'],
#  [77.2, 21.6, 'Lärarrum'],
#  [82.5, 20.6, 'Lärarrum'],
#  [66.5, 21.0, 'Lärarrum'],
#  [98.8, 22.1, 'Klassrum'],
#  [96.0, 21.4, 'Klassrum'],
#  [56.1, 21.0, 'Lärarrum'],
#  [99.3, 22.8, 'Klassrum'],
#  [69.3, 20.2, 'Lärarrum'],
#  [98.4, 20.4, 'Klassrum'],
#  [87.9, 22.0, 'Klassrum'],
#  [58.2, 21.1, 'Lärarrum'],
#  [83.2, 19.8, 'Lärarrum'],
#  [68.1, 22.0, 'Lärarrum'],
#  [76.9, 20.7, 'Lärarrum'],
#  [84.0, 19.5, 'Lärarrum'],
#  [89.5, 19.8, 'Lärarrum'],
#  [65.4, 21.9, 'Lärarrum'],
#  [86.4, 21.1, 'Klassrum'],
#  [53.6, 19.9, 'Lärarrum'],
#  [50.9, 20.8, 'Lärarrum'],
#  [76.5, 20.4, 'Lärarrum'],
#  [52.0, 20.5, 'Lärarrum'],
#  [63.6, 20.5, 'Lärarrum'],
#  [96.7, 19.7, 'Klassrum'],
#  [76.6, 21.9, 'Lärarrum'],
#  [96.4, 21.7, 'Klassrum'],
#  [62.0, 21.7, 'Lärarrum'],
#  [69.9, 21.6, 'Lärarrum'],
#  [89.0, 20.5, 'Klassrum'],
#  [71.8, 19.5, 'Lärarrum'],
#  [97.0, 22.0, 'Klassrum'],
#  [89.1, 20.9, 'Lärarrum'],
#  [77.6, 22.0, 'Lärarrum'],
#  [67.6, 21.3, 'Lärarrum'],
#  [65.4, 19.9, 'Lärarrum'],
#  [90.6, 23.3, 'Klassrum'],
#  [76.4, 21.0, 'Lärarrum'],
#  [88.5, 19.6, 'Lärarrum'],
#  [76.5, 20.3, 'Lärarrum'],
#  [75.5, 20.2, 'Lärarrum'],
#  [53.2, 20.6, 'Lärarrum'],
#  [99.5, 22.5, 'Klassrum'],
#  [88.3, 20.7, 'Lärarrum'],
#  [73.6, 19.5, 'Lärarrum'],
#  [96.5, 19.8, 'Klassrum'],
#  [91.9, 19.8, 'Klassrum'],
#  [73.4, 20.2, 'Lärarrum'],
#  [80.0, 21.1, 'Lärarrum'],
#  [87.7, 19.8, 'Klassrum'],
#  [88.0, 20.6, 'Lärarrum'],
#  [86.9, 19.6, 'Klassrum'],
#  [96.7, 20.3, 'Klassrum'],
#  [92.0, 23.1, 'Klassrum'],
#  [88.4, 20.2, 'Lärarrum']]

# %%
def gini(rows):
    """Calculate the Gini Impurity for a list of rows.

    There are a few different ways to do this, I thought this one was
    the most concise. See:
    https://en.wikipedia.org/wiki/Decision_tree_learning#Gini_impurity
    """
    counts = class_counts(rows)
    impurity = 1
    for lbl in counts:
        prob_of_lbl = counts[lbl] / float(len(rows))
        impurity -= prob_of_lbl**2
    return impurity

# %%
#######
# Demo:
# Let's look at some example to understand how Gini Impurity works.
#
# First, we'll look at a dataset with no mixing.
no_mixing = [['Apple'],
              ['Apple']]
# this will return 0
gini(no_mixing)
# Out:
# 0.0

# %%
# Now, we'll look at dataset with a 50:50 apples:oranges ratio
some_mixing = [['Apple'],
               ['Orange']]
# this will return 0.5 - meaning, there's a 50% chance of misclassifying
# a random example we draw from the dataset.
gini(some_mixing)
# Out:
# 0.5

# %%
# Now, we'll look at a dataset with many different labels
lots_of_mixing = [['Apple'],
                  ['Orange'],
                  ['Grape'],
                  ['Grapefruit'],
                  ['Blueberry']]
# This will return 0.8
gini(lots_of_mixing)
#######
# Out:
# 0.7999999999999998

# %%
def info_gain(left, right, current_uncertainty):
    """Information Gain.

    The uncertainty of the starting node, minus the weighted impurity of
    two child nodes.
    """
    p = float(len(left)) / (len(left) + len(right))
    return current_uncertainty - p * gini(left) - (1 - p) * gini(right)

# %%
#######
# Demo:
# Calculate the uncertainy of our training data.
current_uncertainty = gini(training_data)
current_uncertainty
# Out:
# 0.5832185321618171

# %%
# How much information do we gain by partioning on 'Green'?
true_rows, false_rows = partition(training_data, Question(1, 19.5, 0, 1))
info_gain(true_rows, false_rows, current_uncertainty)
# Out:
# 0.06830854709452555

# %%
# What about if we partioned on 'Red' instead?
true_rows, false_rows = partition(training_data, Question(1, 18.1, 1, 0))
info_gain(true_rows, false_rows, current_uncertainty)
# Out:
# 0.13320582290154712

# %%
# It looks like we learned more using 'Red' (0.37), than 'Green' (0.14).
# Why? Look at the different splits that result, and see which one
# looks more 'unmixed' to you.
true_rows, false_rows = partition(training_data, Question(1, 19.7, 0, 0))

# Here, the true_rows contain only 'Grapes'.
true_rows
# Out:
# [[72.5, 20.1, 'Lärarrum'],
#  [85.7, 23.4, 'Klassrum'],
#  [58.0, 19.8, 'Lärarrum'],
#  [81.3, 22.4, 'Klassrum'],
#  [86.3, 23.0, 'Klassrum'],
#  [85.0, 20.4, 'Klassrum'],
#  [88.2, 20.5, 'Lärarrum'],
#  [59.1, 20.2, 'Lärarrum'],
#  [66.4, 21.4, 'Lärarrum'],
#  [56.1, 21.9, 'Lärarrum'],
#  [87.1, 22.5, 'Klassrum'],
#  [52.7, 20.0, 'Lärarrum'],
#  [62.4, 20.5, 'Lärarrum'],
#  [73.6, 21.7, 'Lärarrum'],
#  [98.3, 20.9, 'Klassrum'],
#  [82.9, 23.3, 'Klassrum'],
#  [53.9, 20.0, 'Lärarrum'],
#  [80.5, 21.6, 'Lärarrum'],
#  [92.0, 23.0, 'Klassrum'],
#  [80.6, 19.8, 'Klassrum'],
#  [82.7, 20.2, 'Klassrum'],
#  [89.4, 21.8, 'Klassrum'],
#  [95.3, 23.0, 'Klassrum'],
#  [55.2, 20.1, 'Lärarrum'],
#  [73.1, 20.1, 'Lärarrum'],
#  [50.8, 21.4, 'Lärarrum'],
#  [81.6, 21.5, 'Lärarrum'],
#  [50.4, 21.9, 'Lärarrum'],
#  [93.6, 20.9, 'Klassrum'],
#  [50.3, 20.2, 'Lärarrum'],
#  [92.3, 20.4, 'Klassrum'],
#  [77.9, 20.2, 'Lärarrum'],
#  [94.9, 21.3, 'Klassrum'],
#  [87.4, 20.3, 'Lärarrum'],
#  [78.5, 21.9, 'Lärarrum'],
#  [66.1, 22.0, 'Lärarrum'],
#  [76.9, 21.9, 'Lärarrum'],
#  [84.1, 23.1, 'Klassrum'],
#  [74.4, 21.9, 'Lärarrum'],
#  [70.2, 20.5, 'Lärarrum'],
#  [68.0, 20.4, 'Lärarrum'],
#  [90.8, 20.1, 'Klassrum'],
#  [84.6, 22.9, 'Klassrum'],
#  [68.2, 21.6, 'Lärarrum'],
#  [83.6, 20.6, 'Klassrum'],
#  [79.0, 20.0, 'Lärarrum'],
#  [97.5, 20.4, 'Klassrum'],
#  [80.8, 23.9, 'Klassrum'],
#  [69.2, 21.8, 'Lärarrum'],
#  [80.2, 23.6, 'Klassrum'],
#  [85.7, 21.7, 'Lärarrum'],
#  [70.0, 19.9, 'Lärarrum'],
#  [75.1, 20.5, 'Lärarrum'],
#  [84.7, 20.9, 'Klassrum'],
#  [87.5, 24.0, 'Klassrum'],
#  [72.4, 21.9, 'Lärarrum'],
#  [85.5, 23.9, 'Klassrum'],
#  [80.4, 20.1, 'Lärarrum'],
#  [93.5, 21.9, 'Klassrum'],
#  [85.7, 23.4, 'Klassrum'],
#  [66.2, 20.7, 'Lärarrum'],
#  [68.8, 22.0, 'Lärarrum'],
#  [72.5, 20.0, 'Lärarrum'],
#  [77.1, 21.2, 'Lärarrum'],
#  [86.7, 21.0, 'Klassrum'],
#  [95.5, 20.8, 'Klassrum'],
#  [82.9, 20.2, 'Lärarrum'],
#  [73.3, 20.0, 'Lärarrum'],
#  [57.4, 20.4, 'Lärarrum'],
#  [65.5, 20.1, 'Lärarrum'],
#  [65.1, 20.3, 'Lärarrum'],
#  [71.9, 21.7, 'Lärarrum'],
#  [98.5, 22.6, 'Klassrum'],
#  [53.4, 21.0, 'Lärarrum'],
#  [89.4, 21.7, 'Lärarrum'],
#  [81.5, 20.1, 'Klassrum'],
#  [61.0, 21.8, 'Lärarrum'],
#  [86.9, 20.9, 'Lärarrum'],
#  [59.0, 21.4, 'Lärarrum'],
#  [73.0, 21.3, 'Lärarrum'],
#  [89.3, 23.5, 'Klassrum'],
#  [71.3, 20.2, 'Lärarrum'],
#  [84.4, 20.3, 'Klassrum'],
#  [94.4, 22.5, 'Klassrum'],
#  [86.1, 21.0, 'Klassrum'],
#  [97.0, 20.8, 'Klassrum'],
#  [50.7, 21.8, 'Lärarrum'],
#  [76.8, 21.9, 'Lärarrum'],
#  [69.1, 20.6, 'Lärarrum'],
#  [74.0, 20.9, 'Lärarrum'],
#  [98.9, 22.4, 'Klassrum'],
#  [67.5, 21.8, 'Lärarrum'],
#  [58.3, 20.2, 'Lärarrum'],
#  [83.6, 20.6, 'Lärarrum'],
#  [83.2, 21.1, 'Lärarrum'],
#  [74.1, 21.1, 'Lärarrum'],
#  [86.2, 20.1, 'Lärarrum'],
#  [53.1, 21.0, 'Lärarrum'],
#  [91.1, 20.8, 'Klassrum'],
#  [84.4, 21.3, 'Lärarrum'],
#  [66.9, 20.3, 'Lärarrum'],
#  [83.8, 22.7, 'Klassrum'],
#  [86.5, 21.9, 'Lärarrum'],
#  [64.9, 20.1, 'Lärarrum'],
#  [69.9, 19.8, 'Lärarrum'],
#  [71.3, 21.8, 'Lärarrum'],
#  [91.1, 20.0, 'Klassrum'],
#  [65.2, 20.7, 'Lärarrum'],
#  [99.3, 23.2, 'Klassrum'],
#  [93.5, 21.1, 'Klassrum'],
#  [88.4, 20.2, 'Lärarrum'],
#  [72.6, 20.5, 'Lärarrum'],
#  [62.6, 20.9, 'Lärarrum'],
#  [63.1, 21.3, 'Lärarrum'],
#  [81.0, 22.9, 'Klassrum'],
#  [94.9, 23.5, 'Klassrum'],
#  [53.8, 19.8, 'Lärarrum'],
#  [87.6, 23.1, 'Klassrum'],
#  [63.2, 21.0, 'Lärarrum'],
#  [96.7, 21.9, 'Klassrum'],
#  [51.6, 19.8, 'Lärarrum'],
#  [67.8, 21.9, 'Lärarrum'],
#  [62.1, 20.4, 'Lärarrum'],
#  [89.3, 21.6, 'Klassrum'],
#  [67.3, 21.8, 'Lärarrum'],
#  [93.5, 22.2, 'Klassrum'],
#  [79.2, 19.9, 'Lärarrum'],
#  [81.2, 19.9, 'Klassrum'],
#  [86.2, 20.9, 'Klassrum'],
#  [94.5, 24.0, 'Klassrum'],
#  [76.8, 21.3, 'Lärarrum'],
#  [79.0, 20.2, 'Lärarrum'],
#  [74.7, 20.1, 'Lärarrum'],
#  [74.5, 20.2, 'Lärarrum'],
#  [82.5, 21.7, 'Lärarrum'],
#  [83.1, 20.0, 'Lärarrum'],
#  [86.1, 20.8, 'Lärarrum'],
#  [94.1, 22.3, 'Klassrum'],
#  [64.3, 21.2, 'Lärarrum'],
#  [56.0, 20.9, 'Lärarrum'],
#  [75.9, 20.2, 'Lärarrum'],
#  [78.5, 19.9, 'Lärarrum'],
#  [56.6, 20.4, 'Lärarrum'],
#  [82.3, 20.9, 'Lärarrum'],
#  [87.4, 22.6, 'Klassrum'],
#  [77.0, 19.8, 'Lärarrum'],
#  [74.3, 20.0, 'Lärarrum'],
#  [54.3, 20.8, 'Lärarrum'],
#  [62.6, 21.9, 'Lärarrum'],
#  [89.4, 21.6, 'Lärarrum'],
#  [87.7, 22.2, 'Klassrum'],
#  [89.7, 23.3, 'Klassrum'],
#  [84.7, 21.3, 'Klassrum'],
#  [94.8, 21.8, 'Klassrum'],
#  [86.1, 20.5, 'Lärarrum'],
#  [87.5, 20.1, 'Klassrum'],
#  [52.8, 19.9, 'Lärarrum'],
#  [98.4, 23.3, 'Klassrum'],
#  [91.9, 22.2, 'Klassrum'],
#  [61.7, 20.1, 'Lärarrum'],
#  [81.4, 19.9, 'Klassrum'],
#  [82.2, 20.4, 'Lärarrum'],
#  [68.2, 20.4, 'Lärarrum'],
#  [71.2, 19.9, 'Lärarrum'],
#  [81.2, 21.9, 'Lärarrum'],
#  [82.1, 21.1, 'Lärarrum'],
#  [81.4, 23.8, 'Klassrum'],
#  [55.9, 21.1, 'Lärarrum'],
#  [52.7, 20.5, 'Lärarrum'],
#  [60.3, 20.7, 'Lärarrum'],
#  [78.5, 21.4, 'Lärarrum'],
#  [80.5, 21.6, 'Lärarrum'],
#  [62.8, 20.5, 'Lärarrum'],
#  [62.9, 21.9, 'Lärarrum'],
#  [83.7, 20.5, 'Klassrum'],
#  [92.6, 23.8, 'Klassrum'],
#  [73.8, 20.9, 'Lärarrum'],
#  [85.1, 21.3, 'Lärarrum'],
#  [67.9, 21.1, 'Lärarrum'],
#  [63.2, 20.8, 'Lärarrum'],
#  [80.2, 21.8, 'Lärarrum'],
#  [88.9, 20.7, 'Lärarrum'],
#  [99.7, 21.7, 'Klassrum'],
#  [97.8, 22.1, 'Klassrum'],
#  [67.9, 20.4, 'Lärarrum'],
#  [62.7, 21.3, 'Lärarrum'],
#  [52.1, 21.5, 'Lärarrum'],
#  [52.6, 21.8, 'Lärarrum'],
#  [90.7, 23.6, 'Klassrum'],
#  [86.4, 19.8, 'Klassrum'],
#  [78.9, 22.0, 'Lärarrum'],
#  [69.8, 21.8, 'Lärarrum'],
#  [89.4, 21.7, 'Lärarrum'],
#  [62.6, 21.6, 'Lärarrum'],
#  [76.2, 21.4, 'Lärarrum'],
#  [88.5, 21.5, 'Klassrum'],
#  [92.6, 22.8, 'Klassrum'],
#  [99.5, 21.9, 'Klassrum'],
#  [78.5, 20.2, 'Lärarrum'],
#  [79.2, 21.9, 'Lärarrum'],
#  [64.3, 21.1, 'Lärarrum'],
#  [69.3, 21.3, 'Lärarrum'],
#  [86.2, 21.9, 'Klassrum'],
#  [72.3, 21.8, 'Lärarrum'],
#  [94.0, 21.2, 'Klassrum'],
#  [63.1, 19.8, 'Lärarrum'],
#  [59.7, 20.8, 'Lärarrum'],
#  [60.8, 20.1, 'Lärarrum'],
#  [72.8, 20.1, 'Lärarrum'],
#  [90.8, 22.4, 'Klassrum'],
#  [55.2, 20.9, 'Lärarrum'],
#  [70.9, 20.3, 'Lärarrum'],
#  [92.5, 21.9, 'Klassrum'],
#  [64.6, 20.9, 'Lärarrum'],
#  [87.9, 21.6, 'Lärarrum'],
#  [67.4, 21.8, 'Lärarrum'],
#  [69.9, 20.7, 'Lärarrum'],
#  [89.1, 23.8, 'Klassrum'],
#  [71.8, 21.8, 'Lärarrum'],
#  [51.5, 19.9, 'Lärarrum'],
#  [86.1, 20.3, 'Klassrum'],
#  [81.6, 20.4, 'Klassrum'],
#  [62.7, 21.4, 'Lärarrum'],
#  [88.9, 20.9, 'Lärarrum'],
#  [96.8, 22.9, 'Klassrum'],
#  [86.2, 21.5, 'Lärarrum'],
#  [85.7, 21.5, 'Klassrum'],
#  [79.5, 19.9, 'Lärarrum'],
#  [62.0, 20.1, 'Lärarrum'],
#  [80.5, 21.0, 'Klassrum'],
#  [95.8, 20.8, 'Klassrum'],
#  [95.1, 22.1, 'Klassrum'],
#  [72.0, 20.4, 'Lärarrum'],
#  [88.7, 20.2, 'Lärarrum'],
#  [81.1, 23.6, 'Klassrum'],
#  [85.0, 21.4, 'Klassrum'],
#  [70.6, 21.7, 'Lärarrum'],
#  [74.6, 20.5, 'Lärarrum'],
#  [84.7, 20.2, 'Lärarrum'],
#  [59.2, 20.8, 'Lärarrum'],
#  [56.3, 21.9, 'Lärarrum'],
#  [59.6, 21.3, 'Lärarrum'],
#  [52.9, 20.5, 'Lärarrum'],
#  [82.8, 20.1, 'Lärarrum'],
#  [83.5, 22.9, 'Klassrum'],
#  [84.6, 21.1, 'Klassrum'],
#  [52.5, 21.0, 'Lärarrum'],
#  [81.0, 22.0, 'Lärarrum'],
#  [96.2, 24.0, 'Klassrum'],
#  [91.4, 22.1, 'Klassrum'],
#  [93.4, 23.2, 'Klassrum'],
#  [69.1, 22.0, 'Lärarrum'],
#  [72.0, 21.5, 'Lärarrum'],
#  [87.1, 20.9, 'Klassrum'],
#  [58.8, 20.7, 'Lärarrum'],
#  [99.6, 22.2, 'Klassrum'],
#  [68.7, 20.8, 'Lärarrum'],
#  [74.8, 20.8, 'Lärarrum'],
#  [62.6, 20.4, 'Lärarrum'],
#  [84.0, 23.0, 'Klassrum'],
#  [60.1, 21.9, 'Lärarrum'],
#  [62.8, 20.1, 'Lärarrum'],
#  [80.7, 21.1, 'Lärarrum'],
#  [63.1, 20.8, 'Lärarrum'],
#  [56.3, 20.3, 'Lärarrum'],
#  [95.1, 19.8, 'Klassrum'],
#  [73.0, 19.9, 'Lärarrum'],
#  [92.9, 21.9, 'Klassrum'],
#  [81.7, 21.7, 'Lärarrum'],
#  [55.0, 20.2, 'Lärarrum'],
#  [68.5, 21.1, 'Lärarrum'],
#  [90.9, 23.8, 'Klassrum'],
#  [72.2, 21.7, 'Lärarrum'],
#  [94.8, 21.6, 'Klassrum'],
#  [66.1, 20.1, 'Lärarrum'],
#  [83.9, 21.8, 'Lärarrum'],
#  [80.5, 21.3, 'Lärarrum'],
#  [65.7, 20.3, 'Lärarrum'],
#  [94.0, 23.2, 'Klassrum'],
#  [80.7, 22.8, 'Klassrum'],
#  [96.1, 21.9, 'Klassrum'],
#  [69.1, 21.2, 'Lärarrum'],
#  [52.3, 19.8, 'Lärarrum'],
#  [76.8, 21.3, 'Lärarrum'],
#  [86.7, 22.7, 'Klassrum'],
#  [69.4, 20.4, 'Lärarrum'],
#  [99.9, 21.0, 'Klassrum'],
#  [53.7, 21.3, 'Lärarrum'],
#  [83.1, 21.9, 'Klassrum'],
#  [79.7, 21.9, 'Lärarrum'],
#  [93.5, 20.1, 'Klassrum'],
#  [79.8, 20.6, 'Lärarrum'],
#  [98.3, 20.4, 'Klassrum'],
#  [86.4, 21.5, 'Lärarrum'],
#  [85.5, 22.8, 'Klassrum'],
#  [65.5, 21.2, 'Lärarrum'],
#  [93.6, 23.1, 'Klassrum'],
#  [82.3, 23.1, 'Klassrum'],
#  [85.6, 21.5, 'Lärarrum'],
#  [99.1, 20.3, 'Klassrum'],
#  [80.5, 20.5, 'Lärarrum'],
#  [88.5, 21.9, 'Lärarrum'],
#  [53.1, 21.5, 'Lärarrum'],
#  [71.5, 20.0, 'Lärarrum'],
#  [83.0, 21.9, 'Lärarrum'],
#  [83.7, 23.6, 'Klassrum'],
#  [57.0, 21.6, 'Lärarrum'],
#  [84.0, 21.5, 'Klassrum'],
#  [56.3, 19.8, 'Lärarrum'],
#  [90.6, 23.1, 'Klassrum'],
#  [75.9, 20.3, 'Lärarrum'],
#  [86.7, 20.2, 'Klassrum'],
#  [62.5, 20.6, 'Lärarrum'],
#  [87.0, 19.8, 'Lärarrum'],
#  [92.3, 21.8, 'Klassrum'],
#  [82.8, 19.8, 'Lärarrum'],
#  [73.4, 21.2, 'Lärarrum'],
#  [88.9, 20.3, 'Klassrum'],
#  [73.8, 20.3, 'Lärarrum'],
#  [95.6, 20.8, 'Klassrum'],
#  [76.5, 20.8, 'Lärarrum'],
#  [62.1, 20.0, 'Lärarrum'],
#  [62.4, 21.3, 'Lärarrum'],
#  [54.9, 21.1, 'Lärarrum'],
#  [98.3, 22.7, 'Klassrum'],
#  [59.9, 20.7, 'Lärarrum'],
#  [78.2, 20.7, 'Lärarrum'],
#  [97.5, 23.2, 'Klassrum'],
#  [53.1, 19.9, 'Lärarrum'],
#  [54.8, 21.2, 'Lärarrum'],
#  [81.1, 21.9, 'Lärarrum'],
#  [88.2, 20.0, 'Klassrum'],
#  [79.8, 21.1, 'Lärarrum'],
#  [60.3, 20.0, 'Lärarrum'],
#  [57.1, 19.8, 'Lärarrum'],
#  [83.7, 20.0, 'Lärarrum'],
#  [78.2, 21.8, 'Lärarrum'],
#  [95.1, 23.9, 'Klassrum'],
#  [81.8, 21.2, 'Lärarrum'],
#  [71.2, 22.0, 'Lärarrum'],
#  [72.8, 21.3, 'Lärarrum'],
#  [80.7, 21.2, 'Lärarrum'],
#  [89.8, 21.4, 'Lärarrum'],
#  [67.5, 21.3, 'Lärarrum'],
#  [83.2, 21.5, 'Klassrum'],
#  [84.6, 21.5, 'Lärarrum'],
#  [76.3, 20.8, 'Lärarrum'],
#  [58.1, 20.2, 'Lärarrum'],
#  [86.4, 23.4, 'Klassrum'],
#  [61.6, 20.8, 'Lärarrum'],
#  [88.1, 19.9, 'Lärarrum'],
#  [88.3, 21.1, 'Lärarrum'],
#  [85.6, 20.9, 'Klassrum'],
#  [50.2, 21.9, 'Lärarrum'],
#  [70.8, 20.0, 'Lärarrum'],
#  [70.8, 21.5, 'Lärarrum'],
#  [71.4, 21.8, 'Lärarrum'],
#  [56.5, 20.1, 'Lärarrum'],
#  [55.6, 19.8, 'Lärarrum'],
#  [88.1, 22.0, 'Lärarrum'],
#  [60.5, 20.9, 'Lärarrum'],
#  [85.9, 21.5, 'Lärarrum'],
#  [83.7, 21.5, 'Lärarrum'],
#  [52.6, 20.9, 'Lärarrum'],
#  [60.3, 20.2, 'Lärarrum'],
#  [88.4, 23.9, 'Klassrum'],
#  [84.3, 22.6, 'Klassrum'],
#  [51.1, 20.3, 'Lärarrum'],
#  [90.3, 20.6, 'Klassrum'],
#  [71.4, 20.1, 'Lärarrum'],
#  [78.7, 21.0, 'Lärarrum'],
#  [71.3, 20.6, 'Lärarrum'],
#  [82.3, 20.1, 'Lärarrum'],
#  [99.1, 22.9, 'Klassrum'],
#  [66.0, 19.9, 'Lärarrum'],
#  [92.3, 22.9, 'Klassrum'],
#  [82.9, 20.4, 'Klassrum'],
#  [83.0, 23.9, 'Klassrum'],
#  [91.3, 20.5, 'Klassrum'],
#  [62.0, 21.5, 'Lärarrum'],
#  [83.6, 20.6, 'Klassrum'],
#  [85.1, 20.3, 'Klassrum'],
#  [83.3, 22.7, 'Klassrum'],
#  [52.1, 21.4, 'Lärarrum'],
#  [83.2, 21.5, 'Lärarrum'],
#  [94.5, 20.0, 'Klassrum'],
#  [84.5, 22.9, 'Klassrum'],
#  [89.2, 21.4, 'Lärarrum'],
#  [60.8, 21.4, 'Lärarrum'],
#  [91.9, 22.0, 'Klassrum'],
#  [66.7, 20.5, 'Lärarrum'],
#  [72.0, 20.3, 'Lärarrum'],
#  [69.2, 21.2, 'Lärarrum'],
#  [76.3, 21.6, 'Lärarrum'],
#  [84.7, 20.3, 'Lärarrum'],
#  [85.2, 21.5, 'Lärarrum'],
#  [54.6, 21.9, 'Lärarrum'],
#  [93.1, 20.5, 'Klassrum'],
#  [84.5, 21.2, 'Klassrum'],
#  [59.2, 21.1, 'Lärarrum'],
#  [87.0, 23.2, 'Klassrum'],
#  [61.7, 21.2, 'Lärarrum'],
#  [67.3, 20.4, 'Lärarrum'],
#  [83.1, 21.2, 'Klassrum'],
#  [51.1, 20.9, 'Lärarrum'],
#  [62.9, 20.8, 'Lärarrum'],
#  [89.0, 20.0, 'Lärarrum'],
#  [65.4, 21.7, 'Lärarrum'],
#  [55.0, 19.9, 'Lärarrum'],
#  [92.8, 20.2, 'Klassrum'],
#  [81.4, 22.0, 'Lärarrum'],
#  [57.3, 21.1, 'Lärarrum'],
#  [64.6, 19.8, 'Lärarrum'],
#  [86.4, 21.8, 'Lärarrum'],
#  [84.2, 20.3, 'Klassrum'],
#  [89.9, 21.4, 'Klassrum'],
#  [88.5, 20.0, 'Lärarrum'],
#  [78.9, 20.8, 'Lärarrum'],
#  [78.0, 20.6, 'Lärarrum'],
#  [85.9, 22.9, 'Klassrum'],
#  [53.6, 20.8, 'Lärarrum'],
#  [89.2, 23.6, 'Klassrum'],
#  [83.6, 22.9, 'Klassrum'],
#  [89.9, 20.7, 'Lärarrum'],
#  [85.6, 21.0, 'Lärarrum'],
#  [85.9, 20.8, 'Klassrum'],
#  [52.9, 21.2, 'Lärarrum'],
#  [83.8, 23.8, 'Klassrum'],
#  [55.2, 20.2, 'Lärarrum'],
#  [59.9, 21.4, 'Lärarrum'],
#  [79.1, 21.0, 'Lärarrum'],
#  [84.7, 23.9, 'Klassrum'],
#  [93.1, 21.8, 'Klassrum'],
#  [64.2, 20.9, 'Lärarrum'],
#  [70.1, 21.5, 'Lärarrum'],
#  [84.0, 21.2, 'Lärarrum'],
#  [87.6, 21.9, 'Klassrum'],
#  [77.9, 21.0, 'Lärarrum'],
#  [64.7, 20.3, 'Lärarrum'],
#  [90.3, 21.8, 'Klassrum'],
#  [94.9, 20.6, 'Klassrum'],
#  [80.5, 19.9, 'Lärarrum'],
#  [86.8, 20.6, 'Lärarrum'],
#  [81.7, 23.6, 'Klassrum'],
#  [66.6, 20.2, 'Lärarrum'],
#  [58.4, 21.6, 'Lärarrum'],
#  [52.6, 21.8, 'Lärarrum'],
#  [63.4, 20.6, 'Lärarrum'],
#  [98.3, 23.5, 'Klassrum'],
#  [52.7, 21.8, 'Lärarrum'],
#  [65.1, 21.5, 'Lärarrum'],
#  [79.7, 21.3, 'Lärarrum'],
#  [59.8, 20.6, 'Lärarrum'],
#  [61.1, 21.0, 'Lärarrum'],
#  [60.7, 20.8, 'Lärarrum'],
#  [99.0, 20.0, 'Klassrum'],
#  [96.7, 22.0, 'Klassrum'],
#  [57.9, 20.3, 'Lärarrum'],
#  [54.1, 21.1, 'Lärarrum'],
#  [53.7, 20.7, 'Lärarrum'],
#  [60.0, 20.5, 'Lärarrum'],
#  [86.4, 21.1, 'Lärarrum'],
#  [71.6, 21.9, 'Lärarrum'],
#  [78.2, 19.8, 'Lärarrum'],
#  [98.3, 21.3, 'Klassrum'],
#  [82.3, 20.4, 'Klassrum'],
#  [56.4, 20.8, 'Lärarrum'],
#  [92.2, 21.0, 'Klassrum'],
#  [89.4, 20.6, 'Lärarrum'],
#  [66.7, 19.8, 'Lärarrum'],
#  [74.4, 21.4, 'Lärarrum'],
#  [88.3, 23.5, 'Klassrum'],
#  [59.7, 19.8, 'Lärarrum'],
#  [81.9, 20.7, 'Klassrum'],
#  [94.6, 22.6, 'Klassrum'],
#  [66.9, 19.9, 'Lärarrum'],
#  [81.3, 21.8, 'Lärarrum'],
#  [58.1, 21.9, 'Lärarrum'],
#  [66.0, 20.4, 'Lärarrum'],
#  [54.6, 21.3, 'Lärarrum'],
#  [50.6, 21.2, 'Lärarrum'],
#  [56.1, 21.5, 'Lärarrum'],
#  [69.3, 20.0, 'Lärarrum'],
#  [95.4, 20.5, 'Klassrum'],
#  [63.5, 19.9, 'Lärarrum'],
#  [69.3, 21.8, 'Lärarrum'],
#  [95.5, 21.5, 'Klassrum'],
#  [84.9, 20.0, 'Klassrum'],
#  [84.7, 22.1, 'Klassrum'],
#  [84.7, 19.8, 'Lärarrum'],
#  [72.5, 21.8, 'Lärarrum'],
#  [64.7, 21.4, 'Lärarrum'],
#  [63.7, 20.7, 'Lärarrum'],
#  [82.4, 23.8, 'Klassrum'],
#  [67.1, 19.9, 'Lärarrum'],
#  [85.6, 20.9, 'Klassrum'],
#  [55.4, 22.0, 'Lärarrum'],
#  [84.8, 20.1, 'Lärarrum'],
#  [88.2, 22.8, 'Klassrum'],
#  [74.1, 21.2, 'Lärarrum'],
#  [86.8, 20.7, 'Klassrum'],
#  [76.8, 21.9, 'Lärarrum'],
#  [99.9, 21.1, 'Klassrum'],
#  [87.4, 19.8, 'Klassrum'],
#  [80.2, 21.4, 'Klassrum'],
#  [86.7, 20.6, 'Lärarrum'],
#  [95.0, 22.8, 'Klassrum'],
#  [80.8, 21.5, 'Klassrum'],
#  [92.1, 21.0, 'Klassrum'],
#  [77.7, 22.0, 'Lärarrum'],
#  [65.6, 21.4, 'Lärarrum'],
#  [81.5, 19.8, 'Lärarrum'],
#  [86.5, 21.3, 'Lärarrum'],
#  [94.1, 20.3, 'Klassrum'],
#  [56.1, 20.0, 'Lärarrum'],
#  [64.4, 21.9, 'Lärarrum'],
#  [84.9, 20.5, 'Klassrum'],
#  [52.9, 21.5, 'Lärarrum'],
#  [79.4, 19.9, 'Lärarrum'],
#  [65.4, 21.7, 'Lärarrum'],
#  [93.6, 23.8, 'Klassrum'],
#  [63.2, 20.9, 'Lärarrum'],
#  [86.4, 22.0, 'Klassrum'],
#  [71.8, 20.2, 'Lärarrum'],
#  [84.5, 21.1, 'Lärarrum'],
#  [87.1, 23.5, 'Klassrum'],
#  [54.5, 20.7, 'Lärarrum'],
#  [88.1, 23.6, 'Klassrum'],
#  [80.3, 20.1, 'Klassrum'],
#  [65.4, 20.1, 'Lärarrum'],
#  [81.2, 21.4, 'Klassrum'],
#  [96.8, 20.2, 'Klassrum'],
#  [81.1, 21.6, 'Klassrum'],
#  [92.3, 21.1, 'Klassrum'],
#  [89.1, 23.9, 'Klassrum'],
#  [71.0, 21.9, 'Lärarrum'],
#  [82.7, 21.5, 'Lärarrum'],
#  [54.2, 21.8, 'Lärarrum'],
#  [85.2, 20.3, 'Lärarrum'],
#  [51.8, 21.4, 'Lärarrum'],
#  [81.5, 21.3, 'Klassrum'],
#  [76.2, 19.9, 'Lärarrum'],
#  [86.5, 21.5, 'Lärarrum'],
#  [73.8, 19.9, 'Lärarrum'],
#  [84.1, 21.8, 'Klassrum'],
#  [85.3, 20.3, 'Klassrum'],
#  [59.3, 20.7, 'Lärarrum'],
#  [56.0, 21.2, 'Lärarrum'],
#  [68.5, 20.3, 'Lärarrum'],
#  [89.0, 21.5, 'Klassrum'],
#  [83.2, 21.5, 'Lärarrum'],
#  [53.6, 20.5, 'Lärarrum'],
#  [63.2, 20.7, 'Lärarrum'],
#  [76.7, 21.9, 'Lärarrum'],
#  [65.8, 21.1, 'Lärarrum'],
#  [55.4, 21.9, 'Lärarrum'],
#  [52.6, 21.4, 'Lärarrum'],
#  [97.0, 22.5, 'Klassrum'],
#  [98.7, 22.0, 'Klassrum'],
#  [69.8, 21.3, 'Lärarrum'],
#  [83.4, 21.2, 'Lärarrum'],
#  [73.6, 21.0, 'Lärarrum'],
#  [51.9, 21.1, 'Lärarrum'],
#  [66.9, 20.7, 'Lärarrum'],
#  [81.6, 22.8, 'Klassrum'],
#  [79.2, 19.8, 'Lärarrum'],
#  [75.6, 19.9, 'Lärarrum'],
#  [77.2, 21.6, 'Lärarrum'],
#  [82.5, 20.6, 'Lärarrum'],
#  [66.5, 21.0, 'Lärarrum'],
#  [98.8, 22.1, 'Klassrum'],
#  [96.0, 21.4, 'Klassrum'],
#  [56.1, 21.0, 'Lärarrum'],
#  [99.3, 22.8, 'Klassrum'],
#  [69.3, 20.2, 'Lärarrum'],
#  [98.4, 20.4, 'Klassrum'],
#  [87.9, 22.0, 'Klassrum'],
#  [58.2, 21.1, 'Lärarrum'],
#  [83.2, 19.8, 'Lärarrum'],
#  [68.1, 22.0, 'Lärarrum'],
#  [76.9, 20.7, 'Lärarrum'],
#  [89.5, 19.8, 'Lärarrum'],
#  [65.4, 21.9, 'Lärarrum'],
#  [86.4, 21.1, 'Klassrum'],
#  [53.6, 19.9, 'Lärarrum'],
#  [50.9, 20.8, 'Lärarrum'],
#  [76.5, 20.4, 'Lärarrum'],
#  [52.0, 20.5, 'Lärarrum'],
#  [63.6, 20.5, 'Lärarrum'],
#  [76.6, 21.9, 'Lärarrum'],
#  [96.4, 21.7, 'Klassrum'],
#  [62.0, 21.7, 'Lärarrum'],
#  [69.9, 21.6, 'Lärarrum'],
#  [89.0, 20.5, 'Klassrum'],
#  [97.0, 22.0, 'Klassrum'],
#  [89.1, 20.9, 'Lärarrum'],
#  [77.6, 22.0, 'Lärarrum'],
#  [67.6, 21.3, 'Lärarrum'],
#  [65.4, 19.9, 'Lärarrum'],
#  [90.6, 23.3, 'Klassrum'],
#  [76.4, 21.0, 'Lärarrum'],
#  [76.5, 20.3, 'Lärarrum'],
#  [75.5, 20.2, 'Lärarrum'],
#  [53.2, 20.6, 'Lärarrum'],
#  [99.5, 22.5, 'Klassrum'],
#  [88.3, 20.7, 'Lärarrum'],
#  [96.5, 19.8, 'Klassrum'],
#  [91.9, 19.8, 'Klassrum'],
#  [73.4, 20.2, 'Lärarrum'],
#  [80.0, 21.1, 'Lärarrum'],
#  [87.7, 19.8, 'Klassrum'],
#  [88.0, 20.6, 'Lärarrum'],
#  [96.7, 20.3, 'Klassrum'],
#  [92.0, 23.1, 'Klassrum'],
#  [88.4, 20.2, 'Lärarrum']]

# %%
# And the false rows contain two types of fruit. Not too bad.
false_rows
# Out:
# [[43.8, 11.3, 'Kylrum'],
#  [64.6, 19.5, 'Lärarrum'],
#  [71.6, 19.2, 'Lärarrum'],
#  [72.2, 16.2, 'Lärarrum'],
#  [38.7, 13.1, 'Kylrum'],
#  [63.6, 17.7, 'Lärarrum'],
#  [39.2, 15.1, 'Kylrum'],
#  [38.8, 15.8, 'Kylrum'],
#  [48.0, 11.0, 'Kylrum'],
#  [41.6, 13.7, 'Kylrum'],
#  [98.5, 19.3, 'Klassrum'],
#  [50.6, 17.1, 'Lärarrum'],
#  [24.4, 11.1, 'Kylrum'],
#  [78.8, 16.7, 'Lärarrum'],
#  [65.0, 19.6, 'Lärarrum'],
#  [64.2, 17.7, 'Lärarrum'],
#  [76.9, 17.3, 'Lärarrum'],
#  [75.6, 16.7, 'Lärarrum'],
#  [88.1, 18.8, 'Lärarrum'],
#  [52.4, 17.7, 'Lärarrum'],
#  [93.9, 18.2, 'Klassrum'],
#  [51.8, 14.9, 'Kylrum'],
#  [50.9, 15.6, 'Kylrum'],
#  [80.0, 16.7, 'Lärarrum'],
#  [56.8, 19.3, 'Lärarrum'],
#  [57.1, 19.3, 'Lärarrum'],
#  [88.3, 16.3, 'Lärarrum'],
#  [48.7, 12.9, 'Kylrum'],
#  [45.2, 12.3, 'Kylrum'],
#  [81.0, 16.9, 'Lärarrum'],
#  [50.4, 15.4, 'Kylrum'],
#  [29.3, 14.4, 'Kylrum'],
#  [81.4, 18.8, 'Lärarrum'],
#  [38.9, 15.2, 'Kylrum'],
#  [59.9, 19.3, 'Lärarrum'],
#  [76.4, 17.1, 'Lärarrum'],
#  [50.4, 19.3, 'Lärarrum'],
#  [89.7, 18.6, 'Klassrum'],
#  [29.8, 13.0, 'Kylrum'],
#  [59.2, 16.7, 'Lärarrum'],
#  [29.3, 14.6, 'Kylrum'],
#  [73.2, 18.2, 'Lärarrum'],
#  [88.7, 16.7, 'Lärarrum'],
#  [80.7, 16.2, 'Lärarrum'],
#  [66.7, 18.4, 'Lärarrum'],
#  [47.9, 15.1, 'Kylrum'],
#  [42.4, 11.6, 'Kylrum'],
#  [21.6, 12.0, 'Kylrum'],
#  [87.1, 17.1, 'Lärarrum'],
#  [62.2, 18.3, 'Lärarrum'],
#  [84.9, 16.9, 'Lärarrum'],
#  [86.2, 18.7, 'Klassrum'],
#  [79.5, 17.6, 'Lärarrum'],
#  [25.0, 14.5, 'Kylrum'],
#  [75.5, 17.2, 'Lärarrum'],
#  [30.0, 15.6, 'Kylrum'],
#  [67.9, 17.8, 'Lärarrum'],
#  [20.9, 10.2, 'Kylrum'],
#  [32.1, 14.9, 'Kylrum'],
#  [61.2, 16.1, 'Lärarrum'],
#  [30.9, 12.5, 'Kylrum'],
#  [51.2, 15.6, 'Kylrum'],
#  [26.5, 10.7, 'Kylrum'],
#  [86.2, 19.7, 'Lärarrum'],
#  [35.6, 10.3, 'Kylrum'],
#  [49.4, 10.9, 'Kylrum'],
#  [19.1, 11.6, 'Kylrum'],
#  [62.2, 16.6, 'Lärarrum'],
#  [76.0, 16.0, 'Lärarrum'],
#  [59.3, 18.7, 'Lärarrum'],
#  [54.0, 16.9, 'Lärarrum'],
#  [21.6, 15.8, 'Kylrum'],
#  [29.0, 14.4, 'Kylrum'],
#  [79.3, 19.2, 'Lärarrum'],
#  [72.9, 17.9, 'Lärarrum'],
#  [27.9, 15.9, 'Kylrum'],
#  [53.0, 11.8, 'Kylrum'],
#  [77.5, 19.6, 'Lärarrum'],
#  [81.8, 18.7, 'Lärarrum'],
#  [55.5, 13.0, 'Kylrum'],
#  [35.2, 14.7, 'Kylrum'],
#  [26.2, 12.1, 'Kylrum'],
#  [68.1, 19.7, 'Lärarrum'],
#  [51.2, 18.7, 'Lärarrum'],
#  [24.4, 14.7, 'Kylrum'],
#  [26.7, 11.4, 'Kylrum'],
#  [96.4, 19.2, 'Klassrum'],
#  [30.3, 15.9, 'Kylrum'],
#  [15.8, 15.9, 'Kylrum'],
#  [85.8, 18.3, 'Lärarrum'],
#  [27.9, 15.3, 'Kylrum'],
#  [56.2, 15.9, 'Kylrum'],
#  [40.6, 15.4, 'Kylrum'],
#  [54.1, 16.2, 'Lärarrum'],
#  [51.9, 18.6, 'Lärarrum'],
#  [73.5, 18.0, 'Lärarrum'],
#  [54.1, 12.8, 'Kylrum'],
#  [36.7, 15.6, 'Kylrum'],
#  [57.1, 18.6, 'Lärarrum'],
#  [89.8, 19.3, 'Lärarrum'],
#  [50.5, 11.6, 'Kylrum'],
#  [77.3, 16.8, 'Lärarrum'],
#  [82.8, 16.9, 'Lärarrum'],
#  [82.6, 18.1, 'Klassrum'],
#  [78.3, 16.7, 'Lärarrum'],
#  [69.7, 16.2, 'Lärarrum'],
#  [74.3, 18.7, 'Lärarrum'],
#  [86.6, 19.0, 'Klassrum'],
#  [80.5, 18.0, 'Lärarrum'],
#  [63.9, 16.8, 'Lärarrum'],
#  [72.9, 17.0, 'Lärarrum'],
#  [64.1, 16.8, 'Lärarrum'],
#  [74.7, 16.4, 'Lärarrum'],
#  [54.3, 19.2, 'Lärarrum'],
#  [65.3, 17.9, 'Lärarrum'],
#  [49.6, 13.5, 'Kylrum'],
#  [50.9, 19.3, 'Lärarrum'],
#  [45.4, 12.3, 'Kylrum'],
#  [78.5, 16.1, 'Lärarrum'],
#  [82.9, 19.7, 'Klassrum'],
#  [41.6, 15.0, 'Kylrum'],
#  [87.0, 18.2, 'Klassrum'],
#  [71.1, 16.4, 'Lärarrum'],
#  [89.1, 18.9, 'Lärarrum'],
#  [69.8, 16.2, 'Lärarrum'],
#  [18.6, 12.3, 'Kylrum'],
#  [51.0, 18.6, 'Lärarrum'],
#  [88.6, 18.8, 'Lärarrum'],
#  [51.7, 16.8, 'Lärarrum'],
#  [75.4, 19.2, 'Lärarrum'],
#  [54.1, 18.3, 'Lärarrum'],
#  [68.0, 17.7, 'Lärarrum'],
#  [81.0, 18.0, 'Klassrum'],
#  [17.2, 14.5, 'Kylrum'],
#  [37.5, 13.7, 'Kylrum'],
#  [79.7, 18.8, 'Lärarrum'],
#  [23.6, 12.9, 'Kylrum'],
#  [74.4, 19.7, 'Lärarrum'],
#  [79.4, 17.4, 'Lärarrum'],
#  [22.1, 15.7, 'Kylrum'],
#  [29.6, 13.0, 'Kylrum'],
#  [40.9, 10.7, 'Kylrum'],
#  [47.1, 13.7, 'Kylrum'],
#  [77.2, 16.1, 'Lärarrum'],
#  [16.1, 10.3, 'Kylrum'],
#  [43.2, 10.7, 'Kylrum'],
#  [73.8, 18.4, 'Lärarrum'],
#  [22.9, 13.0, 'Kylrum'],
#  [31.7, 14.1, 'Kylrum'],
#  [52.1, 17.9, 'Lärarrum'],
#  [86.3, 18.0, 'Lärarrum'],
#  [82.3, 16.9, 'Lärarrum'],
#  [19.4, 12.9, 'Kylrum'],
#  [83.1, 18.2, 'Klassrum'],
#  [55.9, 19.1, 'Lärarrum'],
#  [43.5, 13.1, 'Kylrum'],
#  [72.5, 18.3, 'Lärarrum'],
#  [83.1, 16.8, 'Lärarrum'],
#  [81.1, 19.3, 'Klassrum'],
#  [70.0, 17.7, 'Lärarrum'],
#  [43.3, 13.2, 'Kylrum'],
#  [37.9, 12.1, 'Kylrum'],
#  [82.6, 19.6, 'Lärarrum'],
#  [71.3, 18.4, 'Lärarrum'],
#  [76.9, 18.8, 'Lärarrum'],
#  [45.5, 13.9, 'Kylrum'],
#  [79.1, 16.7, 'Lärarrum'],
#  [50.4, 17.2, 'Lärarrum'],
#  [52.7, 16.0, 'Kylrum'],
#  [44.2, 12.2, 'Kylrum'],
#  [33.8, 13.0, 'Kylrum'],
#  [40.4, 11.9, 'Kylrum'],
#  [47.0, 14.6, 'Kylrum'],
#  [37.6, 14.4, 'Kylrum'],
#  [27.4, 13.7, 'Kylrum'],
#  [42.0, 11.8, 'Kylrum'],
#  [25.4, 15.8, 'Kylrum'],
#  [84.1, 17.1, 'Lärarrum'],
#  [45.1, 10.5, 'Kylrum'],
#  [29.8, 15.7, 'Kylrum'],
#  [73.7, 18.4, 'Lärarrum'],
#  [87.7, 17.8, 'Lärarrum'],
#  [38.5, 15.0, 'Kylrum'],
#  [48.7, 12.5, 'Kylrum'],
#  [74.3, 18.6, 'Lärarrum'],
#  [24.3, 15.5, 'Kylrum'],
#  [24.3, 11.7, 'Kylrum'],
#  [74.6, 18.0, 'Lärarrum'],
#  [82.7, 18.1, 'Lärarrum'],
#  [89.6, 19.5, 'Lärarrum'],
#  [56.7, 17.9, 'Lärarrum'],
#  [60.0, 10.3, 'Kylrum'],
#  [57.7, 19.5, 'Lärarrum'],
#  [86.9, 16.1, 'Lärarrum'],
#  [31.2, 15.1, 'Kylrum'],
#  [59.8, 17.3, 'Lärarrum'],
#  [47.2, 11.6, 'Kylrum'],
#  [50.9, 17.4, 'Lärarrum'],
#  [33.7, 15.0, 'Kylrum'],
#  [57.6, 17.8, 'Lärarrum'],
#  [54.8, 10.3, 'Kylrum'],
#  [52.5, 17.7, 'Lärarrum'],
#  [92.9, 19.5, 'Klassrum'],
#  [44.5, 15.4, 'Kylrum'],
#  [81.8, 19.6, 'Lärarrum'],
#  [54.1, 14.4, 'Kylrum'],
#  [29.8, 11.7, 'Kylrum'],
#  [52.3, 11.9, 'Kylrum'],
#  [48.2, 11.4, 'Kylrum'],
#  [33.7, 11.0, 'Kylrum'],
#  [66.2, 19.1, 'Lärarrum'],
#  [24.8, 10.4, 'Kylrum'],
#  [23.8, 13.7, 'Kylrum'],
#  [86.7, 16.9, 'Lärarrum'],
#  [48.8, 10.9, 'Kylrum'],
#  [74.3, 16.4, 'Lärarrum'],
#  [44.7, 15.3, 'Kylrum'],
#  [55.1, 18.7, 'Lärarrum'],
#  [80.3, 19.0, 'Lärarrum'],
#  [45.7, 13.5, 'Kylrum'],
#  [60.5, 17.0, 'Lärarrum'],
#  [55.6, 17.1, 'Lärarrum'],
#  [84.0, 18.0, 'Lärarrum'],
#  [60.5, 17.2, 'Lärarrum'],
#  [85.1, 16.8, 'Lärarrum'],
#  [84.6, 17.9, 'Lärarrum'],
#  [56.3, 13.9, 'Kylrum'],
#  [65.3, 16.5, 'Lärarrum'],
#  [53.1, 16.8, 'Lärarrum'],
#  [28.4, 13.9, 'Kylrum'],
#  [26.4, 15.6, 'Kylrum'],
#  [52.4, 14.4, 'Kylrum'],
#  [59.4, 19.6, 'Lärarrum'],
#  [20.4, 13.2, 'Kylrum'],
#  [93.2, 18.7, 'Klassrum'],
#  [95.6, 19.6, 'Klassrum'],
#  [31.5, 10.6, 'Kylrum'],
#  [89.5, 19.7, 'Lärarrum'],
#  [55.9, 18.7, 'Lärarrum'],
#  [63.7, 19.1, 'Lärarrum'],
#  [23.6, 12.7, 'Kylrum'],
#  [35.3, 14.8, 'Kylrum'],
#  [70.7, 18.9, 'Lärarrum'],
#  [72.9, 19.7, 'Lärarrum'],
#  [91.7, 18.9, 'Klassrum'],
#  [97.5, 18.7, 'Klassrum'],
#  [89.8, 19.1, 'Lärarrum'],
#  [56.8, 10.5, 'Kylrum'],
#  [61.6, 16.5, 'Lärarrum'],
#  [93.5, 18.2, 'Klassrum'],
#  [99.5, 19.1, 'Klassrum'],
#  [27.6, 12.4, 'Kylrum'],
#  [41.8, 12.0, 'Kylrum'],
#  [26.3, 15.4, 'Kylrum'],
#  [81.9, 18.0, 'Lärarrum'],
#  [32.4, 11.4, 'Kylrum'],
#  [36.4, 13.6, 'Kylrum'],
#  [25.9, 13.9, 'Kylrum'],
#  [98.8, 18.8, 'Klassrum'],
#  [80.3, 19.0, 'Klassrum'],
#  [25.5, 14.6, 'Kylrum'],
#  [51.2, 11.6, 'Kylrum'],
#  [84.2, 18.5, 'Klassrum'],
#  [76.9, 17.9, 'Lärarrum'],
#  [54.0, 16.7, 'Lärarrum'],
#  [39.5, 13.2, 'Kylrum'],
#  [26.8, 12.6, 'Kylrum'],
#  [16.9, 15.2, 'Kylrum'],
#  [97.3, 18.6, 'Klassrum'],
#  [55.8, 18.9, 'Lärarrum'],
#  [58.2, 17.0, 'Lärarrum'],
#  [44.6, 15.2, 'Kylrum'],
#  [32.4, 12.1, 'Kylrum'],
#  [33.8, 11.1, 'Kylrum'],
#  [89.3, 17.4, 'Lärarrum'],
#  [63.9, 19.1, 'Lärarrum'],
#  [27.4, 15.2, 'Kylrum'],
#  [27.6, 14.6, 'Kylrum'],
#  [38.1, 10.3, 'Kylrum'],
#  [23.8, 13.8, 'Kylrum'],
#  [86.3, 17.8, 'Lärarrum'],
#  [53.7, 18.9, 'Lärarrum'],
#  [67.3, 17.1, 'Lärarrum'],
#  [34.7, 10.0, 'Kylrum'],
#  [78.5, 18.3, 'Lärarrum'],
#  [55.2, 16.8, 'Lärarrum'],
#  [80.4, 18.5, 'Lärarrum'],
#  [79.5, 17.0, 'Lärarrum'],
#  [57.9, 19.6, 'Lärarrum'],
#  [67.3, 17.2, 'Lärarrum'],
#  [74.3, 19.6, 'Lärarrum'],
#  [50.8, 17.2, 'Lärarrum'],
#  [58.1, 17.8, 'Lärarrum'],
#  [26.3, 11.6, 'Kylrum'],
#  [23.3, 12.0, 'Kylrum'],
#  [57.6, 12.3, 'Kylrum'],
#  [81.2, 16.3, 'Lärarrum'],
#  [43.4, 10.1, 'Kylrum'],
#  [52.7, 12.0, 'Kylrum'],
#  [19.9, 11.4, 'Kylrum'],
#  [83.4, 18.1, 'Lärarrum'],
#  [73.7, 16.9, 'Lärarrum'],
#  [49.4, 12.4, 'Kylrum'],
#  [31.0, 11.0, 'Kylrum'],
#  [20.9, 10.5, 'Kylrum'],
#  [58.9, 18.8, 'Lärarrum'],
#  [65.0, 18.7, 'Lärarrum'],
#  [71.0, 19.3, 'Lärarrum'],
#  [86.6, 17.9, 'Lärarrum'],
#  [74.7, 18.9, 'Lärarrum'],
#  [55.4, 16.6, 'Lärarrum'],
#  [96.5, 18.4, 'Klassrum'],
#  [83.1, 19.6, 'Lärarrum'],
#  [59.7, 10.5, 'Kylrum'],
#  [89.5, 18.2, 'Klassrum'],
#  [66.7, 16.8, 'Lärarrum'],
#  [57.8, 16.4, 'Lärarrum'],
#  [54.4, 11.9, 'Kylrum'],
#  [64.9, 17.7, 'Lärarrum'],
#  [30.4, 15.7, 'Kylrum'],
#  [52.1, 15.0, 'Kylrum'],
#  [69.7, 19.1, 'Lärarrum'],
#  [90.7, 19.5, 'Klassrum'],
#  [23.6, 14.5, 'Kylrum'],
#  [29.7, 11.6, 'Kylrum'],
#  [58.8, 17.9, 'Lärarrum'],
#  [35.7, 16.0, 'Kylrum'],
#  [90.5, 18.5, 'Klassrum'],
#  [21.6, 14.8, 'Kylrum'],
#  [50.8, 18.2, 'Lärarrum'],
#  [55.2, 14.6, 'Kylrum'],
#  [71.0, 18.9, 'Lärarrum'],
#  [68.0, 18.6, 'Lärarrum'],
#  [53.0, 12.3, 'Kylrum'],
#  [86.4, 16.3, 'Lärarrum'],
#  [55.9, 16.9, 'Lärarrum'],
#  [87.4, 16.6, 'Lärarrum'],
#  [51.1, 15.6, 'Kylrum'],
#  [51.9, 18.3, 'Lärarrum'],
#  [62.8, 18.8, 'Lärarrum'],
#  [54.2, 17.4, 'Lärarrum'],
#  [42.7, 11.2, 'Kylrum'],
#  [55.9, 16.3, 'Lärarrum'],
#  [70.1, 16.6, 'Lärarrum'],
#  [53.9, 13.7, 'Kylrum'],
#  [27.1, 10.5, 'Kylrum'],
#  [52.0, 16.8, 'Lärarrum'],
#  [31.4, 12.6, 'Kylrum'],
#  [83.1, 19.0, 'Lärarrum'],
#  [36.2, 14.3, 'Kylrum'],
#  [32.1, 13.1, 'Kylrum'],
#  [82.5, 19.0, 'Lärarrum'],
#  [47.2, 10.5, 'Kylrum'],
#  [73.5, 17.8, 'Lärarrum'],
#  [63.1, 17.1, 'Lärarrum'],
#  [21.1, 12.5, 'Kylrum'],
#  [80.6, 16.5, 'Lärarrum'],
#  [65.9, 16.9, 'Lärarrum'],
#  [73.9, 16.2, 'Lärarrum'],
#  [48.5, 11.7, 'Kylrum'],
#  [22.5, 10.7, 'Kylrum'],
#  [30.5, 15.9, 'Kylrum'],
#  [94.1, 19.7, 'Klassrum'],
#  [53.9, 15.5, 'Kylrum'],
#  [59.8, 10.8, 'Kylrum'],
#  [56.0, 19.0, 'Lärarrum'],
#  [66.3, 18.9, 'Lärarrum'],
#  [17.3, 10.7, 'Kylrum'],
#  [30.0, 13.2, 'Kylrum'],
#  [35.2, 14.9, 'Kylrum'],
#  [40.6, 12.5, 'Kylrum'],
#  [57.2, 15.7, 'Kylrum'],
#  [30.3, 15.2, 'Kylrum'],
#  [87.4, 18.4, 'Klassrum'],
#  [24.9, 10.8, 'Kylrum'],
#  [62.8, 17.0, 'Lärarrum'],
#  [80.0, 17.0, 'Lärarrum'],
#  [15.6, 10.8, 'Kylrum'],
#  [68.4, 19.4, 'Lärarrum'],
#  [55.4, 12.5, 'Kylrum'],
#  [80.2, 19.2, 'Klassrum'],
#  [73.8, 18.3, 'Lärarrum'],
#  [33.4, 10.6, 'Kylrum'],
#  [80.3, 16.5, 'Lärarrum'],
#  [57.1, 18.8, 'Lärarrum'],
#  [28.4, 14.2, 'Kylrum'],
#  [59.1, 14.8, 'Kylrum'],
#  [42.5, 11.8, 'Kylrum'],
#  [43.3, 12.9, 'Kylrum'],
#  [65.1, 17.0, 'Lärarrum'],
#  [83.0, 19.0, 'Lärarrum'],
#  [20.6, 10.4, 'Kylrum'],
#  [71.1, 19.5, 'Lärarrum'],
#  [59.8, 18.6, 'Lärarrum'],
#  [85.7, 16.9, 'Lärarrum'],
#  [66.6, 18.6, 'Lärarrum'],
#  [72.8, 17.0, 'Lärarrum'],
#  [37.8, 13.6, 'Kylrum'],
#  [80.5, 18.0, 'Lärarrum'],
#  [74.7, 17.4, 'Lärarrum'],
#  [88.3, 17.8, 'Lärarrum'],
#  [22.1, 15.6, 'Kylrum'],
#  [49.8, 14.5, 'Kylrum'],
#  [32.5, 16.0, 'Kylrum'],
#  [58.3, 15.4, 'Kylrum'],
#  [41.9, 12.0, 'Kylrum'],
#  [80.3, 18.7, 'Klassrum'],
#  [30.6, 15.4, 'Kylrum'],
#  [50.7, 11.7, 'Kylrum'],
#  [82.6, 16.3, 'Lärarrum'],
#  [48.5, 13.3, 'Kylrum'],
#  [30.2, 13.3, 'Kylrum'],
#  [56.2, 16.6, 'Lärarrum'],
#  [69.0, 16.4, 'Lärarrum'],
#  [79.1, 17.3, 'Lärarrum'],
#  [81.2, 16.8, 'Lärarrum'],
#  [60.9, 16.4, 'Lärarrum'],
#  [77.8, 16.4, 'Lärarrum'],
#  [35.6, 10.9, 'Kylrum'],
#  [24.6, 13.8, 'Kylrum'],
#  [72.3, 17.3, 'Lärarrum'],
#  [20.1, 16.0, 'Kylrum'],
#  [82.5, 17.9, 'Lärarrum'],
#  [26.6, 10.1, 'Kylrum'],
#  [86.7, 19.3, 'Lärarrum'],
#  [95.1, 18.1, 'Klassrum'],
#  [46.7, 13.7, 'Kylrum'],
#  [61.0, 17.7, 'Lärarrum'],
#  [86.0, 17.8, 'Lärarrum'],
#  [48.1, 14.7, 'Kylrum'],
#  [68.0, 16.1, 'Lärarrum'],
#  [39.1, 12.7, 'Kylrum'],
#  [88.3, 18.6, 'Lärarrum'],
#  [21.9, 11.0, 'Kylrum'],
#  [34.6, 11.4, 'Kylrum'],
#  [58.0, 17.7, 'Lärarrum'],
#  [57.5, 11.5, 'Kylrum'],
#  [63.1, 17.8, 'Lärarrum'],
#  [70.6, 18.5, 'Lärarrum'],
#  [35.4, 11.7, 'Kylrum'],
#  [77.2, 17.8, 'Lärarrum'],
#  [83.8, 19.0, 'Klassrum'],
#  [53.6, 18.4, 'Lärarrum'],
#  [51.4, 15.8, 'Kylrum'],
#  [59.3, 14.6, 'Kylrum'],
#  [89.5, 16.7, 'Lärarrum'],
#  [50.2, 17.2, 'Lärarrum'],
#  [45.6, 15.8, 'Kylrum'],
#  [35.2, 15.1, 'Kylrum'],
#  [75.6, 18.4, 'Lärarrum'],
#  [69.7, 18.8, 'Lärarrum'],
#  [37.9, 10.1, 'Kylrum'],
#  [52.0, 15.8, 'Kylrum'],
#  [74.9, 19.2, 'Lärarrum'],
#  [50.3, 17.7, 'Lärarrum'],
#  [29.1, 12.1, 'Kylrum'],
#  [55.2, 18.4, 'Lärarrum'],
#  [50.8, 18.3, 'Lärarrum'],
#  [77.5, 19.7, 'Lärarrum'],
#  [53.1, 13.1, 'Kylrum'],
#  [68.1, 16.8, 'Lärarrum'],
#  [57.5, 14.2, 'Kylrum'],
#  [96.1, 19.3, 'Klassrum'],
#  [82.2, 18.4, 'Lärarrum'],
#  [41.6, 14.3, 'Kylrum'],
#  [22.7, 13.5, 'Kylrum'],
#  [33.5, 11.1, 'Kylrum'],
#  [67.4, 19.2, 'Lärarrum'],
#  [53.1, 17.5, 'Lärarrum'],
#  [42.1, 12.8, 'Kylrum'],
#  [51.4, 18.3, 'Lärarrum'],
#  [88.1, 16.9, 'Lärarrum'],
#  [60.0, 16.0, 'Lärarrum'],
#  [21.2, 13.8, 'Kylrum'],
#  [35.2, 11.0, 'Kylrum'],
#  [78.1, 19.7, 'Lärarrum'],
#  [58.6, 18.7, 'Lärarrum'],
#  [59.1, 14.7, 'Kylrum'],
#  [72.6, 18.4, 'Lärarrum'],
#  [56.6, 17.1, 'Lärarrum'],
#  [52.5, 16.5, 'Lärarrum'],
#  [65.5, 19.2, 'Lärarrum'],
#  [98.0, 19.5, 'Klassrum'],
#  [35.8, 13.7, 'Kylrum'],
#  [59.4, 16.7, 'Lärarrum'],
#  [61.7, 18.4, 'Lärarrum'],
#  [74.8, 18.5, 'Lärarrum'],
#  [16.0, 15.5, 'Kylrum'],
#  [19.2, 15.0, 'Kylrum'],
#  [16.0, 13.2, 'Kylrum'],
#  [29.7, 10.5, 'Kylrum'],
#  [22.5, 13.7, 'Kylrum'],
#  [57.1, 11.3, 'Kylrum'],
#  [76.2, 17.5, 'Lärarrum'],
#  [16.8, 11.1, 'Kylrum'],
#  [62.6, 16.8, 'Lärarrum'],
#  [52.4, 16.4, 'Lärarrum'],
#  [67.8, 16.3, 'Lärarrum'],
#  [61.1, 17.3, 'Lärarrum'],
#  [56.9, 15.6, 'Kylrum'],
#  [55.5, 12.5, 'Kylrum'],
#  [29.8, 11.3, 'Kylrum'],
#  [25.7, 13.8, 'Kylrum'],
#  [89.9, 18.3, 'Lärarrum'],
#  [42.2, 14.1, 'Kylrum'],
#  [59.5, 19.4, 'Lärarrum'],
#  [50.0, 11.3, 'Kylrum'],
#  [80.1, 17.1, 'Lärarrum'],
#  [75.9, 16.6, 'Lärarrum'],
#  [40.7, 11.9, 'Kylrum'],
#  [82.1, 16.5, 'Lärarrum'],
#  [61.0, 17.4, 'Lärarrum'],
#  [17.9, 14.3, 'Kylrum'],
#  [52.9, 13.4, 'Kylrum'],
#  [40.1, 10.2, 'Kylrum'],
#  [44.9, 12.5, 'Kylrum'],
#  [99.0, 19.5, 'Klassrum'],
#  [35.3, 15.1, 'Kylrum'],
#  [55.1, 18.3, 'Lärarrum'],
#  [41.3, 16.0, 'Kylrum'],
#  [22.8, 14.5, 'Kylrum'],
#  [28.0, 11.1, 'Kylrum'],
#  [57.7, 17.2, 'Lärarrum'],
#  [55.3, 16.5, 'Lärarrum'],
#  [66.0, 18.8, 'Lärarrum'],
#  [31.5, 10.5, 'Kylrum'],
#  [30.7, 15.1, 'Kylrum'],
#  [70.8, 18.1, 'Lärarrum'],
#  [74.8, 16.5, 'Lärarrum'],
#  [86.9, 19.6, 'Lärarrum'],
#  [22.0, 10.3, 'Kylrum'],
#  [28.3, 13.8, 'Kylrum'],
#  [89.8, 16.9, 'Lärarrum'],
#  [39.0, 11.2, 'Kylrum'],
#  [79.8, 19.7, 'Lärarrum'],
#  [26.1, 12.6, 'Kylrum'],
#  [62.4, 18.5, 'Lärarrum'],
#  [27.7, 14.1, 'Kylrum'],
#  [69.6, 19.7, 'Lärarrum'],
#  [88.7, 17.2, 'Lärarrum'],
#  [26.4, 13.0, 'Kylrum'],
#  [85.8, 16.3, 'Lärarrum'],
#  [50.3, 10.7, 'Kylrum'],
#  [57.7, 13.5, 'Kylrum'],
#  [16.4, 10.7, 'Kylrum'],
#  [54.2, 19.3, 'Lärarrum'],
#  [56.8, 16.4, 'Lärarrum'],
#  [54.4, 18.1, 'Lärarrum'],
#  [75.2, 17.9, 'Lärarrum'],
#  [41.3, 15.8, 'Kylrum'],
#  [74.0, 16.4, 'Lärarrum'],
#  [99.3, 18.6, 'Klassrum'],
#  [74.3, 19.4, 'Lärarrum'],
#  [62.5, 16.0, 'Lärarrum'],
#  [19.4, 10.7, 'Kylrum'],
#  [58.8, 12.9, 'Kylrum'],
#  [39.3, 14.6, 'Kylrum'],
#  [86.7, 18.2, 'Lärarrum'],
#  [74.9, 18.9, 'Lärarrum'],
#  [34.2, 15.0, 'Kylrum'],
#  [41.2, 11.9, 'Kylrum'],
#  [56.6, 18.5, 'Lärarrum'],
#  [54.1, 13.6, 'Kylrum'],
#  [89.5, 16.5, 'Lärarrum'],
#  [30.4, 11.7, 'Kylrum'],
#  [33.1, 15.6, 'Kylrum'],
#  [33.9, 13.7, 'Kylrum'],
#  [36.9, 13.0, 'Kylrum'],
#  [98.5, 18.4, 'Klassrum'],
#  [54.1, 16.2, 'Lärarrum'],
#  [63.3, 16.6, 'Lärarrum'],
#  [36.4, 14.4, 'Kylrum'],
#  [54.3, 16.3, 'Lärarrum'],
#  [77.1, 18.5, 'Lärarrum'],
#  [57.8, 11.1, 'Kylrum'],
#  [76.9, 17.7, 'Lärarrum'],
#  [53.9, 13.8, 'Kylrum'],
#  [55.9, 16.5, 'Lärarrum'],
#  [56.3, 19.3, 'Lärarrum'],
#  [56.8, 18.5, 'Lärarrum'],
#  [36.9, 11.8, 'Kylrum'],
#  [87.1, 19.2, 'Lärarrum'],
#  [69.9, 17.4, 'Lärarrum'],
#  [40.2, 14.3, 'Kylrum'],
#  [40.0, 11.3, 'Kylrum'],
#  [50.6, 18.9, 'Lärarrum'],
#  [63.8, 17.5, 'Lärarrum'],
#  [52.4, 19.3, 'Lärarrum'],
#  [63.3, 17.9, 'Lärarrum'],
#  [23.2, 12.5, 'Kylrum'],
#  [54.3, 16.1, 'Lärarrum'],
#  [78.7, 18.9, 'Lärarrum'],
#  [59.6, 15.6, 'Kylrum'],
#  [75.8, 18.1, 'Lärarrum'],
#  [25.7, 12.2, 'Kylrum'],
#  [89.6, 16.3, 'Lärarrum'],
#  [54.7, 10.1, 'Kylrum'],
#  [44.9, 15.8, 'Kylrum'],
#  [54.5, 14.0, 'Kylrum'],
#  [54.8, 19.4, 'Lärarrum'],
#  [69.0, 17.0, 'Lärarrum'],
#  [57.1, 16.6, 'Lärarrum'],
#  [71.4, 19.5, 'Lärarrum'],
#  [29.0, 14.4, 'Kylrum'],
#  [47.3, 11.1, 'Kylrum'],
#  [83.3, 19.0, 'Lärarrum'],
#  [44.3, 14.7, 'Kylrum'],
#  [22.4, 15.1, 'Kylrum'],
#  [25.1, 10.3, 'Kylrum'],
#  [83.0, 18.8, 'Lärarrum'],
#  [65.3, 17.4, 'Lärarrum'],
#  [22.6, 12.1, 'Kylrum'],
#  [78.2, 16.9, 'Lärarrum'],
#  [37.0, 11.5, 'Kylrum'],
#  [39.0, 10.4, 'Kylrum'],
#  [58.2, 16.1, 'Lärarrum'],
#  [70.8, 16.7, 'Lärarrum'],
#  [52.7, 19.2, 'Lärarrum'],
#  [31.7, 12.5, 'Kylrum'],
#  [58.2, 12.3, 'Kylrum'],
#  [80.7, 18.6, 'Lärarrum'],
#  [52.0, 10.6, 'Kylrum'],
#  [87.9, 17.8, 'Lärarrum'],
#  [63.0, 18.5, 'Lärarrum'],
#  [17.3, 15.3, 'Kylrum'],
#  [98.3, 19.4, 'Klassrum'],
#  [55.0, 17.1, 'Lärarrum'],
#  [54.1, 11.1, 'Kylrum'],
#  [71.5, 17.5, 'Lärarrum'],
#  [85.2, 18.9, 'Lärarrum'],
#  [76.4, 16.6, 'Lärarrum'],
#  [38.9, 15.1, 'Kylrum'],
#  [83.5, 19.0, 'Lärarrum'],
#  [58.4, 18.7, 'Lärarrum'],
#  [33.4, 10.8, 'Kylrum'],
#  [79.4, 16.5, 'Lärarrum'],
#  [25.0, 14.5, 'Kylrum'],
#  [55.7, 19.2, 'Lärarrum'],
#  [59.1, 11.3, 'Kylrum'],
#  [86.3, 17.1, 'Lärarrum'],
#  [56.3, 16.0, 'Lärarrum'],
#  [33.0, 12.7, 'Kylrum'],
#  [36.2, 13.8, 'Kylrum'],
#  [65.2, 19.2, 'Lärarrum'],
#  [71.7, 18.4, 'Lärarrum'],
#  [55.9, 15.3, 'Kylrum'],
#  [75.5, 18.3, 'Lärarrum'],
#  [42.5, 13.6, 'Kylrum'],
#  [55.9, 12.7, 'Kylrum'],
#  [51.8, 19.4, 'Lärarrum'],
#  [54.1, 18.4, 'Lärarrum'],
#  [50.1, 11.5, 'Kylrum'],
#  [79.4, 19.7, 'Lärarrum'],
#  [46.8, 10.8, 'Kylrum'],
#  [85.3, 17.3, 'Lärarrum'],
#  [59.9, 18.9, 'Lärarrum'],
#  [53.0, 18.1, 'Lärarrum'],
#  [87.3, 19.3, 'Lärarrum'],
#  [30.0, 10.3, 'Kylrum'],
#  [53.2, 12.4, 'Kylrum'],
#  [56.1, 17.0, 'Lärarrum'],
#  [61.0, 17.9, 'Lärarrum'],
#  [43.1, 14.5, 'Kylrum'],
#  [53.9, 18.0, 'Lärarrum'],
#  [81.1, 18.2, 'Lärarrum'],
#  [89.7, 17.6, 'Lärarrum'],
#  [55.0, 14.4, 'Kylrum'],
#  [51.7, 18.0, 'Lärarrum'],
#  [85.5, 17.5, 'Lärarrum'],
#  [53.5, 17.5, 'Lärarrum'],
#  [88.3, 16.2, 'Lärarrum'],
#  [67.6, 17.4, 'Lärarrum'],
#  [51.7, 19.2, 'Lärarrum'],
#  [33.0, 12.4, 'Kylrum'],
#  [23.1, 15.4, 'Kylrum'],
#  [59.9, 18.8, 'Lärarrum'],
#  [17.3, 13.6, 'Kylrum'],
#  [55.6, 15.6, 'Kylrum'],
#  [73.4, 18.9, 'Lärarrum'],
#  [82.2, 16.5, 'Lärarrum'],
#  [53.4, 17.6, 'Lärarrum'],
#  [96.2, 18.4, 'Klassrum'],
#  [49.0, 14.4, 'Kylrum'],
#  [40.4, 14.9, 'Kylrum'],
#  [84.5, 17.1, 'Lärarrum'],
#  [56.4, 10.7, 'Kylrum'],
#  [83.4, 19.4, 'Klassrum'],
#  [17.5, 15.3, 'Kylrum'],
#  [82.9, 19.0, 'Lärarrum'],
#  [63.5, 19.1, 'Lärarrum'],
#  [33.5, 15.5, 'Kylrum'],
#  [34.2, 13.0, 'Kylrum'],
#  [42.1, 10.3, 'Kylrum'],
#  [89.2, 18.6, 'Klassrum'],
#  [57.0, 12.8, 'Kylrum'],
#  [77.9, 18.5, 'Lärarrum'],
#  [89.9, 18.9, 'Klassrum'],
#  [53.1, 17.1, 'Lärarrum'],
#  [31.0, 12.1, 'Kylrum'],
#  [50.1, 16.4, 'Lärarrum'],
#  [78.8, 17.3, 'Lärarrum'],
#  [74.4, 16.7, 'Lärarrum'],
#  [62.2, 16.2, 'Lärarrum'],
#  [66.9, 19.2, 'Lärarrum'],
#  [52.4, 19.1, 'Lärarrum'],
#  [82.2, 18.9, 'Lärarrum'],
#  [40.0, 11.4, 'Kylrum'],
#  [84.3, 16.2, 'Lärarrum'],
#  [56.2, 11.4, 'Kylrum'],
#  [59.4, 14.0, 'Kylrum'],
#  [51.7, 17.7, 'Lärarrum'],
#  [77.5, 17.9, 'Lärarrum'],
#  [69.1, 19.6, 'Lärarrum'],
#  [17.0, 13.1, 'Kylrum'],
#  [30.4, 14.1, 'Kylrum'],
#  [45.3, 10.1, 'Kylrum'],
#  [51.0, 15.5, 'Kylrum'],
#  [56.1, 19.5, 'Lärarrum'],
#  [54.6, 11.5, 'Kylrum'],
#  [52.7, 11.0, 'Kylrum'],
#  [96.1, 18.7, 'Klassrum'],
#  [82.9, 18.1, 'Klassrum'],
#  [64.2, 16.1, 'Lärarrum'],
#  [86.8, 17.4, 'Lärarrum'],
#  [87.0, 19.0, 'Lärarrum'],
#  [72.0, 17.1, 'Lärarrum'],
#  [32.6, 10.9, 'Kylrum'],
#  [82.9, 18.8, 'Klassrum'],
#  [58.9, 14.7, 'Kylrum'],
#  [43.7, 13.2, 'Kylrum'],
#  [69.2, 18.2, 'Lärarrum'],
#  [71.7, 19.1, 'Lärarrum'],
#  [58.6, 12.8, 'Kylrum'],
#  [36.1, 11.7, 'Kylrum'],
#  [74.6, 16.9, 'Lärarrum'],
#  [45.4, 14.8, 'Kylrum'],
#  [59.5, 16.9, 'Lärarrum'],
#  [53.3, 11.7, 'Kylrum'],
#  [64.4, 17.7, 'Lärarrum'],
#  [67.7, 16.8, 'Lärarrum'],
#  [90.6, 18.4, 'Klassrum'],
#  [82.7, 18.8, 'Klassrum'],
#  [81.7, 17.8, 'Lärarrum'],
#  [59.1, 19.7, 'Lärarrum'],
#  [41.8, 10.7, 'Kylrum'],
#  [44.6, 12.0, 'Kylrum'],
#  [88.7, 19.1, 'Klassrum'],
#  [73.1, 16.9, 'Lärarrum'],
#  [19.0, 15.0, 'Kylrum'],
#  [74.5, 16.2, 'Lärarrum'],
#  [54.2, 14.5, 'Kylrum'],
#  [26.1, 10.5, 'Kylrum'],
#  [44.0, 13.4, 'Kylrum'],
#  [52.3, 16.2, 'Lärarrum'],
#  [38.2, 16.0, 'Kylrum'],
#  [62.7, 18.1, 'Lärarrum'],
#  [77.2, 17.2, 'Lärarrum'],
#  [54.8, 18.3, 'Lärarrum'],
#  [83.5, 18.2, 'Lärarrum'],
#  [59.1, 18.6, 'Lärarrum'],
#  [89.0, 16.5, 'Lärarrum'],
#  [68.5, 18.7, 'Lärarrum'],
#  [82.7, 16.4, 'Lärarrum'],
#  [95.6, 18.4, 'Klassrum'],
#  [39.7, 10.2, 'Kylrum'],
#  [80.9, 17.4, 'Lärarrum'],
#  [15.9, 15.6, 'Kylrum'],
#  [82.9, 19.0, 'Klassrum'],
#  [32.8, 10.8, 'Kylrum'],
#  [54.2, 16.2, 'Lärarrum'],
#  [72.9, 16.7, 'Lärarrum'],
#  [25.7, 13.1, 'Kylrum'],
#  [24.8, 15.7, 'Kylrum'],
#  [70.5, 18.7, 'Lärarrum'],
#  [15.2, 12.5, 'Kylrum'],
#  [21.7, 14.8, 'Kylrum'],
#  [57.3, 13.8, 'Kylrum'],
#  [22.0, 11.3, 'Kylrum'],
#  [53.7, 19.3, 'Lärarrum'],
#  [62.8, 17.7, 'Lärarrum'],
#  [79.6, 17.2, 'Lärarrum'],
#  [86.7, 19.5, 'Klassrum'],
#  [46.5, 15.9, 'Kylrum'],
#  [58.9, 18.9, 'Lärarrum'],
#  [96.7, 18.0, 'Klassrum'],
#  [86.7, 18.5, 'Klassrum'],
#  [55.2, 13.1, 'Kylrum'],
#  [82.2, 18.8, 'Lärarrum'],
#  [40.3, 15.6, 'Kylrum'],
#  [84.4, 18.7, 'Klassrum'],
#  [82.9, 19.6, 'Lärarrum'],
#  [42.6, 12.8, 'Kylrum'],
#  [24.5, 10.1, 'Kylrum'],
#  [87.8, 17.0, 'Lärarrum'],
#  [83.2, 18.5, 'Klassrum'],
#  [57.9, 16.3, 'Lärarrum'],
#  [25.0, 15.0, 'Kylrum'],
#  [38.5, 13.5, 'Kylrum'],
#  [59.2, 12.1, 'Kylrum'],
#  [52.0, 17.4, 'Lärarrum'],
#  [18.6, 11.6, 'Kylrum'],
#  [98.9, 19.4, 'Klassrum'],
#  [51.7, 13.2, 'Kylrum'],
#  [74.1, 16.9, 'Lärarrum'],
#  [33.0, 10.9, 'Kylrum'],
#  [41.3, 15.6, 'Kylrum'],
#  [86.6, 17.7, 'Lärarrum'],
#  [64.2, 16.4, 'Lärarrum'],
#  [84.6, 16.4, 'Lärarrum'],
#  [59.4, 18.3, 'Lärarrum'],
#  [58.7, 10.6, 'Kylrum'],
#  [48.6, 15.4, 'Kylrum'],
#  [47.3, 11.0, 'Kylrum'],
#  [86.5, 19.1, 'Klassrum'],
#  [20.2, 11.6, 'Kylrum'],
#  [17.0, 14.9, 'Kylrum'],
#  [15.8, 15.7, 'Kylrum'],
#  [52.3, 16.4, 'Lärarrum'],
#  [21.7, 14.5, 'Kylrum'],
#  [79.3, 16.4, 'Lärarrum'],
#  [78.0, 18.6, 'Lärarrum'],
#  [70.1, 16.5, 'Lärarrum'],
#  [71.9, 19.6, 'Lärarrum'],
#  [85.6, 16.8, 'Lärarrum'],
#  [48.3, 10.8, 'Kylrum'],
#  [68.3, 17.9, 'Lärarrum'],
#  [55.8, 17.5, 'Lärarrum'],
#  [50.0, 14.0, 'Kylrum'],
#  [51.4, 14.6, 'Kylrum'],
#  [46.2, 12.2, 'Kylrum'],
#  [84.6, 16.7, 'Lärarrum'],
#  [55.7, 16.6, 'Lärarrum'],
#  [58.3, 19.2, 'Lärarrum'],
#  [36.2, 14.4, 'Kylrum'],
#  [44.6, 15.2, 'Kylrum'],
#  [79.4, 19.7, 'Lärarrum'],
#  [50.3, 17.9, 'Lärarrum'],
#  [82.3, 18.7, 'Lärarrum'],
#  [41.9, 13.9, 'Kylrum'],
#  [54.4, 16.3, 'Lärarrum'],
#  [15.1, 10.8, 'Kylrum'],
#  [65.9, 18.2, 'Lärarrum'],
#  [63.0, 17.8, 'Lärarrum'],
#  [78.7, 17.1, 'Lärarrum'],
#  [52.9, 16.9, 'Lärarrum'],
#  [52.7, 10.7, 'Kylrum'],
#  [83.8, 16.9, 'Lärarrum'],
#  [76.6, 17.9, 'Lärarrum'],
#  [56.2, 16.8, 'Lärarrum'],
#  [57.2, 16.7, 'Lärarrum'],
#  [53.2, 10.8, 'Kylrum'],
#  [42.7, 11.9, 'Kylrum'],
#  [39.4, 15.8, 'Kylrum'],
#  [19.9, 12.4, 'Kylrum'],
#  [63.7, 19.4, 'Lärarrum'],
#  [63.0, 17.5, 'Lärarrum'],
#  [58.8, 18.5, 'Lärarrum'],
#  [57.1, 11.8, 'Kylrum'],
#  [76.1, 16.3, 'Lärarrum'],
#  [21.6, 13.9, 'Kylrum'],
#  [44.1, 13.1, 'Kylrum'],
#  [52.6, 15.3, 'Kylrum'],
#  [74.0, 16.5, 'Lärarrum'],
#  [82.4, 19.4, 'Lärarrum'],
#  [56.5, 17.4, 'Lärarrum'],
#  [52.0, 18.1, 'Lärarrum'],
#  [50.1, 16.7, 'Lärarrum'],
#  [29.5, 11.1, 'Kylrum'],
#  [15.3, 15.2, 'Kylrum'],
#  [90.0, 16.5, 'Lärarrum'],
#  [77.9, 16.4, 'Lärarrum'],
#  [56.4, 17.9, 'Lärarrum'],
#  [53.8, 13.3, 'Kylrum'],
#  [85.9, 16.3, 'Lärarrum'],
#  [55.9, 16.9, 'Lärarrum'],
#  [58.8, 18.2, 'Lärarrum'],
#  [43.3, 10.3, 'Kylrum'],
#  [44.3, 15.4, 'Kylrum'],
#  [98.5, 18.1, 'Klassrum'],
#  [70.5, 18.8, 'Lärarrum'],
#  [70.1, 18.9, 'Lärarrum'],
#  [27.6, 10.6, 'Kylrum'],
#  [53.3, 14.5, 'Kylrum'],
#  [22.6, 15.7, 'Kylrum'],
#  [89.5, 19.5, 'Klassrum'],
#  [26.9, 11.0, 'Kylrum'],
#  [83.1, 17.5, 'Lärarrum'],
#  [27.1, 12.9, 'Kylrum'],
#  [37.5, 12.6, 'Kylrum'],
#  [82.9, 19.2, 'Lärarrum'],
#  [36.7, 15.6, 'Kylrum'],
#  [33.4, 15.3, 'Kylrum'],
#  [63.7, 18.3, 'Lärarrum'],
#  [46.9, 15.0, 'Kylrum'],
#  [21.6, 14.4, 'Kylrum'],
#  [89.1, 18.0, 'Lärarrum'],
#  [28.3, 11.9, 'Kylrum'],
#  [20.8, 13.3, 'Kylrum'],
#  [17.4, 12.9, 'Kylrum'],
#  [25.3, 10.0, 'Kylrum'],
#  [27.0, 11.2, 'Kylrum'],
#  [82.8, 19.3, 'Klassrum'],
#  [33.3, 13.7, 'Kylrum'],
#  [66.9, 18.9, 'Lärarrum'],
#  [54.1, 18.8, 'Lärarrum'],
#  [63.3, 19.7, 'Lärarrum'],
#  [68.8, 17.8, 'Lärarrum'],
#  [63.7, 16.6, 'Lärarrum'],
#  [54.5, 10.5, 'Kylrum'],
#  [54.8, 15.8, 'Kylrum'],
#  [58.9, 11.8, 'Kylrum'],
#  [38.5, 12.2, 'Kylrum'],
#  [87.0, 18.7, 'Lärarrum'],
#  [49.2, 10.4, 'Kylrum'],
#  [88.3, 16.6, 'Lärarrum'],
#  [80.3, 19.3, 'Lärarrum'],
#  [74.6, 18.0, 'Lärarrum'],
#  [30.0, 11.1, 'Kylrum'],
#  [74.9, 19.7, 'Lärarrum'],
#  [68.4, 17.0, 'Lärarrum'],
#  [61.4, 16.1, 'Lärarrum'],
#  [37.1, 15.7, 'Kylrum'],
#  [45.0, 13.1, 'Kylrum'],
#  [83.3, 19.3, 'Lärarrum'],
#  [78.9, 18.0, 'Lärarrum'],
#  [75.9, 16.2, 'Lärarrum'],
#  [29.7, 11.3, 'Kylrum'],
#  [73.6, 17.0, 'Lärarrum'],
#  [29.8, 11.1, 'Kylrum'],
#  [87.6, 17.1, 'Lärarrum'],
#  [64.4, 17.2, 'Lärarrum'],
#  [50.3, 11.1, 'Kylrum'],
#  [73.3, 18.9, 'Lärarrum'],
#  [66.8, 17.2, 'Lärarrum'],
#  [36.0, 13.7, 'Kylrum'],
#  [34.6, 11.7, 'Kylrum'],
#  [34.5, 13.5, 'Kylrum'],
#  [58.1, 19.4, 'Lärarrum'],
#  [58.8, 18.2, 'Lärarrum'],
#  [92.2, 18.8, 'Klassrum'],
#  [61.7, 18.8, 'Lärarrum'],
#  [72.7, 18.9, 'Lärarrum'],
#  [16.7, 11.2, 'Kylrum'],
#  [73.5, 18.9, 'Lärarrum'],
#  [55.0, 15.4, 'Kylrum'],
#  [76.9, 16.6, 'Lärarrum'],
#  [90.4, 18.0, 'Klassrum'],
#  [37.5, 14.7, 'Kylrum'],
#  [28.8, 13.1, 'Kylrum'],
#  [25.5, 10.9, 'Kylrum'],
#  [51.7, 14.4, 'Kylrum'],
#  [51.8, 14.5, 'Kylrum'],
#  [53.8, 17.3, 'Lärarrum'],
#  [73.2, 18.2, 'Lärarrum'],
#  [18.0, 12.7, 'Kylrum'],
#  [59.0, 12.7, 'Kylrum'],
#  [63.5, 17.0, 'Lärarrum'],
#  [86.5, 18.3, 'Lärarrum'],
#  [71.1, 17.2, 'Lärarrum'],
#  [16.2, 15.9, 'Kylrum'],
#  [52.5, 13.8, 'Kylrum'],
#  [52.3, 16.0, 'Kylrum'],
#  [58.1, 13.9, 'Kylrum'],
#  [15.0, 14.9, 'Kylrum'],
#  [67.1, 17.3, 'Lärarrum'],
#  [50.7, 15.4, 'Kylrum'],
#  [23.5, 10.7, 'Kylrum'],
#  [77.0, 19.6, 'Lärarrum'],
#  [44.4, 11.7, 'Kylrum'],
#  [58.1, 11.7, 'Kylrum'],
#  [21.5, 12.4, 'Kylrum'],
#  [30.0, 14.7, 'Kylrum'],
#  [75.6, 17.3, 'Lärarrum'],
#  [74.3, 16.9, 'Lärarrum'],
#  [71.6, 17.2, 'Lärarrum'],
#  [58.9, 17.2, 'Lärarrum'],
#  [82.4, 19.0, 'Lärarrum'],
#  [32.1, 11.4, 'Kylrum'],
#  [77.7, 17.8, 'Lärarrum'],
#  [61.1, 17.9, 'Lärarrum'],
#  [76.9, 19.1, 'Lärarrum'],
#  [91.8, 18.3, 'Klassrum'],
#  [21.9, 11.6, 'Kylrum'],
#  [39.3, 11.1, 'Kylrum'],
#  [39.3, 14.8, 'Kylrum'],
#  [57.5, 18.4, 'Lärarrum'],
#  [77.9, 18.2, 'Lärarrum'],
#  [55.2, 16.4, 'Lärarrum'],
#  [62.4, 17.6, 'Lärarrum'],
#  [68.8, 16.7, 'Lärarrum'],
#  [83.9, 19.1, 'Klassrum'],
#  [28.3, 11.6, 'Kylrum'],
#  [60.2, 19.4, 'Lärarrum'],
#  [74.1, 17.8, 'Lärarrum'],
#  [52.3, 13.5, 'Kylrum'],
#  [28.6, 10.3, 'Kylrum'],
#  [74.5, 19.1, 'Lärarrum'],
#  [15.7, 13.7, 'Kylrum'],
#  [85.6, 17.8, 'Lärarrum'],
#  [56.6, 19.3, 'Lärarrum'],
#  ...]

# %%
# On the other hand, partitioning by Green doesn't help so much.
true_rows, false_rows = partition(training_data, Question(0, 45.4, 1, 1))

# We've isolated one apple in the true rows.
true_rows
# Out:
# [[43.8, 11.3, 'Kylrum'],
#  [38.7, 13.1, 'Kylrum'],
#  [39.2, 15.1, 'Kylrum'],
#  [38.8, 15.8, 'Kylrum'],
#  [41.6, 13.7, 'Kylrum'],
#  [24.4, 11.1, 'Kylrum'],
#  [45.2, 12.3, 'Kylrum'],
#  [29.3, 14.4, 'Kylrum'],
#  [38.9, 15.2, 'Kylrum'],
#  [29.8, 13.0, 'Kylrum'],
#  [29.3, 14.6, 'Kylrum'],
#  [42.4, 11.6, 'Kylrum'],
#  [21.6, 12.0, 'Kylrum'],
#  [25.0, 14.5, 'Kylrum'],
#  [30.0, 15.6, 'Kylrum'],
#  [20.9, 10.2, 'Kylrum'],
#  [32.1, 14.9, 'Kylrum'],
#  [30.9, 12.5, 'Kylrum'],
#  [26.5, 10.7, 'Kylrum'],
#  [35.6, 10.3, 'Kylrum'],
#  [19.1, 11.6, 'Kylrum'],
#  [21.6, 15.8, 'Kylrum'],
#  [29.0, 14.4, 'Kylrum'],
#  [27.9, 15.9, 'Kylrum'],
#  [35.2, 14.7, 'Kylrum'],
#  [26.2, 12.1, 'Kylrum'],
#  [24.4, 14.7, 'Kylrum'],
#  [26.7, 11.4, 'Kylrum'],
#  [30.3, 15.9, 'Kylrum'],
#  [15.8, 15.9, 'Kylrum'],
#  [27.9, 15.3, 'Kylrum'],
#  [40.6, 15.4, 'Kylrum'],
#  [36.7, 15.6, 'Kylrum'],
#  [45.4, 12.3, 'Kylrum'],
#  [41.6, 15.0, 'Kylrum'],
#  [18.6, 12.3, 'Kylrum'],
#  [17.2, 14.5, 'Kylrum'],
#  [37.5, 13.7, 'Kylrum'],
#  [23.6, 12.9, 'Kylrum'],
#  [22.1, 15.7, 'Kylrum'],
#  [29.6, 13.0, 'Kylrum'],
#  [40.9, 10.7, 'Kylrum'],
#  [16.1, 10.3, 'Kylrum'],
#  [43.2, 10.7, 'Kylrum'],
#  [22.9, 13.0, 'Kylrum'],
#  [31.7, 14.1, 'Kylrum'],
#  [19.4, 12.9, 'Kylrum'],
#  [43.5, 13.1, 'Kylrum'],
#  [43.3, 13.2, 'Kylrum'],
#  [37.9, 12.1, 'Kylrum'],
#  [44.2, 12.2, 'Kylrum'],
#  [33.8, 13.0, 'Kylrum'],
#  [40.4, 11.9, 'Kylrum'],
#  [37.6, 14.4, 'Kylrum'],
#  [27.4, 13.7, 'Kylrum'],
#  [42.0, 11.8, 'Kylrum'],
#  [25.4, 15.8, 'Kylrum'],
#  [45.1, 10.5, 'Kylrum'],
#  [29.8, 15.7, 'Kylrum'],
#  [38.5, 15.0, 'Kylrum'],
#  [24.3, 15.5, 'Kylrum'],
#  [24.3, 11.7, 'Kylrum'],
#  [31.2, 15.1, 'Kylrum'],
#  [33.7, 15.0, 'Kylrum'],
#  [44.5, 15.4, 'Kylrum'],
#  [29.8, 11.7, 'Kylrum'],
#  [33.7, 11.0, 'Kylrum'],
#  [24.8, 10.4, 'Kylrum'],
#  [23.8, 13.7, 'Kylrum'],
#  [44.7, 15.3, 'Kylrum'],
#  [28.4, 13.9, 'Kylrum'],
#  [26.4, 15.6, 'Kylrum'],
#  [20.4, 13.2, 'Kylrum'],
#  [31.5, 10.6, 'Kylrum'],
#  [23.6, 12.7, 'Kylrum'],
#  [35.3, 14.8, 'Kylrum'],
#  [27.6, 12.4, 'Kylrum'],
#  [41.8, 12.0, 'Kylrum'],
#  [26.3, 15.4, 'Kylrum'],
#  [32.4, 11.4, 'Kylrum'],
#  [36.4, 13.6, 'Kylrum'],
#  [25.9, 13.9, 'Kylrum'],
#  [25.5, 14.6, 'Kylrum'],
#  [39.5, 13.2, 'Kylrum'],
#  [26.8, 12.6, 'Kylrum'],
#  [16.9, 15.2, 'Kylrum'],
#  [44.6, 15.2, 'Kylrum'],
#  [32.4, 12.1, 'Kylrum'],
#  [33.8, 11.1, 'Kylrum'],
#  [27.4, 15.2, 'Kylrum'],
#  [27.6, 14.6, 'Kylrum'],
#  [38.1, 10.3, 'Kylrum'],
#  [23.8, 13.8, 'Kylrum'],
#  [34.7, 10.0, 'Kylrum'],
#  [26.3, 11.6, 'Kylrum'],
#  [23.3, 12.0, 'Kylrum'],
#  [43.4, 10.1, 'Kylrum'],
#  [19.9, 11.4, 'Kylrum'],
#  [31.0, 11.0, 'Kylrum'],
#  [20.9, 10.5, 'Kylrum'],
#  [30.4, 15.7, 'Kylrum'],
#  [23.6, 14.5, 'Kylrum'],
#  [29.7, 11.6, 'Kylrum'],
#  [35.7, 16.0, 'Kylrum'],
#  [21.6, 14.8, 'Kylrum'],
#  [42.7, 11.2, 'Kylrum'],
#  [27.1, 10.5, 'Kylrum'],
#  [31.4, 12.6, 'Kylrum'],
#  [36.2, 14.3, 'Kylrum'],
#  [32.1, 13.1, 'Kylrum'],
#  [21.1, 12.5, 'Kylrum'],
#  [22.5, 10.7, 'Kylrum'],
#  [30.5, 15.9, 'Kylrum'],
#  [17.3, 10.7, 'Kylrum'],
#  [30.0, 13.2, 'Kylrum'],
#  [35.2, 14.9, 'Kylrum'],
#  [40.6, 12.5, 'Kylrum'],
#  [30.3, 15.2, 'Kylrum'],
#  [24.9, 10.8, 'Kylrum'],
#  [15.6, 10.8, 'Kylrum'],
#  [33.4, 10.6, 'Kylrum'],
#  [28.4, 14.2, 'Kylrum'],
#  [42.5, 11.8, 'Kylrum'],
#  [43.3, 12.9, 'Kylrum'],
#  [20.6, 10.4, 'Kylrum'],
#  [37.8, 13.6, 'Kylrum'],
#  [22.1, 15.6, 'Kylrum'],
#  [32.5, 16.0, 'Kylrum'],
#  [41.9, 12.0, 'Kylrum'],
#  [30.6, 15.4, 'Kylrum'],
#  [30.2, 13.3, 'Kylrum'],
#  [35.6, 10.9, 'Kylrum'],
#  [24.6, 13.8, 'Kylrum'],
#  [20.1, 16.0, 'Kylrum'],
#  [26.6, 10.1, 'Kylrum'],
#  [39.1, 12.7, 'Kylrum'],
#  [21.9, 11.0, 'Kylrum'],
#  [34.6, 11.4, 'Kylrum'],
#  [35.4, 11.7, 'Kylrum'],
#  [35.2, 15.1, 'Kylrum'],
#  [37.9, 10.1, 'Kylrum'],
#  [29.1, 12.1, 'Kylrum'],
#  [41.6, 14.3, 'Kylrum'],
#  [22.7, 13.5, 'Kylrum'],
#  [33.5, 11.1, 'Kylrum'],
#  [42.1, 12.8, 'Kylrum'],
#  [21.2, 13.8, 'Kylrum'],
#  [35.2, 11.0, 'Kylrum'],
#  [35.8, 13.7, 'Kylrum'],
#  [16.0, 15.5, 'Kylrum'],
#  [19.2, 15.0, 'Kylrum'],
#  [16.0, 13.2, 'Kylrum'],
#  [29.7, 10.5, 'Kylrum'],
#  [22.5, 13.7, 'Kylrum'],
#  [16.8, 11.1, 'Kylrum'],
#  [29.8, 11.3, 'Kylrum'],
#  [25.7, 13.8, 'Kylrum'],
#  [42.2, 14.1, 'Kylrum'],
#  [40.7, 11.9, 'Kylrum'],
#  [17.9, 14.3, 'Kylrum'],
#  [40.1, 10.2, 'Kylrum'],
#  [44.9, 12.5, 'Kylrum'],
#  [35.3, 15.1, 'Kylrum'],
#  [41.3, 16.0, 'Kylrum'],
#  [22.8, 14.5, 'Kylrum'],
#  [28.0, 11.1, 'Kylrum'],
#  [31.5, 10.5, 'Kylrum'],
#  [30.7, 15.1, 'Kylrum'],
#  [22.0, 10.3, 'Kylrum'],
#  [28.3, 13.8, 'Kylrum'],
#  [39.0, 11.2, 'Kylrum'],
#  [26.1, 12.6, 'Kylrum'],
#  [27.7, 14.1, 'Kylrum'],
#  [26.4, 13.0, 'Kylrum'],
#  [16.4, 10.7, 'Kylrum'],
#  [41.3, 15.8, 'Kylrum'],
#  [19.4, 10.7, 'Kylrum'],
#  [39.3, 14.6, 'Kylrum'],
#  [34.2, 15.0, 'Kylrum'],
#  [41.2, 11.9, 'Kylrum'],
#  [30.4, 11.7, 'Kylrum'],
#  [33.1, 15.6, 'Kylrum'],
#  [33.9, 13.7, 'Kylrum'],
#  [36.9, 13.0, 'Kylrum'],
#  [36.4, 14.4, 'Kylrum'],
#  [36.9, 11.8, 'Kylrum'],
#  [40.2, 14.3, 'Kylrum'],
#  [40.0, 11.3, 'Kylrum'],
#  [23.2, 12.5, 'Kylrum'],
#  [25.7, 12.2, 'Kylrum'],
#  [44.9, 15.8, 'Kylrum'],
#  [29.0, 14.4, 'Kylrum'],
#  [44.3, 14.7, 'Kylrum'],
#  [22.4, 15.1, 'Kylrum'],
#  [25.1, 10.3, 'Kylrum'],
#  [22.6, 12.1, 'Kylrum'],
#  [37.0, 11.5, 'Kylrum'],
#  [39.0, 10.4, 'Kylrum'],
#  [31.7, 12.5, 'Kylrum'],
#  [17.3, 15.3, 'Kylrum'],
#  [38.9, 15.1, 'Kylrum'],
#  [33.4, 10.8, 'Kylrum'],
#  [25.0, 14.5, 'Kylrum'],
#  [33.0, 12.7, 'Kylrum'],
#  [36.2, 13.8, 'Kylrum'],
#  [42.5, 13.6, 'Kylrum'],
#  [30.0, 10.3, 'Kylrum'],
#  [43.1, 14.5, 'Kylrum'],
#  [33.0, 12.4, 'Kylrum'],
#  [23.1, 15.4, 'Kylrum'],
#  [17.3, 13.6, 'Kylrum'],
#  [40.4, 14.9, 'Kylrum'],
#  [17.5, 15.3, 'Kylrum'],
#  [33.5, 15.5, 'Kylrum'],
#  [34.2, 13.0, 'Kylrum'],
#  [42.1, 10.3, 'Kylrum'],
#  [31.0, 12.1, 'Kylrum'],
#  [40.0, 11.4, 'Kylrum'],
#  [17.0, 13.1, 'Kylrum'],
#  [30.4, 14.1, 'Kylrum'],
#  [45.3, 10.1, 'Kylrum'],
#  [32.6, 10.9, 'Kylrum'],
#  [43.7, 13.2, 'Kylrum'],
#  [36.1, 11.7, 'Kylrum'],
#  [45.4, 14.8, 'Kylrum'],
#  [41.8, 10.7, 'Kylrum'],
#  [44.6, 12.0, 'Kylrum'],
#  [19.0, 15.0, 'Kylrum'],
#  [26.1, 10.5, 'Kylrum'],
#  [44.0, 13.4, 'Kylrum'],
#  [38.2, 16.0, 'Kylrum'],
#  [39.7, 10.2, 'Kylrum'],
#  [15.9, 15.6, 'Kylrum'],
#  [32.8, 10.8, 'Kylrum'],
#  [25.7, 13.1, 'Kylrum'],
#  [24.8, 15.7, 'Kylrum'],
#  [15.2, 12.5, 'Kylrum'],
#  [21.7, 14.8, 'Kylrum'],
#  [22.0, 11.3, 'Kylrum'],
#  [40.3, 15.6, 'Kylrum'],
#  [42.6, 12.8, 'Kylrum'],
#  [24.5, 10.1, 'Kylrum'],
#  [25.0, 15.0, 'Kylrum'],
#  [38.5, 13.5, 'Kylrum'],
#  [18.6, 11.6, 'Kylrum'],
#  [33.0, 10.9, 'Kylrum'],
#  [41.3, 15.6, 'Kylrum'],
#  [20.2, 11.6, 'Kylrum'],
#  [17.0, 14.9, 'Kylrum'],
#  [15.8, 15.7, 'Kylrum'],
#  [21.7, 14.5, 'Kylrum'],
#  [36.2, 14.4, 'Kylrum'],
#  [44.6, 15.2, 'Kylrum'],
#  [41.9, 13.9, 'Kylrum'],
#  [15.1, 10.8, 'Kylrum'],
#  [42.7, 11.9, 'Kylrum'],
#  [39.4, 15.8, 'Kylrum'],
#  [19.9, 12.4, 'Kylrum'],
#  [21.6, 13.9, 'Kylrum'],
#  [44.1, 13.1, 'Kylrum'],
#  [29.5, 11.1, 'Kylrum'],
#  [15.3, 15.2, 'Kylrum'],
#  [43.3, 10.3, 'Kylrum'],
#  [44.3, 15.4, 'Kylrum'],
#  [27.6, 10.6, 'Kylrum'],
#  [22.6, 15.7, 'Kylrum'],
#  [26.9, 11.0, 'Kylrum'],
#  [27.1, 12.9, 'Kylrum'],
#  [37.5, 12.6, 'Kylrum'],
#  [36.7, 15.6, 'Kylrum'],
#  [33.4, 15.3, 'Kylrum'],
#  [21.6, 14.4, 'Kylrum'],
#  [28.3, 11.9, 'Kylrum'],
#  [20.8, 13.3, 'Kylrum'],
#  [17.4, 12.9, 'Kylrum'],
#  [25.3, 10.0, 'Kylrum'],
#  [27.0, 11.2, 'Kylrum'],
#  [33.3, 13.7, 'Kylrum'],
#  [38.5, 12.2, 'Kylrum'],
#  [30.0, 11.1, 'Kylrum'],
#  [37.1, 15.7, 'Kylrum'],
#  [45.0, 13.1, 'Kylrum'],
#  [29.7, 11.3, 'Kylrum'],
#  [29.8, 11.1, 'Kylrum'],
#  [36.0, 13.7, 'Kylrum'],
#  [34.6, 11.7, 'Kylrum'],
#  [34.5, 13.5, 'Kylrum'],
#  [16.7, 11.2, 'Kylrum'],
#  [37.5, 14.7, 'Kylrum'],
#  [28.8, 13.1, 'Kylrum'],
#  [25.5, 10.9, 'Kylrum'],
#  [18.0, 12.7, 'Kylrum'],
#  [16.2, 15.9, 'Kylrum'],
#  [15.0, 14.9, 'Kylrum'],
#  [23.5, 10.7, 'Kylrum'],
#  [44.4, 11.7, 'Kylrum'],
#  [21.5, 12.4, 'Kylrum'],
#  [30.0, 14.7, 'Kylrum'],
#  [32.1, 11.4, 'Kylrum'],
#  [21.9, 11.6, 'Kylrum'],
#  [39.3, 11.1, 'Kylrum'],
#  [39.3, 14.8, 'Kylrum'],
#  [28.3, 11.6, 'Kylrum'],
#  [28.6, 10.3, 'Kylrum'],
#  [15.7, 13.7, 'Kylrum'],
#  [42.0, 11.8, 'Kylrum'],
#  [23.7, 10.4, 'Kylrum'],
#  [42.6, 12.5, 'Kylrum'],
#  [22.6, 14.6, 'Kylrum'],
#  [30.3, 12.7, 'Kylrum'],
#  [37.8, 13.2, 'Kylrum'],
#  [26.5, 11.2, 'Kylrum'],
#  [31.4, 15.9, 'Kylrum'],
#  [26.2, 10.9, 'Kylrum'],
#  [24.9, 12.4, 'Kylrum'],
#  [26.8, 10.0, 'Kylrum'],
#  [35.6, 10.9, 'Kylrum'],
#  [32.0, 11.8, 'Kylrum'],
#  [22.6, 10.4, 'Kylrum'],
#  [39.8, 13.4, 'Kylrum'],
#  [17.8, 15.4, 'Kylrum'],
#  [30.3, 13.0, 'Kylrum'],
#  [34.5, 13.5, 'Kylrum'],
#  [29.0, 13.3, 'Kylrum'],
#  [38.6, 11.7, 'Kylrum'],
#  [35.0, 11.6, 'Kylrum'],
#  [32.3, 12.7, 'Kylrum'],
#  [18.3, 10.7, 'Kylrum'],
#  [38.3, 11.0, 'Kylrum'],
#  [33.3, 13.3, 'Kylrum'],
#  [23.1, 15.9, 'Kylrum'],
#  [28.6, 13.4, 'Kylrum'],
#  [39.2, 12.6, 'Kylrum'],
#  [32.3, 10.0, 'Kylrum'],
#  [44.3, 15.8, 'Kylrum'],
#  [32.5, 12.7, 'Kylrum'],
#  [21.3, 11.2, 'Kylrum'],
#  [29.5, 14.7, 'Kylrum'],
#  [40.3, 15.7, 'Kylrum'],
#  [41.4, 11.0, 'Kylrum'],
#  [21.5, 13.1, 'Kylrum'],
#  [20.0, 11.4, 'Kylrum'],
#  [32.7, 12.8, 'Kylrum'],
#  [29.4, 14.8, 'Kylrum'],
#  [41.0, 14.5, 'Kylrum'],
#  [43.4, 15.3, 'Kylrum'],
#  [27.4, 12.9, 'Kylrum'],
#  [15.7, 15.5, 'Kylrum'],
#  [26.0, 12.4, 'Kylrum'],
#  [40.7, 12.7, 'Kylrum'],
#  [43.9, 13.5, 'Kylrum'],
#  [33.9, 10.8, 'Kylrum'],
#  [32.1, 10.3, 'Kylrum'],
#  [38.7, 14.6, 'Kylrum'],
#  [20.8, 11.7, 'Kylrum'],
#  [33.7, 11.3, 'Kylrum'],
#  [42.6, 15.1, 'Kylrum'],
#  [21.2, 11.4, 'Kylrum'],
#  [34.8, 12.4, 'Kylrum'],
#  [35.7, 15.8, 'Kylrum'],
#  [25.6, 10.5, 'Kylrum'],
#  [19.9, 14.7, 'Kylrum'],
#  [33.8, 11.6, 'Kylrum'],
#  [18.7, 13.4, 'Kylrum'],
#  [24.5, 14.2, 'Kylrum'],
#  [37.8, 12.4, 'Kylrum'],
#  [38.7, 14.2, 'Kylrum'],
#  [39.2, 15.6, 'Kylrum'],
#  [30.8, 11.2, 'Kylrum'],
#  [23.3, 12.7, 'Kylrum'],
#  [45.0, 12.1, 'Kylrum'],
#  [41.7, 10.6, 'Kylrum'],
#  [23.0, 15.3, 'Kylrum'],
#  [38.0, 14.0, 'Kylrum'],
#  [34.4, 11.0, 'Kylrum'],
#  [45.4, 10.5, 'Kylrum'],
#  [41.2, 14.8, 'Kylrum'],
#  [41.8, 11.2, 'Kylrum'],
#  [43.1, 12.9, 'Kylrum'],
#  [15.7, 13.2, 'Kylrum'],
#  [34.4, 11.5, 'Kylrum'],
#  [41.1, 14.0, 'Kylrum'],
#  [41.3, 10.5, 'Kylrum'],
#  [29.4, 11.6, 'Kylrum'],
#  [17.6, 11.1, 'Kylrum'],
#  [39.2, 12.0, 'Kylrum'],
#  [41.6, 10.8, 'Kylrum'],
#  [18.4, 13.4, 'Kylrum'],
#  [29.8, 14.0, 'Kylrum'],
#  [42.2, 15.6, 'Kylrum'],
#  [25.7, 14.9, 'Kylrum'],
#  [19.7, 10.7, 'Kylrum'],
#  [38.7, 15.6, 'Kylrum'],
#  [24.5, 10.4, 'Kylrum'],
#  [15.0, 11.8, 'Kylrum'],
#  [23.4, 12.8, 'Kylrum'],
#  [19.4, 11.6, 'Kylrum'],
#  [40.8, 10.4, 'Kylrum'],
#  [42.2, 12.4, 'Kylrum'],
#  [38.4, 14.1, 'Kylrum'],
#  [44.8, 12.0, 'Kylrum'],
#  [44.8, 12.1, 'Kylrum'],
#  [33.8, 10.8, 'Kylrum'],
#  [38.3, 14.1, 'Kylrum'],
#  [38.2, 12.0, 'Kylrum'],
#  [40.2, 13.0, 'Kylrum'],
#  [28.3, 12.5, 'Kylrum'],
#  [29.4, 12.2, 'Kylrum'],
#  [23.7, 14.1, 'Kylrum'],
#  [32.9, 13.5, 'Kylrum'],
#  [36.5, 14.4, 'Kylrum'],
#  [33.3, 15.8, 'Kylrum'],
#  [43.6, 11.4, 'Kylrum'],
#  [16.1, 13.7, 'Kylrum'],
#  [17.9, 12.7, 'Kylrum'],
#  [23.0, 11.8, 'Kylrum']]

# %%
# But, the false-rows are badly mixed up.
false_rows
#######
# Out:
# [[72.5, 20.1, 'Lärarrum'],
#  [85.7, 23.4, 'Klassrum'],
#  [64.6, 19.5, 'Lärarrum'],
#  [71.6, 19.2, 'Lärarrum'],
#  [72.2, 16.2, 'Lärarrum'],
#  [63.6, 17.7, 'Lärarrum'],
#  [48.0, 11.0, 'Kylrum'],
#  [98.5, 19.3, 'Klassrum'],
#  [50.6, 17.1, 'Lärarrum'],
#  [58.0, 19.8, 'Lärarrum'],
#  [78.8, 16.7, 'Lärarrum'],
#  [81.3, 22.4, 'Klassrum'],
#  [65.0, 19.6, 'Lärarrum'],
#  [86.3, 23.0, 'Klassrum'],
#  [64.2, 17.7, 'Lärarrum'],
#  [85.0, 20.4, 'Klassrum'],
#  [76.9, 17.3, 'Lärarrum'],
#  [75.6, 16.7, 'Lärarrum'],
#  [88.2, 20.5, 'Lärarrum'],
#  [59.1, 20.2, 'Lärarrum'],
#  [66.4, 21.4, 'Lärarrum'],
#  [88.1, 18.8, 'Lärarrum'],
#  [52.4, 17.7, 'Lärarrum'],
#  [93.9, 18.2, 'Klassrum'],
#  [51.8, 14.9, 'Kylrum'],
#  [56.1, 21.9, 'Lärarrum'],
#  [50.9, 15.6, 'Kylrum'],
#  [80.0, 16.7, 'Lärarrum'],
#  [87.1, 22.5, 'Klassrum'],
#  [56.8, 19.3, 'Lärarrum'],
#  [52.7, 20.0, 'Lärarrum'],
#  [57.1, 19.3, 'Lärarrum'],
#  [88.3, 16.3, 'Lärarrum'],
#  [62.4, 20.5, 'Lärarrum'],
#  [48.7, 12.9, 'Kylrum'],
#  [81.0, 16.9, 'Lärarrum'],
#  [50.4, 15.4, 'Kylrum'],
#  [81.4, 18.8, 'Lärarrum'],
#  [59.9, 19.3, 'Lärarrum'],
#  [76.4, 17.1, 'Lärarrum'],
#  [73.6, 21.7, 'Lärarrum'],
#  [50.4, 19.3, 'Lärarrum'],
#  [89.7, 18.6, 'Klassrum'],
#  [59.2, 16.7, 'Lärarrum'],
#  [73.2, 18.2, 'Lärarrum'],
#  [98.3, 20.9, 'Klassrum'],
#  [88.7, 16.7, 'Lärarrum'],
#  [82.9, 23.3, 'Klassrum'],
#  [80.7, 16.2, 'Lärarrum'],
#  [66.7, 18.4, 'Lärarrum'],
#  [53.9, 20.0, 'Lärarrum'],
#  [47.9, 15.1, 'Kylrum'],
#  [80.5, 21.6, 'Lärarrum'],
#  [92.0, 23.0, 'Klassrum'],
#  [80.6, 19.8, 'Klassrum'],
#  [87.1, 17.1, 'Lärarrum'],
#  [82.7, 20.2, 'Klassrum'],
#  [62.2, 18.3, 'Lärarrum'],
#  [89.4, 21.8, 'Klassrum'],
#  [84.9, 16.9, 'Lärarrum'],
#  [95.3, 23.0, 'Klassrum'],
#  [55.2, 20.1, 'Lärarrum'],
#  [86.2, 18.7, 'Klassrum'],
#  [79.5, 17.6, 'Lärarrum'],
#  [73.1, 20.1, 'Lärarrum'],
#  [50.8, 21.4, 'Lärarrum'],
#  [75.5, 17.2, 'Lärarrum'],
#  [67.9, 17.8, 'Lärarrum'],
#  [81.6, 21.5, 'Lärarrum'],
#  [61.2, 16.1, 'Lärarrum'],
#  [51.2, 15.6, 'Kylrum'],
#  [50.4, 21.9, 'Lärarrum'],
#  [93.6, 20.9, 'Klassrum'],
#  [86.2, 19.7, 'Lärarrum'],
#  [50.3, 20.2, 'Lärarrum'],
#  [49.4, 10.9, 'Kylrum'],
#  [92.3, 20.4, 'Klassrum'],
#  [77.9, 20.2, 'Lärarrum'],
#  [94.9, 21.3, 'Klassrum'],
#  [62.2, 16.6, 'Lärarrum'],
#  [76.0, 16.0, 'Lärarrum'],
#  [59.3, 18.7, 'Lärarrum'],
#  [87.4, 20.3, 'Lärarrum'],
#  [78.5, 21.9, 'Lärarrum'],
#  [54.0, 16.9, 'Lärarrum'],
#  [79.3, 19.2, 'Lärarrum'],
#  [72.9, 17.9, 'Lärarrum'],
#  [53.0, 11.8, 'Kylrum'],
#  [66.1, 22.0, 'Lärarrum'],
#  [76.9, 21.9, 'Lärarrum'],
#  [77.5, 19.6, 'Lärarrum'],
#  [84.1, 23.1, 'Klassrum'],
#  [81.8, 18.7, 'Lärarrum'],
#  [55.5, 13.0, 'Kylrum'],
#  [68.1, 19.7, 'Lärarrum'],
#  [74.4, 21.9, 'Lärarrum'],
#  [51.2, 18.7, 'Lärarrum'],
#  [96.4, 19.2, 'Klassrum'],
#  [85.8, 18.3, 'Lärarrum'],
#  [70.2, 20.5, 'Lärarrum'],
#  [68.0, 20.4, 'Lärarrum'],
#  [56.2, 15.9, 'Kylrum'],
#  [54.1, 16.2, 'Lärarrum'],
#  [51.9, 18.6, 'Lärarrum'],
#  [90.8, 20.1, 'Klassrum'],
#  [73.5, 18.0, 'Lärarrum'],
#  [84.6, 22.9, 'Klassrum'],
#  [54.1, 12.8, 'Kylrum'],
#  [57.1, 18.6, 'Lärarrum'],
#  [89.8, 19.3, 'Lärarrum'],
#  [50.5, 11.6, 'Kylrum'],
#  [77.3, 16.8, 'Lärarrum'],
#  [68.2, 21.6, 'Lärarrum'],
#  [82.8, 16.9, 'Lärarrum'],
#  [83.6, 20.6, 'Klassrum'],
#  [82.6, 18.1, 'Klassrum'],
#  [78.3, 16.7, 'Lärarrum'],
#  [79.0, 20.0, 'Lärarrum'],
#  [97.5, 20.4, 'Klassrum'],
#  [69.7, 16.2, 'Lärarrum'],
#  [80.8, 23.9, 'Klassrum'],
#  [69.2, 21.8, 'Lärarrum'],
#  [74.3, 18.7, 'Lärarrum'],
#  [86.6, 19.0, 'Klassrum'],
#  [80.5, 18.0, 'Lärarrum'],
#  [63.9, 16.8, 'Lärarrum'],
#  [80.2, 23.6, 'Klassrum'],
#  [72.9, 17.0, 'Lärarrum'],
#  [85.7, 21.7, 'Lärarrum'],
#  [64.1, 16.8, 'Lärarrum'],
#  [74.7, 16.4, 'Lärarrum'],
#  [54.3, 19.2, 'Lärarrum'],
#  [70.0, 19.9, 'Lärarrum'],
#  [65.3, 17.9, 'Lärarrum'],
#  [49.6, 13.5, 'Kylrum'],
#  [50.9, 19.3, 'Lärarrum'],
#  [78.5, 16.1, 'Lärarrum'],
#  [82.9, 19.7, 'Klassrum'],
#  [75.1, 20.5, 'Lärarrum'],
#  [87.0, 18.2, 'Klassrum'],
#  [71.1, 16.4, 'Lärarrum'],
#  [89.1, 18.9, 'Lärarrum'],
#  [69.8, 16.2, 'Lärarrum'],
#  [84.7, 20.9, 'Klassrum'],
#  [87.5, 24.0, 'Klassrum'],
#  [51.0, 18.6, 'Lärarrum'],
#  [72.4, 21.9, 'Lärarrum'],
#  [88.6, 18.8, 'Lärarrum'],
#  [85.5, 23.9, 'Klassrum'],
#  [51.7, 16.8, 'Lärarrum'],
#  [75.4, 19.2, 'Lärarrum'],
#  [80.4, 20.1, 'Lärarrum'],
#  [54.1, 18.3, 'Lärarrum'],
#  [68.0, 17.7, 'Lärarrum'],
#  [93.5, 21.9, 'Klassrum'],
#  [81.0, 18.0, 'Klassrum'],
#  [79.7, 18.8, 'Lärarrum'],
#  [85.7, 23.4, 'Klassrum'],
#  [66.2, 20.7, 'Lärarrum'],
#  [74.4, 19.7, 'Lärarrum'],
#  [79.4, 17.4, 'Lärarrum'],
#  [68.8, 22.0, 'Lärarrum'],
#  [72.5, 20.0, 'Lärarrum'],
#  [47.1, 13.7, 'Kylrum'],
#  [77.2, 16.1, 'Lärarrum'],
#  [73.8, 18.4, 'Lärarrum'],
#  [52.1, 17.9, 'Lärarrum'],
#  [86.3, 18.0, 'Lärarrum'],
#  [82.3, 16.9, 'Lärarrum'],
#  [77.1, 21.2, 'Lärarrum'],
#  [86.7, 21.0, 'Klassrum'],
#  [83.1, 18.2, 'Klassrum'],
#  [55.9, 19.1, 'Lärarrum'],
#  [95.5, 20.8, 'Klassrum'],
#  [72.5, 18.3, 'Lärarrum'],
#  [83.1, 16.8, 'Lärarrum'],
#  [81.1, 19.3, 'Klassrum'],
#  [70.0, 17.7, 'Lärarrum'],
#  [82.9, 20.2, 'Lärarrum'],
#  [73.3, 20.0, 'Lärarrum'],
#  [82.6, 19.6, 'Lärarrum'],
#  [71.3, 18.4, 'Lärarrum'],
#  [76.9, 18.8, 'Lärarrum'],
#  [45.5, 13.9, 'Kylrum'],
#  [57.4, 20.4, 'Lärarrum'],
#  [65.5, 20.1, 'Lärarrum'],
#  [79.1, 16.7, 'Lärarrum'],
#  [50.4, 17.2, 'Lärarrum'],
#  [52.7, 16.0, 'Kylrum'],
#  [65.1, 20.3, 'Lärarrum'],
#  [71.9, 21.7, 'Lärarrum'],
#  [47.0, 14.6, 'Kylrum'],
#  [98.5, 22.6, 'Klassrum'],
#  [53.4, 21.0, 'Lärarrum'],
#  [89.4, 21.7, 'Lärarrum'],
#  [84.1, 17.1, 'Lärarrum'],
#  [81.5, 20.1, 'Klassrum'],
#  [61.0, 21.8, 'Lärarrum'],
#  [73.7, 18.4, 'Lärarrum'],
#  [87.7, 17.8, 'Lärarrum'],
#  [86.9, 20.9, 'Lärarrum'],
#  [48.7, 12.5, 'Kylrum'],
#  [74.3, 18.6, 'Lärarrum'],
#  [59.0, 21.4, 'Lärarrum'],
#  [74.6, 18.0, 'Lärarrum'],
#  [82.7, 18.1, 'Lärarrum'],
#  [89.6, 19.5, 'Lärarrum'],
#  [73.0, 21.3, 'Lärarrum'],
#  [56.7, 17.9, 'Lärarrum'],
#  [89.3, 23.5, 'Klassrum'],
#  [60.0, 10.3, 'Kylrum'],
#  [71.3, 20.2, 'Lärarrum'],
#  [57.7, 19.5, 'Lärarrum'],
#  [84.4, 20.3, 'Klassrum'],
#  [86.9, 16.1, 'Lärarrum'],
#  [94.4, 22.5, 'Klassrum'],
#  [59.8, 17.3, 'Lärarrum'],
#  [86.1, 21.0, 'Klassrum'],
#  [47.2, 11.6, 'Kylrum'],
#  [50.9, 17.4, 'Lärarrum'],
#  [57.6, 17.8, 'Lärarrum'],
#  [54.8, 10.3, 'Kylrum'],
#  [97.0, 20.8, 'Klassrum'],
#  [50.7, 21.8, 'Lärarrum'],
#  [52.5, 17.7, 'Lärarrum'],
#  [92.9, 19.5, 'Klassrum'],
#  [81.8, 19.6, 'Lärarrum'],
#  [54.1, 14.4, 'Kylrum'],
#  [76.8, 21.9, 'Lärarrum'],
#  [69.1, 20.6, 'Lärarrum'],
#  [74.0, 20.9, 'Lärarrum'],
#  [52.3, 11.9, 'Kylrum'],
#  [48.2, 11.4, 'Kylrum'],
#  [98.9, 22.4, 'Klassrum'],
#  [67.5, 21.8, 'Lärarrum'],
#  [66.2, 19.1, 'Lärarrum'],
#  [58.3, 20.2, 'Lärarrum'],
#  [83.6, 20.6, 'Lärarrum'],
#  [83.2, 21.1, 'Lärarrum'],
#  [74.1, 21.1, 'Lärarrum'],
#  [86.7, 16.9, 'Lärarrum'],
#  [48.8, 10.9, 'Kylrum'],
#  [74.3, 16.4, 'Lärarrum'],
#  [86.2, 20.1, 'Lärarrum'],
#  [55.1, 18.7, 'Lärarrum'],
#  [80.3, 19.0, 'Lärarrum'],
#  [45.7, 13.5, 'Kylrum'],
#  [53.1, 21.0, 'Lärarrum'],
#  [60.5, 17.0, 'Lärarrum'],
#  [91.1, 20.8, 'Klassrum'],
#  [55.6, 17.1, 'Lärarrum'],
#  [84.4, 21.3, 'Lärarrum'],
#  [84.0, 18.0, 'Lärarrum'],
#  [60.5, 17.2, 'Lärarrum'],
#  [85.1, 16.8, 'Lärarrum'],
#  [66.9, 20.3, 'Lärarrum'],
#  [83.8, 22.7, 'Klassrum'],
#  [84.6, 17.9, 'Lärarrum'],
#  [86.5, 21.9, 'Lärarrum'],
#  [64.9, 20.1, 'Lärarrum'],
#  [69.9, 19.8, 'Lärarrum'],
#  [56.3, 13.9, 'Kylrum'],
#  [65.3, 16.5, 'Lärarrum'],
#  [71.3, 21.8, 'Lärarrum'],
#  [53.1, 16.8, 'Lärarrum'],
#  [91.1, 20.0, 'Klassrum'],
#  [65.2, 20.7, 'Lärarrum'],
#  [52.4, 14.4, 'Kylrum'],
#  [99.3, 23.2, 'Klassrum'],
#  [59.4, 19.6, 'Lärarrum'],
#  [93.2, 18.7, 'Klassrum'],
#  [95.6, 19.6, 'Klassrum'],
#  [89.5, 19.7, 'Lärarrum'],
#  [55.9, 18.7, 'Lärarrum'],
#  [93.5, 21.1, 'Klassrum'],
#  [88.4, 20.2, 'Lärarrum'],
#  [72.6, 20.5, 'Lärarrum'],
#  [63.7, 19.1, 'Lärarrum'],
#  [62.6, 20.9, 'Lärarrum'],
#  [70.7, 18.9, 'Lärarrum'],
#  [72.9, 19.7, 'Lärarrum'],
#  [91.7, 18.9, 'Klassrum'],
#  [97.5, 18.7, 'Klassrum'],
#  [63.1, 21.3, 'Lärarrum'],
#  [89.8, 19.1, 'Lärarrum'],
#  [81.0, 22.9, 'Klassrum'],
#  [56.8, 10.5, 'Kylrum'],
#  [61.6, 16.5, 'Lärarrum'],
#  [94.9, 23.5, 'Klassrum'],
#  [93.5, 18.2, 'Klassrum'],
#  [99.5, 19.1, 'Klassrum'],
#  [53.8, 19.8, 'Lärarrum'],
#  [87.6, 23.1, 'Klassrum'],
#  [81.9, 18.0, 'Lärarrum'],
#  [98.8, 18.8, 'Klassrum'],
#  [80.3, 19.0, 'Klassrum'],
#  [51.2, 11.6, 'Kylrum'],
#  [84.2, 18.5, 'Klassrum'],
#  [76.9, 17.9, 'Lärarrum'],
#  [63.2, 21.0, 'Lärarrum'],
#  [54.0, 16.7, 'Lärarrum'],
#  [96.7, 21.9, 'Klassrum'],
#  [51.6, 19.8, 'Lärarrum'],
#  [97.3, 18.6, 'Klassrum'],
#  [55.8, 18.9, 'Lärarrum'],
#  [58.2, 17.0, 'Lärarrum'],
#  [67.8, 21.9, 'Lärarrum'],
#  [62.1, 20.4, 'Lärarrum'],
#  [89.3, 21.6, 'Klassrum'],
#  [89.3, 17.4, 'Lärarrum'],
#  [63.9, 19.1, 'Lärarrum'],
#  [67.3, 21.8, 'Lärarrum'],
#  [93.5, 22.2, 'Klassrum'],
#  [79.2, 19.9, 'Lärarrum'],
#  [86.3, 17.8, 'Lärarrum'],
#  [81.2, 19.9, 'Klassrum'],
#  [53.7, 18.9, 'Lärarrum'],
#  [67.3, 17.1, 'Lärarrum'],
#  [78.5, 18.3, 'Lärarrum'],
#  [86.2, 20.9, 'Klassrum'],
#  [55.2, 16.8, 'Lärarrum'],
#  [94.5, 24.0, 'Klassrum'],
#  [80.4, 18.5, 'Lärarrum'],
#  [79.5, 17.0, 'Lärarrum'],
#  [76.8, 21.3, 'Lärarrum'],
#  [57.9, 19.6, 'Lärarrum'],
#  [67.3, 17.2, 'Lärarrum'],
#  [74.3, 19.6, 'Lärarrum'],
#  [79.0, 20.2, 'Lärarrum'],
#  [50.8, 17.2, 'Lärarrum'],
#  [58.1, 17.8, 'Lärarrum'],
#  [57.6, 12.3, 'Kylrum'],
#  [81.2, 16.3, 'Lärarrum'],
#  [74.7, 20.1, 'Lärarrum'],
#  [52.7, 12.0, 'Kylrum'],
#  [74.5, 20.2, 'Lärarrum'],
#  [82.5, 21.7, 'Lärarrum'],
#  [83.4, 18.1, 'Lärarrum'],
#  [83.1, 20.0, 'Lärarrum'],
#  [86.1, 20.8, 'Lärarrum'],
#  [73.7, 16.9, 'Lärarrum'],
#  [94.1, 22.3, 'Klassrum'],
#  [64.3, 21.2, 'Lärarrum'],
#  [49.4, 12.4, 'Kylrum'],
#  [56.0, 20.9, 'Lärarrum'],
#  [58.9, 18.8, 'Lärarrum'],
#  [65.0, 18.7, 'Lärarrum'],
#  [71.0, 19.3, 'Lärarrum'],
#  [86.6, 17.9, 'Lärarrum'],
#  [74.7, 18.9, 'Lärarrum'],
#  [75.9, 20.2, 'Lärarrum'],
#  [55.4, 16.6, 'Lärarrum'],
#  [96.5, 18.4, 'Klassrum'],
#  [83.1, 19.6, 'Lärarrum'],
#  [59.7, 10.5, 'Kylrum'],
#  [89.5, 18.2, 'Klassrum'],
#  [66.7, 16.8, 'Lärarrum'],
#  [57.8, 16.4, 'Lärarrum'],
#  [54.4, 11.9, 'Kylrum'],
#  [78.5, 19.9, 'Lärarrum'],
#  [64.9, 17.7, 'Lärarrum'],
#  [56.6, 20.4, 'Lärarrum'],
#  [52.1, 15.0, 'Kylrum'],
#  [82.3, 20.9, 'Lärarrum'],
#  [87.4, 22.6, 'Klassrum'],
#  [69.7, 19.1, 'Lärarrum'],
#  [77.0, 19.8, 'Lärarrum'],
#  [74.3, 20.0, 'Lärarrum'],
#  [90.7, 19.5, 'Klassrum'],
#  [54.3, 20.8, 'Lärarrum'],
#  [62.6, 21.9, 'Lärarrum'],
#  [89.4, 21.6, 'Lärarrum'],
#  [58.8, 17.9, 'Lärarrum'],
#  [87.7, 22.2, 'Klassrum'],
#  [90.5, 18.5, 'Klassrum'],
#  [50.8, 18.2, 'Lärarrum'],
#  [89.7, 23.3, 'Klassrum'],
#  [55.2, 14.6, 'Kylrum'],
#  [84.7, 21.3, 'Klassrum'],
#  [71.0, 18.9, 'Lärarrum'],
#  [68.0, 18.6, 'Lärarrum'],
#  [53.0, 12.3, 'Kylrum'],
#  [86.4, 16.3, 'Lärarrum'],
#  [55.9, 16.9, 'Lärarrum'],
#  [87.4, 16.6, 'Lärarrum'],
#  [94.8, 21.8, 'Klassrum'],
#  [51.1, 15.6, 'Kylrum'],
#  [51.9, 18.3, 'Lärarrum'],
#  [62.8, 18.8, 'Lärarrum'],
#  [54.2, 17.4, 'Lärarrum'],
#  [86.1, 20.5, 'Lärarrum'],
#  [55.9, 16.3, 'Lärarrum'],
#  [87.5, 20.1, 'Klassrum'],
#  [70.1, 16.6, 'Lärarrum'],
#  [52.8, 19.9, 'Lärarrum'],
#  [98.4, 23.3, 'Klassrum'],
#  [53.9, 13.7, 'Kylrum'],
#  [91.9, 22.2, 'Klassrum'],
#  [52.0, 16.8, 'Lärarrum'],
#  [61.7, 20.1, 'Lärarrum'],
#  [83.1, 19.0, 'Lärarrum'],
#  [81.4, 19.9, 'Klassrum'],
#  [82.5, 19.0, 'Lärarrum'],
#  [47.2, 10.5, 'Kylrum'],
#  [82.2, 20.4, 'Lärarrum'],
#  [73.5, 17.8, 'Lärarrum'],
#  [63.1, 17.1, 'Lärarrum'],
#  [80.6, 16.5, 'Lärarrum'],
#  [65.9, 16.9, 'Lärarrum'],
#  [68.2, 20.4, 'Lärarrum'],
#  [73.9, 16.2, 'Lärarrum'],
#  [48.5, 11.7, 'Kylrum'],
#  [94.1, 19.7, 'Klassrum'],
#  [53.9, 15.5, 'Kylrum'],
#  [71.2, 19.9, 'Lärarrum'],
#  [59.8, 10.8, 'Kylrum'],
#  [81.2, 21.9, 'Lärarrum'],
#  [56.0, 19.0, 'Lärarrum'],
#  [66.3, 18.9, 'Lärarrum'],
#  [57.2, 15.7, 'Kylrum'],
#  [82.1, 21.1, 'Lärarrum'],
#  [87.4, 18.4, 'Klassrum'],
#  [81.4, 23.8, 'Klassrum'],
#  [62.8, 17.0, 'Lärarrum'],
#  [80.0, 17.0, 'Lärarrum'],
#  [55.9, 21.1, 'Lärarrum'],
#  [52.7, 20.5, 'Lärarrum'],
#  [68.4, 19.4, 'Lärarrum'],
#  [60.3, 20.7, 'Lärarrum'],
#  [55.4, 12.5, 'Kylrum'],
#  [78.5, 21.4, 'Lärarrum'],
#  [80.2, 19.2, 'Klassrum'],
#  [80.5, 21.6, 'Lärarrum'],
#  [73.8, 18.3, 'Lärarrum'],
#  [62.8, 20.5, 'Lärarrum'],
#  [80.3, 16.5, 'Lärarrum'],
#  [57.1, 18.8, 'Lärarrum'],
#  [62.9, 21.9, 'Lärarrum'],
#  [83.7, 20.5, 'Klassrum'],
#  [59.1, 14.8, 'Kylrum'],
#  [92.6, 23.8, 'Klassrum'],
#  [73.8, 20.9, 'Lärarrum'],
#  [65.1, 17.0, 'Lärarrum'],
#  [85.1, 21.3, 'Lärarrum'],
#  [67.9, 21.1, 'Lärarrum'],
#  [83.0, 19.0, 'Lärarrum'],
#  [63.2, 20.8, 'Lärarrum'],
#  [71.1, 19.5, 'Lärarrum'],
#  [59.8, 18.6, 'Lärarrum'],
#  [85.7, 16.9, 'Lärarrum'],
#  [66.6, 18.6, 'Lärarrum'],
#  [72.8, 17.0, 'Lärarrum'],
#  [80.5, 18.0, 'Lärarrum'],
#  [74.7, 17.4, 'Lärarrum'],
#  [88.3, 17.8, 'Lärarrum'],
#  [49.8, 14.5, 'Kylrum'],
#  [80.2, 21.8, 'Lärarrum'],
#  [88.9, 20.7, 'Lärarrum'],
#  [58.3, 15.4, 'Kylrum'],
#  [99.7, 21.7, 'Klassrum'],
#  [80.3, 18.7, 'Klassrum'],
#  [97.8, 22.1, 'Klassrum'],
#  [50.7, 11.7, 'Kylrum'],
#  [82.6, 16.3, 'Lärarrum'],
#  [48.5, 13.3, 'Kylrum'],
#  [56.2, 16.6, 'Lärarrum'],
#  [69.0, 16.4, 'Lärarrum'],
#  [79.1, 17.3, 'Lärarrum'],
#  [81.2, 16.8, 'Lärarrum'],
#  [67.9, 20.4, 'Lärarrum'],
#  [62.7, 21.3, 'Lärarrum'],
#  [60.9, 16.4, 'Lärarrum'],
#  [77.8, 16.4, 'Lärarrum'],
#  [72.3, 17.3, 'Lärarrum'],
#  [82.5, 17.9, 'Lärarrum'],
#  [86.7, 19.3, 'Lärarrum'],
#  [95.1, 18.1, 'Klassrum'],
#  [46.7, 13.7, 'Kylrum'],
#  [61.0, 17.7, 'Lärarrum'],
#  [86.0, 17.8, 'Lärarrum'],
#  [52.1, 21.5, 'Lärarrum'],
#  [52.6, 21.8, 'Lärarrum'],
#  [48.1, 14.7, 'Kylrum'],
#  [68.0, 16.1, 'Lärarrum'],
#  [88.3, 18.6, 'Lärarrum'],
#  [90.7, 23.6, 'Klassrum'],
#  [58.0, 17.7, 'Lärarrum'],
#  [57.5, 11.5, 'Kylrum'],
#  [63.1, 17.8, 'Lärarrum'],
#  [70.6, 18.5, 'Lärarrum'],
#  [77.2, 17.8, 'Lärarrum'],
#  [83.8, 19.0, 'Klassrum'],
#  [53.6, 18.4, 'Lärarrum'],
#  [51.4, 15.8, 'Kylrum'],
#  [59.3, 14.6, 'Kylrum'],
#  [86.4, 19.8, 'Klassrum'],
#  [89.5, 16.7, 'Lärarrum'],
#  [50.2, 17.2, 'Lärarrum'],
#  [78.9, 22.0, 'Lärarrum'],
#  [45.6, 15.8, 'Kylrum'],
#  [69.8, 21.8, 'Lärarrum'],
#  [75.6, 18.4, 'Lärarrum'],
#  [89.4, 21.7, 'Lärarrum'],
#  [62.6, 21.6, 'Lärarrum'],
#  [69.7, 18.8, 'Lärarrum'],
#  [52.0, 15.8, 'Kylrum'],
#  [74.9, 19.2, 'Lärarrum'],
#  [76.2, 21.4, 'Lärarrum'],
#  [50.3, 17.7, 'Lärarrum'],
#  [55.2, 18.4, 'Lärarrum'],
#  [50.8, 18.3, 'Lärarrum'],
#  [77.5, 19.7, 'Lärarrum'],
#  [53.1, 13.1, 'Kylrum'],
#  [68.1, 16.8, 'Lärarrum'],
#  [88.5, 21.5, 'Klassrum'],
#  [92.6, 22.8, 'Klassrum'],
#  [57.5, 14.2, 'Kylrum'],
#  [99.5, 21.9, 'Klassrum'],
#  [96.1, 19.3, 'Klassrum'],
#  [82.2, 18.4, 'Lärarrum'],
#  [67.4, 19.2, 'Lärarrum'],
#  [78.5, 20.2, 'Lärarrum'],
#  [53.1, 17.5, 'Lärarrum'],
#  [51.4, 18.3, 'Lärarrum'],
#  [79.2, 21.9, 'Lärarrum'],
#  [64.3, 21.1, 'Lärarrum'],
#  [69.3, 21.3, 'Lärarrum'],
#  [88.1, 16.9, 'Lärarrum'],
#  [60.0, 16.0, 'Lärarrum'],
#  [86.2, 21.9, 'Klassrum'],
#  [78.1, 19.7, 'Lärarrum'],
#  [58.6, 18.7, 'Lärarrum'],
#  [72.3, 21.8, 'Lärarrum'],
#  [59.1, 14.7, 'Kylrum'],
#  [94.0, 21.2, 'Klassrum'],
#  [63.1, 19.8, 'Lärarrum'],
#  [59.7, 20.8, 'Lärarrum'],
#  [60.8, 20.1, 'Lärarrum'],
#  [72.6, 18.4, 'Lärarrum'],
#  [72.8, 20.1, 'Lärarrum'],
#  [56.6, 17.1, 'Lärarrum'],
#  [52.5, 16.5, 'Lärarrum'],
#  [65.5, 19.2, 'Lärarrum'],
#  [90.8, 22.4, 'Klassrum'],
#  [98.0, 19.5, 'Klassrum'],
#  [59.4, 16.7, 'Lärarrum'],
#  [61.7, 18.4, 'Lärarrum'],
#  [74.8, 18.5, 'Lärarrum'],
#  [55.2, 20.9, 'Lärarrum'],
#  [70.9, 20.3, 'Lärarrum'],
#  [92.5, 21.9, 'Klassrum'],
#  [57.1, 11.3, 'Kylrum'],
#  [76.2, 17.5, 'Lärarrum'],
#  [62.6, 16.8, 'Lärarrum'],
#  [52.4, 16.4, 'Lärarrum'],
#  [67.8, 16.3, 'Lärarrum'],
#  [61.1, 17.3, 'Lärarrum'],
#  [56.9, 15.6, 'Kylrum'],
#  [55.5, 12.5, 'Kylrum'],
#  [64.6, 20.9, 'Lärarrum'],
#  [87.9, 21.6, 'Lärarrum'],
#  [89.9, 18.3, 'Lärarrum'],
#  [67.4, 21.8, 'Lärarrum'],
#  [59.5, 19.4, 'Lärarrum'],
#  [50.0, 11.3, 'Kylrum'],
#  [80.1, 17.1, 'Lärarrum'],
#  [75.9, 16.6, 'Lärarrum'],
#  [82.1, 16.5, 'Lärarrum'],
#  [69.9, 20.7, 'Lärarrum'],
#  [61.0, 17.4, 'Lärarrum'],
#  [89.1, 23.8, 'Klassrum'],
#  [52.9, 13.4, 'Kylrum'],
#  [71.8, 21.8, 'Lärarrum'],
#  [51.5, 19.9, 'Lärarrum'],
#  [99.0, 19.5, 'Klassrum'],
#  [55.1, 18.3, 'Lärarrum'],
#  [86.1, 20.3, 'Klassrum'],
#  [81.6, 20.4, 'Klassrum'],
#  [57.7, 17.2, 'Lärarrum'],
#  [55.3, 16.5, 'Lärarrum'],
#  [66.0, 18.8, 'Lärarrum'],
#  [70.8, 18.1, 'Lärarrum'],
#  [62.7, 21.4, 'Lärarrum'],
#  [88.9, 20.9, 'Lärarrum'],
#  [74.8, 16.5, 'Lärarrum'],
#  [86.9, 19.6, 'Lärarrum'],
#  [89.8, 16.9, 'Lärarrum'],
#  [79.8, 19.7, 'Lärarrum'],
#  [62.4, 18.5, 'Lärarrum'],
#  [69.6, 19.7, 'Lärarrum'],
#  [88.7, 17.2, 'Lärarrum'],
#  [96.8, 22.9, 'Klassrum'],
#  [85.8, 16.3, 'Lärarrum'],
#  [50.3, 10.7, 'Kylrum'],
#  [57.7, 13.5, 'Kylrum'],
#  [54.2, 19.3, 'Lärarrum'],
#  [56.8, 16.4, 'Lärarrum'],
#  [54.4, 18.1, 'Lärarrum'],
#  [75.2, 17.9, 'Lärarrum'],
#  [86.2, 21.5, 'Lärarrum'],
#  [85.7, 21.5, 'Klassrum'],
#  [74.0, 16.4, 'Lärarrum'],
#  [99.3, 18.6, 'Klassrum'],
#  [79.5, 19.9, 'Lärarrum'],
#  [74.3, 19.4, 'Lärarrum'],
#  [62.0, 20.1, 'Lärarrum'],
#  [80.5, 21.0, 'Klassrum'],
#  [62.5, 16.0, 'Lärarrum'],
#  [95.8, 20.8, 'Klassrum'],
#  [58.8, 12.9, 'Kylrum'],
#  [95.1, 22.1, 'Klassrum'],
#  [86.7, 18.2, 'Lärarrum'],
#  [72.0, 20.4, 'Lärarrum'],
#  [74.9, 18.9, 'Lärarrum'],
#  [88.7, 20.2, 'Lärarrum'],
#  [56.6, 18.5, 'Lärarrum'],
#  [81.1, 23.6, 'Klassrum'],
#  [54.1, 13.6, 'Kylrum'],
#  [85.0, 21.4, 'Klassrum'],
#  [89.5, 16.5, 'Lärarrum'],
#  [98.5, 18.4, 'Klassrum'],
#  [54.1, 16.2, 'Lärarrum'],
#  [63.3, 16.6, 'Lärarrum'],
#  [70.6, 21.7, 'Lärarrum'],
#  [54.3, 16.3, 'Lärarrum'],
#  [77.1, 18.5, 'Lärarrum'],
#  [57.8, 11.1, 'Kylrum'],
#  [76.9, 17.7, 'Lärarrum'],
#  [53.9, 13.8, 'Kylrum'],
#  [55.9, 16.5, 'Lärarrum'],
#  [56.3, 19.3, 'Lärarrum'],
#  [56.8, 18.5, 'Lärarrum'],
#  [74.6, 20.5, 'Lärarrum'],
#  [87.1, 19.2, 'Lärarrum'],
#  [69.9, 17.4, 'Lärarrum'],
#  [84.7, 20.2, 'Lärarrum'],
#  [50.6, 18.9, 'Lärarrum'],
#  [63.8, 17.5, 'Lärarrum'],
#  [59.2, 20.8, 'Lärarrum'],
#  [52.4, 19.3, 'Lärarrum'],
#  [56.3, 21.9, 'Lärarrum'],
#  [63.3, 17.9, 'Lärarrum'],
#  [54.3, 16.1, 'Lärarrum'],
#  [78.7, 18.9, 'Lärarrum'],
#  [59.6, 15.6, 'Kylrum'],
#  [75.8, 18.1, 'Lärarrum'],
#  [59.6, 21.3, 'Lärarrum'],
#  [89.6, 16.3, 'Lärarrum'],
#  [54.7, 10.1, 'Kylrum'],
#  [52.9, 20.5, 'Lärarrum'],
#  [82.8, 20.1, 'Lärarrum'],
#  [83.5, 22.9, 'Klassrum'],
#  [84.6, 21.1, 'Klassrum'],
#  [54.5, 14.0, 'Kylrum'],
#  [52.5, 21.0, 'Lärarrum'],
#  [54.8, 19.4, 'Lärarrum'],
#  [81.0, 22.0, 'Lärarrum'],
#  [69.0, 17.0, 'Lärarrum'],
#  [96.2, 24.0, 'Klassrum'],
#  [91.4, 22.1, 'Klassrum'],
#  [57.1, 16.6, 'Lärarrum'],
#  [71.4, 19.5, 'Lärarrum'],
#  [93.4, 23.2, 'Klassrum'],
#  [47.3, 11.1, 'Kylrum'],
#  [69.1, 22.0, 'Lärarrum'],
#  [83.3, 19.0, 'Lärarrum'],
#  [72.0, 21.5, 'Lärarrum'],
#  [87.1, 20.9, 'Klassrum'],
#  [58.8, 20.7, 'Lärarrum'],
#  [99.6, 22.2, 'Klassrum'],
#  [68.7, 20.8, 'Lärarrum'],
#  [74.8, 20.8, 'Lärarrum'],
#  [83.0, 18.8, 'Lärarrum'],
#  [65.3, 17.4, 'Lärarrum'],
#  [78.2, 16.9, 'Lärarrum'],
#  [62.6, 20.4, 'Lärarrum'],
#  [84.0, 23.0, 'Klassrum'],
#  [60.1, 21.9, 'Lärarrum'],
#  [58.2, 16.1, 'Lärarrum'],
#  [70.8, 16.7, 'Lärarrum'],
#  [62.8, 20.1, 'Lärarrum'],
#  [52.7, 19.2, 'Lärarrum'],
#  [80.7, 21.1, 'Lärarrum'],
#  [58.2, 12.3, 'Kylrum'],
#  [80.7, 18.6, 'Lärarrum'],
#  [52.0, 10.6, 'Kylrum'],
#  [87.9, 17.8, 'Lärarrum'],
#  [63.0, 18.5, 'Lärarrum'],
#  [63.1, 20.8, 'Lärarrum'],
#  [98.3, 19.4, 'Klassrum'],
#  [55.0, 17.1, 'Lärarrum'],
#  [54.1, 11.1, 'Kylrum'],
#  [56.3, 20.3, 'Lärarrum'],
#  [71.5, 17.5, 'Lärarrum'],
#  [85.2, 18.9, 'Lärarrum'],
#  [95.1, 19.8, 'Klassrum'],
#  [76.4, 16.6, 'Lärarrum'],
#  [73.0, 19.9, 'Lärarrum'],
#  [83.5, 19.0, 'Lärarrum'],
#  [92.9, 21.9, 'Klassrum'],
#  [58.4, 18.7, 'Lärarrum'],
#  [81.7, 21.7, 'Lärarrum'],
#  [55.0, 20.2, 'Lärarrum'],
#  [79.4, 16.5, 'Lärarrum'],
#  [55.7, 19.2, 'Lärarrum'],
#  [68.5, 21.1, 'Lärarrum'],
#  [59.1, 11.3, 'Kylrum'],
#  [90.9, 23.8, 'Klassrum'],
#  [86.3, 17.1, 'Lärarrum'],
#  [72.2, 21.7, 'Lärarrum'],
#  [56.3, 16.0, 'Lärarrum'],
#  [94.8, 21.6, 'Klassrum'],
#  [66.1, 20.1, 'Lärarrum'],
#  [83.9, 21.8, 'Lärarrum'],
#  [80.5, 21.3, 'Lärarrum'],
#  [65.7, 20.3, 'Lärarrum'],
#  [94.0, 23.2, 'Klassrum'],
#  [80.7, 22.8, 'Klassrum'],
#  [65.2, 19.2, 'Lärarrum'],
#  [96.1, 21.9, 'Klassrum'],
#  [71.7, 18.4, 'Lärarrum'],
#  [55.9, 15.3, 'Kylrum'],
#  [69.1, 21.2, 'Lärarrum'],
#  [52.3, 19.8, 'Lärarrum'],
#  [75.5, 18.3, 'Lärarrum'],
#  [55.9, 12.7, 'Kylrum'],
#  [76.8, 21.3, 'Lärarrum'],
#  [86.7, 22.7, 'Klassrum'],
#  [69.4, 20.4, 'Lärarrum'],
#  [51.8, 19.4, 'Lärarrum'],
#  [99.9, 21.0, 'Klassrum'],
#  [54.1, 18.4, 'Lärarrum'],
#  [53.7, 21.3, 'Lärarrum'],
#  [50.1, 11.5, 'Kylrum'],
#  [79.4, 19.7, 'Lärarrum'],
#  [83.1, 21.9, 'Klassrum'],
#  [46.8, 10.8, 'Kylrum'],
#  [85.3, 17.3, 'Lärarrum'],
#  [59.9, 18.9, 'Lärarrum'],
#  [53.0, 18.1, 'Lärarrum'],
#  [87.3, 19.3, 'Lärarrum'],
#  [53.2, 12.4, 'Kylrum'],
#  [56.1, 17.0, 'Lärarrum'],
#  [61.0, 17.9, 'Lärarrum'],
#  [53.9, 18.0, 'Lärarrum'],
#  [81.1, 18.2, 'Lärarrum'],
#  [89.7, 17.6, 'Lärarrum'],
#  [55.0, 14.4, 'Kylrum'],
#  [51.7, 18.0, 'Lärarrum'],
#  [85.5, 17.5, 'Lärarrum'],
#  [79.7, 21.9, 'Lärarrum'],
#  [53.5, 17.5, 'Lärarrum'],
#  [93.5, 20.1, 'Klassrum'],
#  [88.3, 16.2, 'Lärarrum'],
#  [67.6, 17.4, 'Lärarrum'],
#  [79.8, 20.6, 'Lärarrum'],
#  [51.7, 19.2, 'Lärarrum'],
#  [98.3, 20.4, 'Klassrum'],
#  [86.4, 21.5, 'Lärarrum'],
#  [59.9, 18.8, 'Lärarrum'],
#  [85.5, 22.8, 'Klassrum'],
#  [55.6, 15.6, 'Kylrum'],
#  [73.4, 18.9, 'Lärarrum'],
#  [65.5, 21.2, 'Lärarrum'],
#  [82.2, 16.5, 'Lärarrum'],
#  [53.4, 17.6, 'Lärarrum'],
#  [96.2, 18.4, 'Klassrum'],
#  [49.0, 14.4, 'Kylrum'],
#  [93.6, 23.1, 'Klassrum'],
#  [82.3, 23.1, 'Klassrum'],
#  [85.6, 21.5, 'Lärarrum'],
#  [99.1, 20.3, 'Klassrum'],
#  [84.5, 17.1, 'Lärarrum'],
#  [56.4, 10.7, 'Kylrum'],
#  [83.4, 19.4, 'Klassrum'],
#  [80.5, 20.5, 'Lärarrum'],
#  [82.9, 19.0, 'Lärarrum'],
#  [63.5, 19.1, 'Lärarrum'],
#  [89.2, 18.6, 'Klassrum'],
#  [88.5, 21.9, 'Lärarrum'],
#  [57.0, 12.8, 'Kylrum'],
#  [77.9, 18.5, 'Lärarrum'],
#  [89.9, 18.9, 'Klassrum'],
#  [53.1, 21.5, 'Lärarrum'],
#  [71.5, 20.0, 'Lärarrum'],
#  [53.1, 17.1, 'Lärarrum'],
#  [83.0, 21.9, 'Lärarrum'],
#  [83.7, 23.6, 'Klassrum'],
#  [57.0, 21.6, 'Lärarrum'],
#  [84.0, 21.5, 'Klassrum'],
#  [56.3, 19.8, 'Lärarrum'],
#  [90.6, 23.1, 'Klassrum'],
#  [75.9, 20.3, 'Lärarrum'],
#  [86.7, 20.2, 'Klassrum'],
#  [50.1, 16.4, 'Lärarrum'],
#  [78.8, 17.3, 'Lärarrum'],
#  [74.4, 16.7, 'Lärarrum'],
#  [62.5, 20.6, 'Lärarrum'],
#  [62.2, 16.2, 'Lärarrum'],
#  [66.9, 19.2, 'Lärarrum'],
#  [52.4, 19.1, 'Lärarrum'],
#  [82.2, 18.9, 'Lärarrum'],
#  [84.3, 16.2, 'Lärarrum'],
#  [87.0, 19.8, 'Lärarrum'],
#  [92.3, 21.8, 'Klassrum'],
#  [82.8, 19.8, 'Lärarrum'],
#  [56.2, 11.4, 'Kylrum'],
#  [73.4, 21.2, 'Lärarrum'],
#  [59.4, 14.0, 'Kylrum'],
#  [51.7, 17.7, 'Lärarrum'],
#  [77.5, 17.9, 'Lärarrum'],
#  [88.9, 20.3, 'Klassrum'],
#  [69.1, 19.6, 'Lärarrum'],
#  [73.8, 20.3, 'Lärarrum'],
#  [51.0, 15.5, 'Kylrum'],
#  [56.1, 19.5, 'Lärarrum'],
#  [54.6, 11.5, 'Kylrum'],
#  [52.7, 11.0, 'Kylrum'],
#  [95.6, 20.8, 'Klassrum'],
#  [76.5, 20.8, 'Lärarrum'],
#  [96.1, 18.7, 'Klassrum'],
#  [82.9, 18.1, 'Klassrum'],
#  [64.2, 16.1, 'Lärarrum'],
#  [86.8, 17.4, 'Lärarrum'],
#  [62.1, 20.0, 'Lärarrum'],
#  [87.0, 19.0, 'Lärarrum'],
#  [72.0, 17.1, 'Lärarrum'],
#  [82.9, 18.8, 'Klassrum'],
#  [62.4, 21.3, 'Lärarrum'],
#  [58.9, 14.7, 'Kylrum'],
#  [69.2, 18.2, 'Lärarrum'],
#  [71.7, 19.1, 'Lärarrum'],
#  [54.9, 21.1, 'Lärarrum'],
#  [58.6, 12.8, 'Kylrum'],
#  [74.6, 16.9, 'Lärarrum'],
#  [98.3, 22.7, 'Klassrum'],
#  [59.5, 16.9, 'Lärarrum'],
#  [59.9, 20.7, 'Lärarrum'],
#  [78.2, 20.7, 'Lärarrum'],
#  [97.5, 23.2, 'Klassrum'],
#  [53.3, 11.7, 'Kylrum'],
#  [64.4, 17.7, 'Lärarrum'],
#  [67.7, 16.8, 'Lärarrum'],
#  [53.1, 19.9, 'Lärarrum'],
#  [54.8, 21.2, 'Lärarrum'],
#  [90.6, 18.4, 'Klassrum'],
#  [82.7, 18.8, 'Klassrum'],
#  [81.7, 17.8, 'Lärarrum'],
#  [59.1, 19.7, 'Lärarrum'],
#  [88.7, 19.1, 'Klassrum'],
#  [73.1, 16.9, 'Lärarrum'],
#  [74.5, 16.2, 'Lärarrum'],
#  [54.2, 14.5, 'Kylrum'],
#  [81.1, 21.9, 'Lärarrum'],
#  [88.2, 20.0, 'Klassrum'],
#  [52.3, 16.2, 'Lärarrum'],
#  [62.7, 18.1, 'Lärarrum'],
#  [77.2, 17.2, 'Lärarrum'],
#  [54.8, 18.3, 'Lärarrum'],
#  [83.5, 18.2, 'Lärarrum'],
#  [79.8, 21.1, 'Lärarrum'],
#  [60.3, 20.0, 'Lärarrum'],
#  [57.1, 19.8, 'Lärarrum'],
#  [59.1, 18.6, 'Lärarrum'],
#  [89.0, 16.5, 'Lärarrum'],
#  [68.5, 18.7, 'Lärarrum'],
#  [82.7, 16.4, 'Lärarrum'],
#  [95.6, 18.4, 'Klassrum'],
#  [80.9, 17.4, 'Lärarrum'],
#  [83.7, 20.0, 'Lärarrum'],
#  [78.2, 21.8, 'Lärarrum'],
#  [95.1, 23.9, 'Klassrum'],
#  [82.9, 19.0, 'Klassrum'],
#  [81.8, 21.2, 'Lärarrum'],
#  [54.2, 16.2, 'Lärarrum'],
#  [72.9, 16.7, 'Lärarrum'],
#  [71.2, 22.0, 'Lärarrum'],
#  [70.5, 18.7, 'Lärarrum'],
#  [72.8, 21.3, 'Lärarrum'],
#  [80.7, 21.2, 'Lärarrum'],
#  [89.8, 21.4, 'Lärarrum'],
#  [57.3, 13.8, 'Kylrum'],
#  [67.5, 21.3, 'Lärarrum'],
#  [53.7, 19.3, 'Lärarrum'],
#  [62.8, 17.7, 'Lärarrum'],
#  [79.6, 17.2, 'Lärarrum'],
#  [86.7, 19.5, 'Klassrum'],
#  [83.2, 21.5, 'Klassrum'],
#  [46.5, 15.9, 'Kylrum'],
#  [58.9, 18.9, 'Lärarrum'],
#  [96.7, 18.0, 'Klassrum'],
#  [84.6, 21.5, 'Lärarrum'],
#  [86.7, 18.5, 'Klassrum'],
#  [55.2, 13.1, 'Kylrum'],
#  [82.2, 18.8, 'Lärarrum'],
#  [76.3, 20.8, 'Lärarrum'],
#  [58.1, 20.2, 'Lärarrum'],
#  [86.4, 23.4, 'Klassrum'],
#  [84.4, 18.7, 'Klassrum'],
#  [82.9, 19.6, 'Lärarrum'],
#  [61.6, 20.8, 'Lärarrum'],
#  [88.1, 19.9, 'Lärarrum'],
#  [88.3, 21.1, 'Lärarrum'],
#  [85.6, 20.9, 'Klassrum'],
#  [50.2, 21.9, 'Lärarrum'],
#  [87.8, 17.0, 'Lärarrum'],
#  [83.2, 18.5, 'Klassrum'],
#  [57.9, 16.3, 'Lärarrum'],
#  [59.2, 12.1, 'Kylrum'],
#  [52.0, 17.4, 'Lärarrum'],
#  [98.9, 19.4, 'Klassrum'],
#  [70.8, 20.0, 'Lärarrum'],
#  [51.7, 13.2, 'Kylrum'],
#  [70.8, 21.5, 'Lärarrum'],
#  [71.4, 21.8, 'Lärarrum'],
#  [56.5, 20.1, 'Lärarrum'],
#  [74.1, 16.9, 'Lärarrum'],
#  [55.6, 19.8, 'Lärarrum'],
#  [86.6, 17.7, 'Lärarrum'],
#  [64.2, 16.4, 'Lärarrum'],
#  [88.1, 22.0, 'Lärarrum'],
#  [60.5, 20.9, 'Lärarrum'],
#  [84.6, 16.4, 'Lärarrum'],
#  [59.4, 18.3, 'Lärarrum'],
#  [58.7, 10.6, 'Kylrum'],
#  [48.6, 15.4, 'Kylrum'],
#  [47.3, 11.0, 'Kylrum'],
#  [86.5, 19.1, 'Klassrum'],
#  [85.9, 21.5, 'Lärarrum'],
#  [52.3, 16.4, 'Lärarrum'],
#  [79.3, 16.4, 'Lärarrum'],
#  [78.0, 18.6, 'Lärarrum'],
#  [70.1, 16.5, 'Lärarrum'],
#  [71.9, 19.6, 'Lärarrum'],
#  [83.7, 21.5, 'Lärarrum'],
#  [52.6, 20.9, 'Lärarrum'],
#  [85.6, 16.8, 'Lärarrum'],
#  [48.3, 10.8, 'Kylrum'],
#  [68.3, 17.9, 'Lärarrum'],
#  [55.8, 17.5, 'Lärarrum'],
#  [50.0, 14.0, 'Kylrum'],
#  [51.4, 14.6, 'Kylrum'],
#  [60.3, 20.2, 'Lärarrum'],
#  [46.2, 12.2, 'Kylrum'],
#  [84.6, 16.7, 'Lärarrum'],
#  [88.4, 23.9, 'Klassrum'],
#  [84.3, 22.6, 'Klassrum'],
#  [51.1, 20.3, 'Lärarrum'],
#  [90.3, 20.6, 'Klassrum'],
#  [55.7, 16.6, 'Lärarrum'],
#  [58.3, 19.2, 'Lärarrum'],
#  [71.4, 20.1, 'Lärarrum'],
#  [79.4, 19.7, 'Lärarrum'],
#  [50.3, 17.9, 'Lärarrum'],
#  [78.7, 21.0, 'Lärarrum'],
#  [82.3, 18.7, 'Lärarrum'],
#  [54.4, 16.3, 'Lärarrum'],
#  [65.9, 18.2, 'Lärarrum'],
#  [71.3, 20.6, 'Lärarrum'],
#  [82.3, 20.1, 'Lärarrum'],
#  [63.0, 17.8, 'Lärarrum'],
#  [78.7, 17.1, 'Lärarrum'],
#  [52.9, 16.9, 'Lärarrum'],
#  [99.1, 22.9, 'Klassrum'],
#  [52.7, 10.7, 'Kylrum'],
#  [83.8, 16.9, 'Lärarrum'],
#  [66.0, 19.9, 'Lärarrum'],
#  [76.6, 17.9, 'Lärarrum'],
#  [56.2, 16.8, 'Lärarrum'],
#  [57.2, 16.7, 'Lärarrum'],
#  [53.2, 10.8, 'Kylrum'],
#  [92.3, 22.9, 'Klassrum'],
#  [82.9, 20.4, 'Klassrum'],
#  [63.7, 19.4, 'Lärarrum'],
#  [63.0, 17.5, 'Lärarrum'],
#  [58.8, 18.5, 'Lärarrum'],
#  [57.1, 11.8, 'Kylrum'],
#  [83.0, 23.9, 'Klassrum'],
#  [76.1, 16.3, 'Lärarrum'],
#  [91.3, 20.5, 'Klassrum'],
#  [62.0, 21.5, 'Lärarrum'],
#  [83.6, 20.6, 'Klassrum'],
#  [85.1, 20.3, 'Klassrum'],
#  [83.3, 22.7, 'Klassrum'],
#  [52.6, 15.3, 'Kylrum'],
#  [74.0, 16.5, 'Lärarrum'],
#  [82.4, 19.4, 'Lärarrum'],
#  [52.1, 21.4, 'Lärarrum'],
#  [56.5, 17.4, 'Lärarrum'],
#  [52.0, 18.1, 'Lärarrum'],
#  [83.2, 21.5, 'Lärarrum'],
#  [50.1, 16.7, 'Lärarrum'],
#  [90.0, 16.5, 'Lärarrum'],
#  [77.9, 16.4, 'Lärarrum'],
#  [56.4, 17.9, 'Lärarrum'],
#  [53.8, 13.3, 'Kylrum'],
#  [94.5, 20.0, 'Klassrum'],
#  [85.9, 16.3, 'Lärarrum'],
#  [84.5, 22.9, 'Klassrum'],
#  [55.9, 16.9, 'Lärarrum'],
#  ...]

# %%
def find_best_split(rows):
    """Find the best question to ask by iterating over every feature / value
    and calculating the information gain."""
    best_gain = 0  # keep track of the best information gain
    best_question = None  # keep train of the feature / value that produced it
    current_uncertainty = gini(rows)
    n_features = len(rows[0]) - 1  # number of columns

    for col in range(n_features):  # for each feature

        values = set([row[col] for row in rows])  # unique values in the column

        for val in values:  # for each value
            for less in range(0,2):
                for eq in range(0,2):
                    question = Question(col, val, less, eq)

                    # try splitting the dataset
                    true_rows, false_rows = partition(rows, question)

                    # Skip this split if it doesn't divide the
                    # dataset.
                    if len(true_rows) == 0 or len(false_rows) == 0:
                        continue

                    # Calculate the information gain from this split
                    gain = info_gain(true_rows, false_rows, current_uncertainty)

                    # You actually can use '>' instead of '>=' here
                    # but I wanted the tree to look a certain way for our
                    # toy dataset.
                    if gain > best_gain:
                        best_gain, best_question = gain, question

    return best_gain, best_question

# %%
# %%time
#######
# Demo:
# Find the best question to ask first for our toy dataset.
best_gain, best_question = find_best_split(training_data)
best_question
# FYI: is color == Red is just as good. See the note in the code above
# where I used '>='.
#######
# Out:
# Wall time: 3.98 s
# Är temperatur >= 16.0?

# %%
class Leaf:
    """A Leaf node classifies data.

    This holds a dictionary of class (e.g., "Apple") -> number of times
    it appears in the rows from the training data that reach this leaf.
    """

    def __init__(self, rows):
        self.predictions = class_counts(rows)

# %%
class Decision_Node:
    """A Decision Node asks a question.

    This holds a reference to the question, and to the two child nodes.
    """

    def __init__(self,
                 question,
                 true_branch,
                 false_branch):
        self.question = question
        self.true_branch = true_branch
        self.false_branch = false_branch

# %%
def build_tree(rows):
    """Builds the tree.

    Rules of recursion: 1) Believe that it works. 2) Start by checking
    for the base case (no further information gain). 3) Prepare for
    giant stack traces.
    """

    # Try partitioing the dataset on each of the unique attribute,
    # calculate the information gain,
    # and return the question that produces the highest gain.
    gain, question = find_best_split(rows)

    # Base case: no further info gain
    # Since we can ask no further questions,
    # we'll return a leaf.
    if gain == 0:
        return Leaf(rows)

    # If we reach here, we have found a useful feature / value
    # to partition on.
    true_rows, false_rows = partition(rows, question)

    # Recursively build the true branch.
    true_branch = build_tree(true_rows)

    # Recursively build the false branch.
    false_branch = build_tree(false_rows)

    # Return a Question node.
    # This records the best feature / value to ask at this point,
    # as well as the branches to follow
    # dependingo on the answer.
    return Decision_Node(question, true_branch, false_branch)

# %%
def print_tree(node, spacing=""):
    """World's most elegant tree printing function."""

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        print (spacing + "Predict", node.predictions)
        return

    # Print the question at this node
    print (spacing + str(node.question))

    # Call this function recursively on the true branch
    print (spacing + '--> True:')
    print_tree(node.true_branch, spacing + "  ")

    # Call this function recursively on the false branch
    print (spacing + '--> False:')
    print_tree(node.false_branch, spacing + "  ")

# %%
## Här nedan är decisionForest funktionen
## Även en loop som bygger 20 träd från 500 slumpmässigt valda datapunkter

# %%
# %%time
trees = []
for n in range (1,21):
    tree = build_tree(random.sample(training_data, 500))
    trees.append(tree)
def decisionForest(row):
    votes = {'Kylrum': 0, 'Lärarrum': 0, 'Klassrum': 0}
    for tree in trees:
        predict = classify(row, tree)
        maxValue = max(predict.items(), key = operator.itemgetter(1))[0]
        votes[maxValue] += 1/len(trees)
    for key in votes:
        votes[key] = str(round(votes[key]*100)) + '%'
    return votes
decisionForest([30, 15.6, 'Kylrum'])
# Out:
# {'Kylrum': '100%', 'Lärarrum': '0%', 'Klassrum': '0%'}

# %%
my_tree = build_tree(training_data)

# %%
print_tree(my_tree)
# Out:
# Är luftfuktighet > 79.9?
# --> True:
#   Är temperatur >= 18.0?
#   --> True:
#     Är luftfuktighet < 89.7?
#     --> True:
#       Är temperatur <= 21.7?
#       --> True:
#         Är luftfuktighet >= 80.9?
#         --> True:
#           Är luftfuktighet >= 84.6?
#           --> True:
#             Är luftfuktighet > 88.6?
#             --> True:
#               Är temperatur < 18.7?
#               --> True:
#                 Är luftfuktighet >= 89.5?
#                 --> True:
#                   Predict {'Lärarrum': 3}
#                 --> False:
#                   Är temperatur > 18.4?
#                   --> True:
#                     Predict {'Lärarrum': 1}
#                   --> False:
#                     Predict {'Klassrum': 2}
#               --> False:
#                 Är luftfuktighet >= 89.0?
#                 --> True:
#                   Är temperatur >= 19.6?
#                   --> True:
#                     Är temperatur <= 21.6?
#                     --> True:
#                       Är luftfuktighet > 89.5?
#                       --> True:
#                         Predict {'Lärarrum': 1}
#                       --> False:
#                         Är temperatur >= 20.4?
#                         --> True:
#                           Är temperatur >= 21.6?
#                           --> True:
#                             Predict {'Klassrum': 1, 'Lärarrum': 1}
#                           --> False:
#                             Är luftfuktighet < 89.1?
#                             --> True:
#                               Är temperatur > 20.7?
#                               --> True:
#                                 Predict {'Klassrum': 2}
#                               --> False:
#                                 Predict {'Lärarrum': 1}
#                             --> False:
#                               Predict {'Klassrum': 7}
#                         --> False:
#                           Är temperatur > 19.9?
#                           --> True:
#                             Predict {'Lärarrum': 1}
#                           --> False:
#                             Är temperatur >= 19.7?
#                             --> True:
#                               Predict {'Klassrum': 2}
#                             --> False:
#                               Predict {'Lärarrum': 1, 'Klassrum': 1}
#                     --> False:
#                       Predict {'Klassrum': 3}
#                   --> False:
#                     Predict {'Klassrum': 7}
#                 --> False:
#                   Är temperatur > 21.4?
#                   --> True:
#                     Predict {'Lärarrum': 1}
#                   --> False:
#                     Är temperatur >= 21.1?
#                     --> True:
#                       Predict {'Klassrum': 3}
#                     --> False:
#                       Är temperatur < 20.2?
#                       --> True:
#                         Är temperatur > 19.1?
#                         --> True:
#                           Predict {'Klassrum': 2}
#                         --> False:
#                           Är luftfuktighet > 88.7?
#                           --> True:
#                             Predict {'Lärarrum': 1}
#                           --> False:
#                             Predict {'Klassrum': 1}
#                       --> False:
#                         Är luftfuktighet >= 88.9?
#                         --> True:
#                           Predict {'Lärarrum': 3}
#                         --> False:
#                           Predict {'Lärarrum': 1, 'Klassrum': 1}
#             --> False:
#               Är temperatur < 18.4?
#               --> True:
#                 Är luftfuktighet > 85.7?
#                 --> True:
#                   Predict {'Klassrum': 13}
#                 --> False:
#                   Är luftfuktighet > 85.6?
#                   --> True:
#                     Predict {'Lärarrum': 1}
#                   --> False:
#                     Är luftfuktighet > 85.5?
#                     --> True:
#                       Är temperatur >= 18.3?
#                       --> True:
#                         Predict {'Klassrum': 2}
#                       --> False:
#                         Predict {'Lärarrum': 1}
#                     --> False:
#                       Predict {'Klassrum': 4}
#               --> False:
#                 Är temperatur > 18.4?
#                 --> True:
#                   Är temperatur >= 19.2?
#                   --> True:
#                     Är luftfuktighet > 88.4?
#                     --> True:
#                       Predict {'Lärarrum': 1}
#                     --> False:
#                       Är luftfuktighet <= 85.2?
#                       --> True:
#                         Är temperatur >= 21.4?
#                         --> True:
#                           Är luftfuktighet > 85.0?
#                           --> True:
#                             Predict {'Klassrum': 2}
#                           --> False:
#                             Predict {'Lärarrum': 2}
#                         --> False:
#                           Är temperatur > 19.9?
#                           --> True:
#                             Är luftfuktighet >= 85.1?
#                             --> True:
#                               Är luftfuktighet >= 85.2?
#                               --> True:
#                                 Predict {'Klassrum': 2}
#                               --> False:
#                                 Är temperatur >= 21.1?
#                                 --> True:
#                                   Predict {'Klassrum': 1}
#                                 --> False:
#                                   Predict {'Lärarrum': 1}
#                             --> False:
#                               Predict {'Klassrum': 6}
#                           --> False:
#                             Är temperatur >= 19.8?
#                             --> True:
#                               Är luftfuktighet >= 85.1?
#                               --> True:
#                                 Är luftfuktighet > 85.1?
#                                 --> True:
#                                   Predict {'Lärarrum': 1}
#                                 --> False:
#                                   Predict {'Klassrum': 1}
#                               --> False:
#                                 Predict {'Lärarrum': 1}
#                             --> False:
#                               Predict {'Klassrum': 2}
#                       --> False:
#                         Är temperatur >= 20.7?
#                         --> True:
#                           Är luftfuktighet <= 86.1?
#                           --> True:
#                             Är luftfuktighet > 86.0?
#                             --> True:
#                               Predict {'Lärarrum': 1}
#                             --> False:
#                               Är temperatur > 21.3?
#                               --> True:
#                                 Är luftfuktighet > 85.6?
#                                 --> True:
#                                   Predict {'Lärarrum': 1}
#                                 --> False:
#                                   Predict {'Klassrum': 1}
#                               --> False:
#                                 Predict {'Klassrum': 7}
#                           --> False:
#                             Är temperatur >= 21.5?
#                             --> True:
#                               Är luftfuktighet >= 87.3?
#                               --> True:
#                                 Predict {'Klassrum': 5}
#                               --> False:
#                                 Predict {'Lärarrum': 1}
#                             --> False:
#                               Predict {'Klassrum': 19}
#                         --> False:
#                           Är temperatur > 20.1?
#                           --> True:
#                             Är luftfuktighet >= 88.1?
#                             --> True:
#                               Predict {'Lärarrum': 2}
#                             --> False:
#                               Är luftfuktighet <= 86.3?
#                               --> True:
#                                 Predict {'Klassrum': 3}
#                               --> False:
#                                 Är luftfuktighet >= 86.5?
#                                 --> True:
#                                   Är luftfuktighet > 87.4?
#                                   --> True:
#                                     Predict {'Klassrum': 2}
#                                   --> False:
#                                     Är luftfuktighet >= 86.8?
#                                     --> True:
#                                       Är temperatur >= 20.6?
#                                       --> True:
#                                         Predict {'Lärarrum': 2}
#                                       --> False:
#                                         Är luftfuktighet > 86.9?
#                                         --> True:
#                                           Är temperatur >= 20.3?
#                                           --> True:
#                                             Predict {'Lärarrum': 1}
#                                           --> False:
#                                             Predict {'Klassrum': 1}
#                                         --> False:
#                                           Predict {'Klassrum': 1}
#                                     --> False:
#                                       Predict {'Klassrum': 2}
#                                 --> False:
#                                   Predict {'Lärarrum': 1}
#                           --> False:
#                             Är temperatur >= 19.6?
#                             --> True:
#                               Är temperatur >= 19.9?
#                               --> True:
#                                 Predict {'Klassrum': 11}
#                               --> False:
#                                 Är temperatur > 19.7?
#                                 --> True:
#                                   Är luftfuktighet > 86.9?
#                                   --> True:
#                                     Predict {'Lärarrum': 1}
#                                   --> False:
#                                     Predict {'Klassrum': 2}
#                                 --> False:
#                                   Predict {'Klassrum': 7}
#                             --> False:
#                               Är luftfuktighet > 85.4?
#                               --> True:
#                                 Är luftfuktighet >= 87.0?
#                                 --> True:
#                                   Är luftfuktighet > 87.0?
#                                   --> True:
#                                     Är temperatur > 19.4?
#                                     --> True:
#                                       Är luftfuktighet >= 87.6?
#                                       --> True:
#                                         Predict {'Lärarrum': 1}
#                                       --> False:
#                                         Predict {'Klassrum': 1}
#                                     --> False:
#                                       Predict {'Klassrum': 5}
#                                   --> False:
#                                     Predict {'Lärarrum': 1}
#                                 --> False:
#                                   Predict {'Klassrum': 5}
#                               --> False:
#                                 Är luftfuktighet > 85.3?
#                                 --> True:
#                                   Predict {'Lärarrum': 1}
#                                 --> False:
#                                   Predict {'Klassrum': 1}
#                   --> False:
#                     Är luftfuktighet >= 85.5?
#                     --> True:
#                       Är temperatur > 19.0?
#                       --> True:
#                         Predict {'Lärarrum': 1}
#                       --> False:
#                         Är luftfuktighet >= 88.5?
#                         --> True:
#                           Predict {'Klassrum': 2}
#                         --> False:
#                           Är temperatur > 18.8?
#                           --> True:
#                             Är luftfuktighet > 85.9?
#                             --> True:
#                               Predict {'Lärarrum': 3}
#                             --> False:
#                               Är luftfuktighet > 85.5?
#                               --> True:
#                                 Predict {'Klassrum': 2}
#                               --> False:
#                                 Predict {'Klassrum': 1, 'Lärarrum': 1}
#                           --> False:
#                             Är luftfuktighet > 87.1?
#                             --> True:
#                               Predict {'Klassrum': 4}
#                             --> False:
#                               Är temperatur > 18.6?
#                               --> True:
#                                 Predict {'Klassrum': 2}
#                               --> False:
#                                 Är luftfuktighet >= 86.8?
#                                 --> True:
#                                   Är luftfuktighet > 86.8?
#                                   --> True:
#                                     Predict {'Lärarrum': 1}
#                                   --> False:
#                                     Predict {'Klassrum': 1}
#                                 --> False:
#                                   Predict {'Lärarrum': 1}
#                     --> False:
#                       Predict {'Klassrum': 4}
#                 --> False:
#                   Predict {'Lärarrum': 2}
#           --> False:
#             Är temperatur > 20.9?
#             --> True:
#               Är temperatur >= 21.2?
#               --> True:
#                 Är luftfuktighet > 81.8?
#                 --> True:
#                   Är luftfuktighet >= 82.3?
#                   --> True:
#                     Är luftfuktighet < 83.1?
#                     --> True:
#                       Är temperatur >= 21.3?
#                       --> True:
#                         Predict {'Klassrum': 4}
#                       --> False:
#                         Predict {'Lärarrum': 1}
#                     --> False:
#                       Är luftfuktighet > 83.9?
#                       --> True:
#                         Är temperatur >= 21.5?
#                         --> True:
#                           Predict {'Lärarrum': 2}
#                         --> False:
#                           Predict {'Klassrum': 3}
#                       --> False:
#                         Predict {'Lärarrum': 4}
#                   --> False:
#                     Predict {'Lärarrum': 2}
#                 --> False:
#                   Predict {'Klassrum': 5}
#               --> False:
#                 Är luftfuktighet > 82.5?
#                 --> True:
#                   Är luftfuktighet > 84.4?
#                   --> True:
#                     Predict {'Lärarrum': 1}
#                   --> False:
#                     Predict {'Klassrum': 2}
#                 --> False:
#                   Predict {'Lärarrum': 4}
#             --> False:
#               Är temperatur > 19.9?
#               --> True:
#                 Är luftfuktighet >= 84.2?
#                 --> True:
#                   Är temperatur >= 20.6?
#                   --> True:
#                     Predict {'Klassrum': 2}
#                   --> False:
#                     Predict {'Lärarrum': 2}
#                 --> False:
#                   Är luftfuktighet <= 83.4?
#                   --> True:
#                     Är luftfuktighet >= 83.4?
#                     --> True:
#                       Predict {'Lärarrum': 1}
#                     --> False:
#                       Är luftfuktighet >= 81.7?
#                       --> True:
#                         Är luftfuktighet <= 82.1?
#                         --> True:
#                           Är luftfuktighet >= 82.1?
#                           --> True:
#                             Predict {'Lärarrum': 3}
#                           --> False:
#                             Är luftfuktighet >= 81.8?
#                             --> True:
#                               Predict {'Klassrum': 3}
#                             --> False:
#                               Är temperatur >= 20.4?
#                               --> True:
#                                 Predict {'Lärarrum': 1}
#                               --> False:
#                                 Predict {'Klassrum': 1}
#                         --> False:
#                           Är luftfuktighet > 82.9?
#                           --> True:
#                             Predict {'Klassrum': 5}
#                           --> False:
#                             Är luftfuktighet > 82.7?
#                             --> True:
#                               Är temperatur > 20.4?
#                               --> True:
#                                 Predict {'Klassrum': 1}
#                               --> False:
#                                 Predict {'Lärarrum': 1}
#                             --> False:
#                               Predict {'Klassrum': 3}
#                       --> False:
#                         Är luftfuktighet >= 81.1?
#                         --> True:
#                           Predict {'Klassrum': 10}
#                         --> False:
#                           Är luftfuktighet > 80.9?
#                           --> True:
#                             Är temperatur > 20.0?
#                             --> True:
#                               Är temperatur >= 20.5?
#                               --> True:
#                                 Predict {'Klassrum': 1}
#                               --> False:
#                                 Predict {'Lärarrum': 1}
#                             --> False:
#                               Predict {'Klassrum': 1}
#                           --> False:
#                             Predict {'Klassrum': 1}
#                   --> False:
#                     Predict {'Klassrum': 12}
#               --> False:
#                 Är luftfuktighet >= 81.8?
#                 --> True:
#                   Är luftfuktighet <= 83.1?
#                   --> True:
#                     Är luftfuktighet > 82.8?
#                     --> True:
#                       Predict {'Klassrum': 5}
#                     --> False:
#                       Är temperatur >= 18.4?
#                       --> True:
#                         Är temperatur > 18.4?
#                         --> True:
#                           Är luftfuktighet >= 82.4?
#                           --> True:
#                             Är temperatur >= 18.8?
#                             --> True:
#                               Är temperatur > 19.2?
#                               --> True:
#                                 Är luftfuktighet > 82.7?
#                                 --> True:
#                                   Predict {'Lärarrum': 1}
#                                 --> False:
#                                   Är luftfuktighet >= 82.6?
#                                   --> True:
#                                     Predict {'Klassrum': 2}
#                                   --> False:
#                                     Är luftfuktighet > 82.4?
#                                     --> True:
#                                       Predict {'Lärarrum': 1}
#                                     --> False:
#                                       Predict {'Klassrum': 1}
#                               --> False:
#                                 Predict {'Klassrum': 4}
#                             --> False:
#                               Predict {'Lärarrum': 1}
#                           --> False:
#                             Predict {'Klassrum': 11}
#                         --> False:
#                           Är luftfuktighet >= 82.5?
#                           --> True:
#                             Predict {'Klassrum': 1}
#                           --> False:
#                             Predict {'Lärarrum': 2}
#                       --> False:
#                         Predict {'Klassrum': 4}
#                   --> False:
#                     Är temperatur >= 18.1?
#                     --> True:
#                       Är luftfuktighet > 83.5?
#                       --> True:
#                         Är temperatur <= 18.9?
#                         --> True:
#                           Är temperatur < 18.3?
#                           --> True:
#                             Är luftfuktighet > 83.8?
#                             --> True:
#                               Är luftfuktighet > 84.0?
#                               --> True:
#                                 Predict {'Klassrum': 1}
#                               --> False:
#                                 Predict {'Lärarrum': 1}
#                             --> False:
#                               Predict {'Klassrum': 1}
#                           --> False:
#                             Predict {'Klassrum': 4}
#                         --> False:
#                           Är temperatur <= 19.3?
#                           --> True:
#                             Är luftfuktighet > 83.7?
#                             --> True:
#                               Är luftfuktighet > 84.3?
#                               --> True:
#                                 Predict {'Lärarrum': 1}
#                               --> False:
#                                 Är luftfuktighet <= 83.9?
#                                 --> True:
#                                   Predict {'Lärarrum': 1, 'Klassrum': 1}
#                                 --> False:
#                                   Predict {'Klassrum': 1}
#                             --> False:
#                               Predict {'Lärarrum': 1}
#                           --> False:
#                             Är temperatur >= 19.9?
#                             --> True:
#                               Är luftfuktighet > 84.4?
#                               --> True:
#                                 Predict {'Klassrum': 1}
#                               --> False:
#                                 Predict {'Lärarrum': 1}
#                             --> False:
#                               Predict {'Klassrum': 4}
#                       --> False:
#                         Är temperatur > 18.2?
#                         --> True:
#                           Är temperatur > 18.3?
#                           --> True:
#                             Är temperatur > 18.5?
#                             --> True:
#                               Är luftfuktighet >= 83.5?
#                               --> True:
#                                 Är temperatur < 19.7?
#                                 --> True:
#                                   Är temperatur > 18.7?
#                                   --> True:
#                                     Predict {'Klassrum': 1}
#                                   --> False:
#                                     Predict {'Lärarrum': 1}
#                                 --> False:
#                                   Predict {'Lärarrum': 1}
#                               --> False:
#                                 Är luftfuktighet >= 83.3?
#                                 --> True:
#                                   Predict {'Klassrum': 2}
#                                 --> False:
#                                   Är temperatur < 19.8?
#                                   --> True:
#                                     Predict {'Lärarrum': 1, 'Klassrum': 1}
#                                   --> False:
#                                     Predict {'Klassrum': 1}
#                             --> False:
#                               Predict {'Lärarrum': 2}
#                           --> False:
#                             Predict {'Klassrum': 2}
#                         --> False:
#                           Predict {'Lärarrum': 2}
#                     --> False:
#                       Predict {'Klassrum': 2}
#                 --> False:
#                   Är luftfuktighet > 81.2?
#                   --> True:
#                     Är luftfuktighet > 81.5?
#                     --> True:
#                       Predict {'Lärarrum': 3}
#                     --> False:
#                       Är temperatur >= 18.9?
#                       --> True:
#                         Predict {'Klassrum': 1}
#                       --> False:
#                         Predict {'Lärarrum': 2}
#                   --> False:
#                     Är luftfuktighet > 80.9?
#                     --> True:
#                       Predict {'Klassrum': 3}
#                     --> False:
#                       Är temperatur > 19.4?
#                       --> True:
#                         Predict {'Klassrum': 1}
#                       --> False:
#                         Är temperatur >= 19.4?
#                         --> True:
#                           Predict {'Lärarrum': 2}
#                         --> False:
#                           Predict {'Klassrum': 1}
#         --> False:
#           Är luftfuktighet > 80.4?
#           --> True:
#             Predict {'Klassrum': 16}
#           --> False:
#             Är temperatur >= 18.8?
#             --> True:
#               Är luftfuktighet > 80.3?
#               --> True:
#                 Är temperatur > 20.3?
#                 --> True:
#                   Predict {'Klassrum': 2}
#                 --> False:
#                   Är temperatur > 19.0?
#                   --> True:
#                     Predict {'Lärarrum': 1}
#                   --> False:
#                     Predict {'Klassrum': 1}
#               --> False:
#                 Predict {'Klassrum': 12}
#             --> False:
#               Är luftfuktighet > 80.0?
#               --> True:
#                 Är luftfuktighet > 80.2?
#                 --> True:
#                   Predict {'Klassrum': 3}
#                 --> False:
#                   Är temperatur > 18.5?
#                   --> True:
#                     Predict {'Klassrum': 2}
#                   --> False:
#                     Predict {'Lärarrum': 1}
#               --> False:
#                 Predict {'Lärarrum': 1}
#       --> False:
#         Är temperatur <= 21.8?
#         --> True:
#           Är luftfuktighet > 82.4?
#           --> True:
#             Predict {'Klassrum': 8}
#           --> False:
#             Är luftfuktighet >= 82.4?
#             --> True:
#               Predict {'Lärarrum': 1}
#             --> False:
#               Predict {'Klassrum': 3}
#         --> False:
#           Predict {'Klassrum': 201}
#     --> False:
#       Är luftfuktighet > 89.9?
#       --> True:
#         Predict {'Klassrum': 497}
#       --> False:
#         Är luftfuktighet >= 89.9?
#         --> True:
#           Är temperatur > 21.0?
#           --> True:
#             Predict {'Lärarrum': 1}
#           --> False:
#             Predict {'Klassrum': 3}
#         --> False:
#           Predict {'Klassrum': 10}
#   --> False:
#     Predict {'Lärarrum': 52}
# --> False:
#   Är temperatur >= 16.0?
#   --> True:
#     Är temperatur >= 16.1?
#     --> True:
#       Predict {'Lärarrum': 425}
#     --> False:
#       Är luftfuktighet > 54.1?
#       --> True:
#         Predict {'Lärarrum': 2}
#       --> False:
#         Predict {'Kylrum': 1}
#   --> False:
#     Predict {'Kylrum': 404}

# %%
def classify(row, node):
    """See the 'rules of recursion' above."""

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        return node.predictions

    # Decide whether to follow the true-branch or the false-branch.
    # Compare the feature / value stored in the node,
    # to the example we're considering.
    if node.question.moreless(row):
        return classify(row, node.true_branch)
    else:
        return classify(row, node.false_branch)

# %%
#######
# Demo:
# The tree predicts the 1st row of our
# training data is an apple with confidence 1.
classify(training_data[0], my_tree)
#######
# Out:
# {'Klassrum': 201}

# %%
def print_leaf(counts):
    """A nicer way to print the predictions at a leaf."""
    total = sum(counts.values())
    probs = {}
    for lbl in counts.keys():
        probs[lbl] = str(int(counts[lbl] / total * 100)) + "%"
    return probs

# %%
#######
# Demo:
# Printing that a bit nicer
print_leaf(classify(training_data[0], my_tree))
#######
# Out:
# {'Klassrum': '100%'}

# %%
#######
# Demo:
# On the second example, the confidence is lower
print_leaf(classify(training_data[1], my_tree))
#######
# Out:
# {'Lärarrum': '100%'}

# %%
# Evaluate
testing_data = dataGenerator(5)

# %%
## Här nedan körs decisionForest funktionen på lite test-data

# %%
for row in testing_data:
    print ("Actual: %s. Predicted: %s" %
           (row[-1], decisionForest(row)))
# Out:
# Actual: Kylrum. Predicted: {'Kylrum': '100%', 'Lärarrum': '0%', 'Klassrum': '0%'}
# Actual: Kylrum. Predicted: {'Kylrum': '100%', 'Lärarrum': '0%', 'Klassrum': '0%'}
# Actual: Lärarrum. Predicted: {'Kylrum': '0%', 'Lärarrum': '100%', 'Klassrum': '0%'}
# Actual: Klassrum. Predicted: {'Kylrum': '0%', 'Lärarrum': '70%', 'Klassrum': '30%'}
# Actual: Klassrum. Predicted: {'Kylrum': '0%', 'Lärarrum': '0%', 'Klassrum': '100%'}
# Actual: Klassrum. Predicted: {'Kylrum': '0%', 'Lärarrum': '70%', 'Klassrum': '30%'}
# Actual: Klassrum. Predicted: {'Kylrum': '0%', 'Lärarrum': '70%', 'Klassrum': '30%'}
# Actual: Klassrum. Predicted: {'Kylrum': '0%', 'Lärarrum': '0%', 'Klassrum': '100%'}
